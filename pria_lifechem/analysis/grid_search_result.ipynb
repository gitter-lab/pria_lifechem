# %%
from virtual_screening.analysis.analysis import *

file_paths = {0: 'single_classification/45472002/', #0: 'single_classification/45472002/',
              1: 'single_regression/45472003/', 
              2: 'vanilla_lstm/45476819/',
              3: 'multi_classification/45472055/'}

number = {0: 48, 1: 24, 2: 30, 3: 24}

evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01'}

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (25.0, 5.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Single-task Classification

# %%
k = 0

# %%
check_result_completeness(dir_='../../output/grid_search/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1']

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [22, 46, 42, 19, 44]
# [ 0.56023059  0.54468522  0.49855678  0.4966316   0.49116136  0.47680627
#   0.4727313   0.45420578  0.43424759  0.42450489  0.4170471   0.41542322
#   0.41237759  0.40371276  0.40036183  0.3986052   0.39770799  0.39659209
#   0.38293949  0.38055588  0.3705572   0.34825154  0.3466667   0.34469222
#   0.33428107  0.33056223  0.3277793   0.32380452  0.31318678  0.30777919
#   0.28950062  0.28334525  0.24597267  0.22437752  0.19680541  0.19584445
#   0.17886991  0.15129161  0.14532467  0.13684852  0.12715543  0.11708131
#   0.09937945  0.09366183  0.06919845  0.06894515  0.01877328  0.01514217]
#
# Analyze val roc:
# Top 5 rankings:  [7, 4, 8, 44, 45]
# [ 0.95992025  0.95791992  0.9514936   0.95070942  0.95070942  0.93851803
#   0.93834856  0.93353049  0.93075262  0.92784848  0.92582821  0.9253896
#   0.9178734   0.91656421  0.91627181  0.91477986  0.9126433   0.90856288
# ...

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [0, 2, 6, 10, 39]
# [ 0.18977356  0.18520124  0.16952055  0.15093599  0.14679677  0.14033002
#   0.11716817  0.11250193  0.11044394  0.10798461  0.10556792  0.10520439
#   0.10428606  0.09772711  0.09541813  0.09449073  0.09291162  0.09176366
#   0.0916938   0.09086729  0.09083298  0.08791405  0.08660308  0.0856499
#   0.08563268  0.08241272  0.08233762  0.08198592  0.07708811  0.0747738
#   0.07344152  0.07164041  0.06467223  0.06307171  0.05499849  0.05283926
#   0.05281306  0.04920895  0.04667819  0.04528205  0.04215218  0.03976733
#   0.03768349  0.03601575  0.0311399   0.02998645  0.02767475  0.01755492]
#
# Analyze test roc:
# Top 5 rankings:  [25, 32, 43, 42, 36]
# [ 0.82191603  0.81894653  0.81080252  0.80008855  0.798052    0.79283863
#   0.7907157   0.78523454  0.77881609  0.77620292  0.77616621  0.77025959
#   0.76524274  0.75924542  0.75903594  0.74651866  0.7449702   0.74019307
# ...

# %% [markdown]
# # Single-task Regression

# %%
k = 1

# %%
check_result_completeness(dir_='../../output/grid_search/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1']

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [8, 5, 2, 11, 10]
# [ 0.20861519  0.12241459  0.06466855  0.05683699  0.04088439  0.03261961
#   0.02265087  0.02264738  0.02193686  0.01965718  0.0147569   0.01353486
#   0.00516312  0.00507582  0.00471419  0.004538    0.00425672  0.00389649
#   0.00382057  0.00330063  0.00284767  0.00270752  0.0024767   0.00245812]
#
# Analyze val roc:
# Top 5 rankings:  [1, 3, 9, 5, 7]
# [ 0.9118857   0.91144044  0.91097525  0.9109686   0.91048347  0.90650939
#   0.89050673  0.88708423  0.87895664  0.87678352  0.86585147  0.86465858
#   0.84680512  0.84276458  0.82560226  0.82354544  0.82108656  0.81170959
#   0.80350224  0.80162153  0.79840505  0.79824888  0.76393089  0.74984881]
#
# Analyze val bedroc:
# Top 5 rankings:  [5, 11, 2, 3, 1]
# [ 0.73445987  0.71922495  0.68913339  0.68366581  0.68347991  0.67919749
#   0.67778909  0.67547627  0.60545318  0.59037935  0.53918697  0.53540611
#   0.41387966  0.40924558  0.38921272  0.37644633  0.36473507  0.33583248
# ...

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [5, 11, 8, 2, 3]
# [ 0.12370219  0.09902602  0.08985583  0.0653226   0.06220102  0.05831003
#   0.04458258  0.04089053  0.03553309  0.03523414  0.01706151  0.01644912
#   0.00371556  0.00366932  0.00365551  0.00364435  0.00297075  0.00283624
#   0.00275798  0.00239052  0.00233371  0.00226133  0.00222442  0.002008  ]
#
# Analyze test roc:
# Top 5 rankings:  [4, 10, 2, 9, 3]
# [ 0.88150052  0.88020905  0.87512958  0.87179077  0.87106945  0.84486006
#   0.84056237  0.83335781  0.8252462   0.822132    0.79642364  0.7962811
#   0.78282438  0.77403464  0.77367614  0.77040428  0.75999914  0.75395646
#   0.74036584  0.73398842  0.73387396  0.7337595   0.72504319  0.68078136]
#
# Analyze test bedroc:
# Top 5 rankings:  [10, 4, 8, 2, 11]
# [ 0.61525194  0.61394937  0.59313483  0.582335    0.57678205  0.56603207
#   0.563039    0.55432956  0.5417806   0.5345313   0.51702883  0.51424909
# ...

# %% [markdown]
# # Vanilla LSTM

# %%
k = 2

# %%
check_result_completeness(dir_='../../output/grid_search/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1']

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [25, 11, 10, 0, 29]
# [ 0.00601978  0.00436316  0.00352429  0.00310255  0.00278298  0.00260181
#   0.00250767  0.00224109  0.00196328  0.00184904  0.00181025  0.00177294
#   0.00170483  0.00168471  0.00162804  0.00157509  0.00156163  0.00152243
#   0.00146069  0.0014235   0.00141692  0.00139835  0.00139508  0.00131425
#   0.00127153  0.00124733  0.00124617  0.00115296  0.00110375  0.00084489]
#
# Analyze val roc:
# Top 5 rankings:  [10, 17, 4, 7, 12]
# [ 0.71003821  0.68533643  0.66767569  0.65734507  0.64252201  0.63277289
#   0.62776209  0.62273135  0.61769729  0.61270643  0.61193221  0.60655258
#   0.60464861  0.59288586  0.58951653  0.58786842  0.5865692   0.58559894
#   0.56639973  0.56294401  0.55741153  0.55535139  0.55365343  0.54737332
#   0.53626516  0.52522678  0.51818575  0.51714238  0.48009968  0.46253198]
#
# Analyze val bedroc:
# Top 5 rankings:  [10, 27, 7, 25, 11]
# ...

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [11, 8, 25, 0, 19]
# [ 0.01321857  0.01255196  0.00687299  0.00668433  0.00550561  0.00381441
#   0.00300325  0.00289525  0.00275484  0.00241745  0.00200573  0.0019768
#   0.0019468   0.00158839  0.00155694  0.00143763  0.00139179  0.00128497
#   0.00122871  0.00121024  0.0012071   0.00103515  0.00101236  0.00096027
#   0.00094364  0.00092906  0.00092507  0.00089858  0.00086595  0.00072519]
#
# Analyze test roc:
# Top 5 rankings:  [9, 19, 3, 16, 8]
# [ 0.6813515   0.66634416  0.66415644  0.64104613  0.63556064  0.62156185
#   0.59156228  0.58995119  0.58329734  0.58038614  0.57038917  0.56450631
#   0.55891716  0.54743435  0.53783474  0.5368046   0.53201451  0.49921605
#   0.48938969  0.47836904  0.47387699  0.46496199  0.45904242  0.45246631
#   0.45155494  0.44046735  0.43923419  0.42050579  0.40104743  0.2943547 ]
#
# Analyze test bedroc:
# Top 5 rankings:  [8, 19, 9, 3, 16]
# ...

# %% [markdown]
# # Multi-task Classification

# %%
k = 3

# %%
check_result_completeness(dir_='../../output/grid_search/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [7, 3, 6, 5, 12]
# [ 0.25565117  0.21970194  0.20655338  0.20592277  0.19559863  0.18585657
#   0.1807768   0.17850125  0.17351712  0.16769529  0.16499066  0.16164689
#   0.16038191  0.15938983  0.1566469   0.15449598  0.13640286  0.13462076
#   0.13361788  0.12318653  0.07254784  0.05900161  0.01282096  0.00978457]
#
# Analyze val roc:
# Top 5 rankings:  [6, 3, 7, 9, 14]
# [ 0.94935177  0.94154003  0.9358486   0.91573583  0.90854295  0.90747759
#   0.90692651  0.89471257  0.88744363  0.88455606  0.88054546  0.87994777
#   0.87931205  0.86784699  0.86203595  0.86112576  0.86085651  0.85682997
#   0.84480432  0.83509003  0.83226869  0.83106073  0.80029587  0.78719996]
#
# Analyze val bedroc:
# Top 5 rankings:  [6, 3, 9, 7, 14]
# [ 0.8607047   0.8347095   0.80522878  0.78450671  0.76525124  0.75961472
#   0.75776286  0.75358533  0.75000657  0.745891    0.74581755  0.74489361
#   0.74365603  0.73984893  0.72918598  0.70410843  0.68574974  0.67669934
# ...

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [12, 20, 7, 6, 3]
# [ 0.05492193  0.03520862  0.03246217  0.03130421  0.03103107  0.03056002
#   0.02854981  0.0285401   0.02827527  0.02707542  0.02654805  0.0264624
#   0.02622479  0.02503145  0.02283552  0.02254167  0.02076122  0.01685586
#   0.01646102  0.01474316  0.01241484  0.00776671  0.00727075  0.00590113]
#
# Analyze test roc:
# Top 5 rankings:  [3, 2, 12, 9, 7]
# [ 0.85375163  0.85044706  0.83476563  0.82158841  0.81288117  0.81040677
#   0.805583    0.78963509  0.78271474  0.78138111  0.77564777  0.76626733
#   0.7642176   0.75823025  0.75408394  0.75122381  0.74105213  0.73309263
#   0.72355917  0.71960694  0.67716952  0.66008875  0.63345566  0.60739022]
#
# Analyze test bedroc:
# Top 5 rankings:  [7, 12, 2, 0, 6]
# [ 0.64889574  0.64562823  0.61686753  0.60059018  0.59989757  0.59141563
#   0.59062708  0.58278394  0.57190586  0.56058542  0.5428619   0.5379019
# ...

# %% [markdown]
# # Multi-task Classification 2

# %%
k = 3
file_paths[3] = 'multi_classification/45952844/'

# %%
check_result_completeness(dir_='../../output/grid_search/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
# %load_ext autoreload
# %autoreload 2
from virtual_screening.analysis.analysis import *

plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/grid_search/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1', 'EF_015', 'EF_01']

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [3, 18, 23, 19, 8]
# [ 0.26426657  0.22401042  0.20890031  0.20402895  0.20298642  0.19629904
#   0.1954359   0.18745889  0.17637844  0.17606402  0.17334667  0.17068157
#   0.16778159  0.15174669  0.15053744  0.14998973  0.1442269   0.12362153
#   0.12154396  0.11924294  0.11611568  0.05225721  0.01560132  0.01333012]
#
# Analyze val roc:
# Top 5 rankings:  [3, 7, 8, 6, 2]
# [ 0.94597321  0.94549819  0.94192337  0.93944274  0.93562933  0.93534229
#   0.92385638  0.91572602  0.91499983  0.91330549  0.90884747  0.90858128
#   0.90719545  0.88420308  0.87811635  0.87741868  0.87694335  0.8686569
#   0.86148548  0.8603729   0.85323614  0.83808034  0.82393838  0.81875785]
#
# Analyze val bedroc:
# Top 5 rankings:  [22, 7, 3, 5, 9]
# [ 0.83999701  0.83232141  0.8282682   0.82677177  0.82152549  0.8083181
#   0.80734091  0.80253535  0.79021512  0.75973149  0.75256546  0.74930911
#   0.74045665  0.73965506  0.73892468  0.71229373  0.71213588  0.70830345
# ...

# %%
get_ranked_analysis('../../output/grid_search/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=10)
# Out:
# Analyze test prec:
# Top 10 rankings:  [15, 6, 19, 12, 8, 3, 18, 4, 2, 22]
# [ 0.10174548  0.05033203  0.0469043   0.04125908  0.04113416  0.03957473
#   0.03805304  0.03606833  0.03206324  0.02630991  0.02601217  0.02353491
#   0.02352562  0.01919202  0.0183451   0.01806693  0.0147326   0.01442026
#   0.01280529  0.01201187  0.0084334   0.00697301  0.00548818  0.00536775]
#
# Analyze test roc:
# Top 10 rankings:  [18, 9, 2, 7, 8, 22, 0, 1, 20, 5]
# [ 0.86564876  0.85878986  0.85778903  0.84180309  0.83391599  0.80099377
#   0.7973777   0.79192879  0.7908008   0.7775022   0.77682748  0.77274414
#   0.77136366  0.76769618  0.7631179   0.7529085   0.74987467  0.74278275
#   0.73621042  0.7214632   0.71301879  0.69217836  0.68709784  0.66477046]
#
# Analyze test bedroc:
# Top 10 rankings:  [2, 18, 9, 7, 8, 22, 0, 6, 4, 1]
# [ 0.65509109  0.65339318  0.61364724  0.61085491  0.60601472  0.58497309
#   0.57624269  0.56888898  0.56809413  0.56798991  0.54790543  0.54745063
# ...

# %% [markdown]
# # Appendix
#
# All the corresponding hyperparamter sets are displayed [here](https://github.com/chao1224/virtual-screening/blob/6ff69e2f64f954c88d34c6a90a0569e5d50e7c8a/virtual_screening/analysis/Hyperparameter_Set_Display.ipynb).
