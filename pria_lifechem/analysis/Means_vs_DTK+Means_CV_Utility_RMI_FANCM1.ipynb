# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib
import os
from IPython.display import display
matplotlib.use('Agg')
# %matplotlib inline
import pandas as pd
pd.set_option('precision', 4)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

from gather_metrics import *
def get_ranked_by_means_df(gather_df, metric_list):
    means_df = gather_df.xs(['test_metrics', 'Folds Mean'], level=['set','fold'])
    ranked_df = pd.DataFrame(data=np.zeros(shape=means_df.shape), columns=metric_list, dtype=str)
    for m, i in zip(metric_list, range(len(metric_list))):
        metric_df = means_df[m]
        sorted_df = metric_df.sort_values(ascending=False)
        mscore_list = sorted_df.tolist()
        models_ranked = sorted_df.index.tolist()
        m_order_mscore_list = [str(m) + ", " + str(round(r,4)) for m, r in zip(models_ranked, mscore_list)]
        ranked_df.iloc[:,i] = m_order_mscore_list
    return ranked_df

# %%
# load stage CV
model_directory = '../../../job_results_small/'
class_dirs = [model_directory+'/random_forest/stage_1/',
              model_directory+'/irv/stage_1/',
              model_directory+'/neural_networks/stage_1/',
              model_directory+'/docking/stage_1/']
k = 5
gather_df_2 = gather_dir_metrics(class_dirs[0], k)     
gather_df_2 = gather_df_2.append(gather_dir_metrics(class_dirs[1], k))   
gather_df_2 = gather_df_2.append(gather_dir_metrics(class_dirs[2], 20))
gather_df_2 = gather_df_2.append(gather_dir_metrics(class_dirs[3], k))

col_indices = list(range(10)) + list(range(15, 20)) + list(range(25, 105)) + list(range(145, 149)) + list(range(150, 183))
col_indices = [i for i in col_indices if 'Mean' not in gather_df_2.columns[i] and 'Median' not in gather_df_2.columns[i]]
col_indices = [i for i in col_indices if 'RMI-FANCM FP' in gather_df_2.columns[i]]
metric_names = list(gather_df_2.columns.values[col_indices])

gather_df_2 = gather_df_2[metric_names]
gather_df_2 = gather_df_2.dropna(axis=0)

gather_df_cv = gather_df_2

#setup comparison matrix and overlaps
dtk_dict = dtk_multi_metrics(gather_df_cv, list(range(len(col_indices))))
dtk_analysis_dict = analyze_dtk_dict(dtk_dict)
mm_comp_dicts = get_mean_median_comps(gather_df_cv, list(range(len(col_indices))))
agg_comp_dict = get_agg_comp(mm_comp_dicts, dtk_analysis_dict, mean_w=1, median_w=0, tukey_w=1)

# %% [markdown]
# ---
# ## Compute Best Models for Each Metric Based on Mean VS DTK+Mean

# %%
simple_ranked_cv = get_ranked_by_means_df(gather_df_cv, metric_names)
complex_ranked_cv = get_model_ordering(agg_comp_dict, metric_names)

top_n = 1
req_metrics = ['ROC AUC RMI-FANCM FP', 'BEDROC AUC RMI-FANCM FP','PR auc.integral RMI-FANCM FP', 
               'NEF AUC RMI-FANCM FP', 'NEF_1 % RMI-FANCM FP', 'EF_1 % RMI-FANCM FP']

simple_top_n = simple_ranked_cv[req_metrics].iloc[:top_n,:]
complex_top_n = complex_ranked_cv[req_metrics].iloc[:top_n,:]

# %% [markdown]
# ### Ranking by Folds Mean Only

# %%
display('Ranking by Means. Shows model-mean pairs.', simple_ranked_cv[req_metrics])
# Out:
# 'Ranking by Means. Shows model-mean pairs.'
#                    ROC AUC RMI-FANCM FP              BEDROC AUC RMI-FANCM FP         PR auc.integral RMI-FANCM FP                NEF AUC RMI-FANCM FP                NEF_1 % RMI-FANCM FP                  EF_1 % RMI-FANCM FP
# 0                RandomForest_h, 0.8346               RandomForest_h, 0.5114               RandomForest_h, 0.1237              RandomForest_h, 0.5439              RandomForest_h, 0.2782              RandomForest_h, 27.8179
# 1                RandomForest_g, 0.8306               RandomForest_g, 0.5045               RandomForest_g, 0.1225              RandomForest_g, 0.5324              RandomForest_g, 0.2738              RandomForest_g, 27.3831
# 2                RandomForest_e, 0.8256               RandomForest_e, 0.5001               RandomForest_e, 0.1224               RandomForest_e, 0.527              RandomForest_d, 0.2608              RandomForest_d, 26.0783
# 3                RandomForest_d, 0.8225               RandomForest_d, 0.4967               RandomForest_b, 0.1219              RandomForest_b, 0.5241              RandomForest_e, 0.2563              RandomForest_e, 25.6339
# 4                RandomForest_f, 0.8207               RandomForest_b, 0.4908               RandomForest_a, 0.1218              RandomForest_d, 0.5237              RandomForest_a, 0.2474              RandomForest_a, 24.7357
# 5                RandomForest_c, 0.8161               RandomForest_a, 0.4898               RandomForest_d, 0.1213              RandomForest_a, 0.5234              RandomForest_b, 0.2474              RandomForest_b, 24.7357
# 6                RandomForest_b, 0.8159               RandomForest_c, 0.4897               RandomForest_c, 0.1208              RandomForest_c, 0.5222              RandomForest_c, 0.2474              RandomForest_c, 24.7357
# 7                RandomForest_a, 0.8157               RandomForest_f, 0.4637                        IRV_d, 0.0841              RandomForest_f, 0.4903              RandomForest_f, 0.2431              RandomForest_f, 24.3098
# 8         MultiClassification_b, 0.7532                        IRV_e, 0.4356       SingleClassification_b, 0.0824                       IRV_e, 0.4554                       IRV_d, 0.2343                        IRV_d, 23.431
# 9                         IRV_e, 0.7463                        IRV_d, 0.4324                        IRV_e, 0.0752                       IRV_d, 0.4459                       IRV_b, 0.2123                       IRV_b, 21.2277
# 10        MultiClassification_a, 0.7259                        IRV_c, 0.3931                        IRV_a, 0.0745                       IRV_c, 0.3784                       IRV_c, 0.2123                       IRV_c, 21.2277
# 11                        IRV_d, 0.7189                        IRV_b, 0.3727       SingleClassification_a, 0.0724       MultiClassification_b, 0.3768                       IRV_e, 0.2083                       IRV_e, 20.8307
# 12                        IRV_c, 0.6854        MultiClassification_b, 0.3582                        IRV_c, 0.0716      SingleClassification_a, 0.3565                       IRV_a, 0.2081                       IRV_a, 20.8114
# 13                        IRV_b, 0.6649       SingleClassification_a, 0.3393               RandomForest_f, 0.0681      SingleClassification_b, 0.3513      SingleClassification_b, 0.2031      SingleClassification_b, 20.3147
# 14       SingleClassification_b, 0.6623       SingleClassification_b, 0.3373                        IRV_b, 0.0678                       IRV_b, 0.3429      SingleClassification_a, 0.1911       SingleClassification_a, 19.105
# 15       SingleClassification_a, 0.6366                        IRV_a, 0.3288        MultiClassification_a, 0.0442       MultiClassification_a, 0.3337       MultiClassification_b, 0.1412        MultiClassification_b, 14.117
# 16                        IRV_a, 0.6339        MultiClassification_a, 0.3177        MultiClassification_b, 0.0405                       IRV_a, 0.2821          SingleRegression_b, 0.1249          SingleRegression_b, 12.4906
# 17                  Docking_ad4, 0.5753              Docking_rdocktot, 0.169           SingleRegression_b, 0.0398                  Docking_ad4, 0.177       MultiClassification_a, 0.1249        MultiClassification_a, 12.486
# 18             Docking_rdocktot, 0.5603           SingleRegression_b, 0.1684                  Docking_ad4, 0.0117            Docking_rdocktot, 0.1733            Docking_rdockint, 0.0393             Docking_rdockint, 3.9336
# 19                       LSTM_a, 0.5576                  Docking_ad4, 0.1651             Docking_rdocktot, 0.0114          SingleRegression_b, 0.1729     ConsensusDocking_median, 0.0391      ConsensusDocking_median, 3.9054
# 20                Docking_smina, 0.5478                Docking_smina, 0.1491                Docking_smina, 0.0109               Docking_smina, 0.1569            Docking_rdocktot, 0.0303             Docking_rdocktot, 3.0258
# 21         ConsensusDocking_max, 0.5229             Docking_rdockint, 0.1442      ConsensusDocking_median, 0.0103            Docking_rdockint, 0.1492        ConsensusDocking_max, 0.0218          ConsensusDocking_max, 2.184
# 22              Docking_rdockint, 0.522                       LSTM_a, 0.1338  ConsensusDocking_rocauc_opt, 0.0102                      LSTM_a, 0.1376                 Docking_ad4, 0.0217                  Docking_ad4, 2.1747
# 23                       LSTM_b, 0.5197         ConsensusDocking_max, 0.1254    ConsensusDocking_efr1_opt, 0.0098        ConsensusDocking_max, 0.1298       ConsensusDocking_mean, 0.0174          ConsensusDocking_mean, 1.74
# 24       ConsensusDocking_median, 0.511      ConsensusDocking_median, 0.1216         ConsensusDocking_max, 0.0092     ConsensusDocking_median, 0.1231    ConsensusDocking_efr1_opt, 0.017    ConsensusDocking_efr1_opt, 1.7021
# 25               Docking_hybrid, 0.4964               Docking_hybrid, 0.1192             Docking_rdockint, 0.0073              Docking_hybrid, 0.1227  ConsensusDocking_rocauc_opt, 0.017  ConsensusDocking_rocauc_opt, 1.7021
# 26        ConsensusDocking_mean, 0.4878                       LSTM_b, 0.1172        ConsensusDocking_mean, 0.0068                      LSTM_b, 0.1187                Docking_fred, 0.0133                 Docking_fred, 1.3333
# 27               Docking_plants, 0.4821        ConsensusDocking_mean, 0.1032                       LSTM_a, 0.0061       ConsensusDocking_mean, 0.1013                Docking_dock6, 0.013                Docking_dock6, 1.3043
# 28  ConsensusDocking_rocauc_opt, 0.4788    ConsensusDocking_efr1_opt, 0.0934                       LSTM_b, 0.0055   ConsensusDocking_efr1_opt, 0.0928                Docking_smina, 0.013                Docking_smina, 1.2955
# 29    ConsensusDocking_efr1_opt, 0.4756  ConsensusDocking_rocauc_opt, 0.0899                Docking_hybrid, 0.005  ConsensusDocking_rocauc_opt, 0.085              Docking_plants, 0.0128               Docking_plants, 1.2766
# 30           SingleRegression_b, 0.4634               Docking_plants, 0.0832               Docking_plants, 0.0047              Docking_plants, 0.0827                      LSTM_b, 0.0119                       LSTM_b, 1.1914
# 31                 Docking_fred, 0.4516                 Docking_fred, 0.0814                 Docking_fred, 0.0044                 Docking_fred, 0.078                      LSTM_a, 0.0109                       LSTM_a, 1.0922
# 32                Docking_dock6, 0.4376                Docking_dock6, 0.0669                Docking_dock6, 0.0042                Docking_dock6, 0.064              Docking_hybrid, 0.0088               Docking_hybrid, 0.8792
# 33              Docking_surflex, 0.4196               Docking_surflex, 0.063              Docking_surflex, 0.0039             Docking_surflex, 0.0563          SingleRegression_a, 0.0065           SingleRegression_a, 0.6548
# 34           SingleRegression_a, 0.3876           SingleRegression_a, 0.0541           SingleRegression_a, 0.0036          SingleRegression_a, 0.0523             Docking_surflex, 0.0043              Docking_surflex, 0.4255

# %% [markdown]
# ### Ranking by DTK+Means

# %%
display('Ranking by DTK+Means. Shows model-rank pairs.', complex_ranked_cv[req_metrics])
# Out:
# 'Ranking by DTK+Means. Shows model-rank pairs.'
#                  ROC AUC RMI-FANCM FP            BEDROC AUC RMI-FANCM FP       PR auc.integral RMI-FANCM FP               NEF AUC RMI-FANCM FP               NEF_1 % RMI-FANCM FP                EF_1 % RMI-FANCM FP
# 0                 RandomForest_h, 1.0                RandomForest_h, 1.0        SingleClassification_b, 1.0                RandomForest_h, 1.0                RandomForest_h, 1.0                RandomForest_h, 1.0
# 1                 RandomForest_g, 2.0                RandomForest_g, 2.0        SingleClassification_a, 2.0                RandomForest_g, 2.0                RandomForest_g, 2.0                RandomForest_g, 2.0
# 2                 RandomForest_e, 3.0                RandomForest_e, 3.0                RandomForest_h, 2.0                RandomForest_e, 3.0                RandomForest_d, 3.0                RandomForest_d, 3.0
# 3                 RandomForest_d, 4.0                RandomForest_d, 4.0                RandomForest_g, 4.0                RandomForest_b, 4.0                RandomForest_e, 4.0                RandomForest_e, 4.0
# 4                 RandomForest_c, 5.0                RandomForest_b, 5.0                RandomForest_e, 5.0                RandomForest_d, 5.0                RandomForest_f, 5.0                RandomForest_f, 5.0
# 5                 RandomForest_f, 6.0                RandomForest_c, 6.0                RandomForest_b, 6.0                RandomForest_a, 6.0                         IRV_d, 6.0                         IRV_d, 6.0
# 6                 RandomForest_b, 6.0                RandomForest_a, 6.0                RandomForest_a, 7.0                RandomForest_c, 7.0                         IRV_a, 7.0                         IRV_a, 7.0
# 7                 RandomForest_a, 8.0                RandomForest_f, 8.0                RandomForest_d, 8.0                RandomForest_f, 8.0        SingleClassification_b, 8.0        SingleClassification_b, 8.0
# 8          MultiClassification_b, 9.0                         IRV_d, 9.0                RandomForest_c, 9.0                         IRV_d, 9.0        SingleClassification_a, 9.0        SingleClassification_a, 9.0
# 9                         IRV_e, 10.0                        IRV_e, 10.0         MultiClassification_b, 9.0        MultiClassification_b, 10.0               RandomForest_c, 10.0               RandomForest_c, 10.0
# 10        MultiClassification_a, 11.0        MultiClassification_b, 11.0                        IRV_d, 11.0                        IRV_e, 10.0               RandomForest_b, 10.0               RandomForest_b, 10.0
# 11                        IRV_d, 12.0       SingleClassification_a, 12.0                        IRV_e, 12.0       SingleClassification_a, 12.0               RandomForest_a, 10.0               RandomForest_a, 10.0
# 12       SingleClassification_b, 13.0       SingleClassification_b, 13.0                        IRV_a, 13.0       SingleClassification_b, 13.0        MultiClassification_b, 13.0        MultiClassification_b, 13.0
# 13                        IRV_c, 14.0                        IRV_b, 14.0                        IRV_c, 14.0        MultiClassification_a, 14.0           SingleRegression_b, 14.0           SingleRegression_b, 14.0
# 14                        IRV_b, 15.0        MultiClassification_a, 15.0               RandomForest_f, 15.0                        IRV_c, 15.0                        IRV_c, 15.0                        IRV_c, 15.0
# 15       SingleClassification_a, 16.0                        IRV_c, 16.0                        IRV_b, 16.0                        IRV_b, 16.0                        IRV_b, 15.0                        IRV_b, 15.0
# 16                        IRV_a, 16.0                        IRV_a, 17.0           SingleRegression_b, 17.0                        IRV_a, 17.0                        IRV_e, 17.0                        IRV_e, 17.0
# 17                       LSTM_a, 18.0             Docking_rdocktot, 18.0        MultiClassification_a, 17.0             Docking_rdocktot, 18.0        MultiClassification_a, 18.0        MultiClassification_a, 18.0
# 18                  Docking_ad4, 19.0           SingleRegression_b, 18.0                  Docking_ad4, 19.0                  Docking_ad4, 19.0             Docking_rdockint, 19.0             Docking_rdockint, 19.0
# 19             Docking_rdocktot, 20.0                Docking_smina, 20.0             Docking_rdocktot, 20.0           SingleRegression_b, 19.0      ConsensusDocking_median, 20.0      ConsensusDocking_median, 20.0
# 20                Docking_smina, 21.0                  Docking_ad4, 20.0                Docking_smina, 21.0                Docking_smina, 21.0             Docking_rdocktot, 21.0             Docking_rdocktot, 21.0
# 21         ConsensusDocking_max, 22.0                       LSTM_a, 22.0      ConsensusDocking_median, 22.0                       LSTM_a, 22.0         ConsensusDocking_max, 22.0         ConsensusDocking_max, 22.0
# 22             Docking_rdockint, 23.0             Docking_rdockint, 22.0  ConsensusDocking_rocauc_opt, 23.0             Docking_rdockint, 22.0                  Docking_ad4, 23.0                  Docking_ad4, 23.0
# 23                       LSTM_b, 23.0         ConsensusDocking_max, 24.0    ConsensusDocking_efr1_opt, 24.0         ConsensusDocking_max, 24.0        ConsensusDocking_mean, 24.0        ConsensusDocking_mean, 24.0
# 24      ConsensusDocking_median, 25.0      ConsensusDocking_median, 25.0         ConsensusDocking_max, 25.0      ConsensusDocking_median, 25.0  ConsensusDocking_rocauc_opt, 25.0  ConsensusDocking_rocauc_opt, 25.0
# 25               Docking_hybrid, 26.0                       LSTM_b, 26.0             Docking_rdockint, 26.0               Docking_hybrid, 26.0    ConsensusDocking_efr1_opt, 25.0    ConsensusDocking_efr1_opt, 25.0
# 26        ConsensusDocking_mean, 27.0               Docking_hybrid, 26.0        ConsensusDocking_mean, 27.0                       LSTM_b, 26.0                 Docking_fred, 27.0                 Docking_fred, 27.0
# 27               Docking_plants, 28.0        ConsensusDocking_mean, 28.0                       LSTM_a, 28.0        ConsensusDocking_mean, 28.0                Docking_dock6, 28.0                Docking_dock6, 28.0
# 28  ConsensusDocking_rocauc_opt, 29.0    ConsensusDocking_efr1_opt, 29.0                       LSTM_b, 29.0    ConsensusDocking_efr1_opt, 29.0                Docking_smina, 29.0                Docking_smina, 29.0
# 29           SingleRegression_b, 30.0  ConsensusDocking_rocauc_opt, 30.0               Docking_hybrid, 30.0  ConsensusDocking_rocauc_opt, 30.0               Docking_plants, 30.0               Docking_plants, 30.0
# 30    ConsensusDocking_efr1_opt, 30.0               Docking_plants, 31.0               Docking_plants, 31.0               Docking_plants, 31.0                       LSTM_b, 31.0                       LSTM_b, 31.0
# 31                 Docking_fred, 32.0                 Docking_fred, 32.0                 Docking_fred, 32.0                 Docking_fred, 32.0                       LSTM_a, 32.0                       LSTM_a, 32.0
# 32                Docking_dock6, 33.0                Docking_dock6, 33.0                Docking_dock6, 33.0                Docking_dock6, 33.0               Docking_hybrid, 33.0               Docking_hybrid, 33.0
# 33              Docking_surflex, 34.0              Docking_surflex, 34.0              Docking_surflex, 34.0              Docking_surflex, 34.0           SingleRegression_a, 34.0           SingleRegression_a, 34.0
# 34           SingleRegression_a, 35.0           SingleRegression_a, 35.0           SingleRegression_a, 35.0           SingleRegression_a, 35.0              Docking_surflex, 35.0              Docking_surflex, 35.0

# %% [markdown]
# ---
# ## Regret of best model

# %%
for m in req_metrics:
    simple_model = simple_top_n[m].iloc[0]
    simple_model = simple_model[:simple_model.index(',')]
    simple_top_n[m].iloc[0] = simple_model
    complex_model = complex_top_n[m].iloc[0]
    complex_model = complex_model[:complex_model.index(',')]
    complex_top_n[m].iloc[0] = complex_model

# %%
final_df = simple_top_n.T
final_df = pd.merge(final_df, complex_top_n.T, left_index=True, right_index=True)
final_df.columns = ['Best by Mean','Best by DTK+Mean']
final_df.columns.name = 'Metric'
final_df.index = [s.replace(' RMI-FANCM FP', '') for s in final_df.index]

display(final_df)
# Out:
# Metric             Best by Mean        Best by DTK+Mean
# ROC AUC          RandomForest_h          RandomForest_h
# BEDROC AUC       RandomForest_h          RandomForest_h
# PR auc.integral  RandomForest_h  SingleClassification_b
# NEF AUC          RandomForest_h          RandomForest_h
# NEF_1 %          RandomForest_h          RandomForest_h
# EF_1 %           RandomForest_h          RandomForest_h
