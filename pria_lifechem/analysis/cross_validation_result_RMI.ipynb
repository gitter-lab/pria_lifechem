# %%
from analysis import *
from docking_analysis import *
from IPython.display import Markdown

task_name = 'Keck_RMI'

file_paths = {0: 'single_classification_22/46244865/',
              1: 'single_classification_42/46101892/', 
              2: 'single_regression_2/46245031/',
              3: 'single_regression_11/46245032/',
              4: 'vanilla_lstm_8/46680983/',
              5: 'vanilla_lstm_19/46680994/',
              6: 'multi_classification_15/eval_keck/',
              7: 'multi_classification_18/eval_keck/',
              8: 'sklearn_rf_390014_96/',
              9: 'sklearn_rf_390014_97/'}

file_paths = {0: 'single_classification_22/46244865/',
              1: 'single_regression_2/46245031/',
              2: 'vanilla_lstm_19/46680994/',
              3: 'multi_classification_15/eval_keck/',
              4: 'random_forest_97/',
              5: 'irv_80/'}

number = 20

evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01',
               13: 'NEF_2', 14: 'NEF_1', 15: 'NEF_015', 16:'NEF_01'}

paths = ['../../output/stage_1/cross_validation_RMI/{}'.format(p) for p in file_paths.values()]
model_list = ['single_classification',
              'single_regression',
              'vanilla_lstm',
              'multi_classification',
              'random_forest',
              'irv']
# Out:
# Note: no visible global function definition for 'radixsort'
# /home/sliu/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
for k in range(len(file_paths)):
    print 'Check ', file_paths[k]
    check_result_completeness(file_path=paths[k], number=number)
    print
# Out:
# Check  single_classification_22/46244865/
# All output result complete.
#
# Check  single_regression_2/46245031/
# All output result complete.
#
# Check  vanilla_lstm_19/46680994/
# All output result complete.
#
# Check  multi_classification_15/eval_keck/
# All output result complete.
#
# Check  random_forest_97/
# All output result complete.
#
# Check  irv_80/
# All output result complete.

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                      model_list=model_list,
                      title='AUC[PR]',
                      task_name=task_name)

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[PR]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | STNN-C | 0.933 | 0.111 | 0.073 |
# | STNN-R | 0.007 | 0.004 | 0.004 |
# | LSTM | 0.006 | 0.007 | 0.005 |
# | MTNN-C | 0.640 | 0.053 | 0.044 |
# | RF | 1.000 | 0.000 | 0.124 |
# | IRV | 0.055 | 0.089 | 0.075 |
#
# ## Model comparison
# ### median of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | STNN-C | 0.997 | 0.120 | 0.068 |
# | STNN-R | 0.005 | 0.004 | 0.004 |
# | LSTM | 0.006 | 0.007 | 0.005 |
# | MTNN-C | 0.752 | 0.051 | 0.034 |
# | RF | 1.000 | 0.000 | 0.110 |
# | IRV | 0.054 | 0.082 | 0.045 |
#
# ## Model comparison
# ### std of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | STNN-C | 0.135 | 0.035 | 0.035 |
# | STNN-R | 0.005 | 0.000 | 0.000 |
# | LSTM | 0.001 | 0.002 | 0.002 |
# | MTNN-C | 0.347 | 0.028 | 0.032 |
# | RF | 0.000 | 0.000 | 0.051 |
# | IRV | 0.012 | 0.042 | 0.044 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                      model_list=model_list,
                      title='AUC[ROC]',
                      task_name=task_name)

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | STNN-C | 0.997 | 0.648 | 0.637 |
# | STNN-R | 0.486 | 0.389 | 0.388 |
# | LSTM | 0.540 | 0.577 | 0.520 |
# | MTNN-C | 0.919 | 0.730 | 0.726 |
# | RF | 1.000 | 0.000 | 0.835 |
# | IRV | 0.727 | 0.736 | 0.746 |
#
# ## Model comparison
# ### median of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | STNN-C | 1.000 | 0.613 | 0.640 |
# | STNN-R | 0.490 | 0.383 | 0.382 |
# | LSTM | 0.532 | 0.570 | 0.528 |
# | MTNN-C | 0.996 | 0.752 | 0.742 |
# | RF | 1.000 | 0.000 | 0.842 |
# | IRV | 0.729 | 0.743 | 0.751 |
#
# ## Model comparison
# ### std of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | STNN-C | 0.008 | 0.092 | 0.079 |
# | STNN-R | 0.019 | 0.029 | 0.029 |
# | LSTM | 0.047 | 0.047 | 0.058 |
# | MTNN-C | 0.161 | 0.078 | 0.080 |
# | RF | 0.000 | 0.000 | 0.036 |
# | IRV | 0.015 | 0.036 | 0.039 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                      model_list=model_list,
                      title='AUC[BED ROC]',
                      task_name=task_name)

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[BED ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | STNN-C | 0.965 | 0.344 | 0.339 |
# | STNN-R | 0.091 | 0.055 | 0.054 |
# | LSTM | 0.130 | 0.152 | 0.117 |
# | MTNN-C | 0.795 | 0.339 | 0.318 |
# | RF | 0.977 | 0.000 | 0.511 |
# | IRV | 0.416 | 0.428 | 0.436 |
#
# ## Model comparison
# ### median of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | STNN-C | 0.977 | 0.323 | 0.329 |
# | STNN-R | 0.094 | 0.049 | 0.049 |
# | LSTM | 0.130 | 0.153 | 0.112 |
# | MTNN-C | 0.942 | 0.361 | 0.338 |
# | RF | 0.977 | 0.000 | 0.481 |
# | IRV | 0.417 | 0.410 | 0.420 |
#
# ## Model comparison
# ### std of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | STNN-C | 0.033 | 0.084 | 0.065 |
# | STNN-R | 0.018 | 0.015 | 0.015 |
# | LSTM | 0.037 | 0.049 | 0.036 |
# | MTNN-C | 0.320 | 0.081 | 0.082 |
# | RF | 0.000 | 0.000 | 0.058 |
# | IRV | 0.018 | 0.070 | 0.072 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                      model_list=model_list,
                      title='Enrichment Factor on Test Set',
                      task_name=task_name)

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='Enrichment Factor (Test-set)')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | STNN-C | 11.998 | 19.105 | 51.440 | 54.278 |
# | STNN-R | 0.652 | 0.655 | 0.709 | 0.000 |
# | LSTM | 1.032 | 1.191 | 2.159 | 1.111 |
# | MTNN-C | 8.250 | 12.486 | 31.913 | 34.916 |
# | RF | 16.935 | 27.818 | 63.860 | 78.298 |
# | IRV | 15.644 | 20.831 | 49.295 | 47.939 |
#
# ## Model comparison
# ### median of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | STNN-C | 11.962 | 20.000 | 50.591 | 63.830 |
# | STNN-R | 0.000 | 0.000 | 0.000 | 0.000 |
# | LSTM | 1.099 | 0.000 | 0.000 | 0.000 |
# | MTNN-C | 8.696 | 11.111 | 35.769 | 21.981 |
# | RF | 15.556 | 26.087 | 74.074 | 88.889 |
# | IRV | 14.444 | 17.778 | 43.478 | 43.478 |
#
# ## Model comparison
# ### std of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | STNN-C | 3.016 | 5.657 | 30.270 | 35.995 |
# | STNN-R | 0.890 | 1.254 | 3.172 | 0.000 |
# | LSTM | 0.892 | 1.642 | 5.275 | 4.969 |
# | MTNN-C | 3.421 | 5.932 | 23.927 | 31.495 |
# | RF | 2.840 | 5.386 | 27.796 | 45.804 |
# | IRV | 3.310 | 6.158 | 20.210 | 35.652 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[13], evaluations[14], evaluations[15], evaluations[16]],
                      model_list=model_list,
                      title='Normalized Enrichment Factor on Test Set',
                      task_name=task_name)

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[13], evaluations[14], evaluations[15], evaluations[16]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='Normalized Enrichment Factor (Test-set)')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of Normalized Enrichment Factor (Test-set)
# | model | NEF_2 | NEF_1 | NEF_015 | NEF_01 |
# | --- | --- | --- | --- | --- |
# | STNN-C | 0.240 | 0.191 | 0.254 | 0.278 |
# | STNN-R | 0.013 | 0.007 | 0.004 | 0.000 |
# | LSTM | 0.021 | 0.012 | 0.011 | 0.006 |
# | MTNN-C | 0.165 | 0.125 | 0.157 | 0.178 |
# | RF | 0.339 | 0.278 | 0.314 | 0.400 |
# | IRV | 0.313 | 0.208 | 0.243 | 0.244 |
#
# ## Model comparison
# ### median of Normalized Enrichment Factor (Test-set)
# | model | NEF_2 | NEF_1 | NEF_015 | NEF_01 |
# | --- | --- | --- | --- | --- |
# | STNN-C | 0.239 | 0.200 | 0.250 | 0.333 |
# | STNN-R | 0.000 | 0.000 | 0.000 | 0.000 |
# | LSTM | 0.022 | 0.000 | 0.000 | 0.000 |
# | MTNN-C | 0.174 | 0.111 | 0.179 | 0.111 |
# | RF | 0.311 | 0.261 | 0.357 | 0.444 |
# | IRV | 0.289 | 0.178 | 0.214 | 0.222 |
#
# ## Model comparison
# ### std of Normalized Enrichment Factor (Test-set)
# | model | NEF_2 | NEF_1 | NEF_015 | NEF_01 |
# | --- | --- | --- | --- | --- |
# | STNN-C | 0.060 | 0.057 | 0.149 | 0.186 |
# | STNN-R | 0.018 | 0.013 | 0.016 | 0.000 |
# | LSTM | 0.018 | 0.016 | 0.026 | 0.025 |
# | MTNN-C | 0.068 | 0.059 | 0.117 | 0.159 |
# | RF | 0.057 | 0.054 | 0.136 | 0.235 |
# | IRV | 0.066 | 0.062 | 0.099 | 0.182 |

# %% [markdown]
# # Docking Results

# %%
content = get_auc_table(file_path='../../output/docking/stage_1/lc123_rmi_all_docking_scores.csv',
                        target_name='Keck_RMI_cdd',
                        auc_list=['precision_auc_single', 'roc_auc_single', 'bedroc_auc_single'],
                        auc_header=['AUC[PR]', 'AUC[ROC]', 'AUC[BED ROC]'],
                        title='AUC for Docking Methods')
Markdown(content)
# Out:
# ## AUC for Docking Methods
# | docking method | AUC[PR] | AUC[ROC] | AUC[BED ROC] |
# | --- | --- | --- | --- |
# | consensus_bcs_efr1_opt | 0.004717 | 0.478746 | 0.089088 |
# | consensus_bcs_rocauc_opt | 0.004670 | 0.480623 | 0.084198 |
# | consensus_dockscore_max | 0.008438 | 0.549098 | 0.151286 |
# | consensus_dockscore_mean | 0.005138 | 0.499520 | 0.106350 |
# | consensus_dockscore_median | 0.004947 | 0.495799 | 0.100859 |
# | dockscore_ad4 | 0.007137 | 0.545203 | 0.147147 |
# | dockscore_dock6 | 0.004384 | 0.426895 | 0.059025 |
# | dockscore_fred | 0.004312 | 0.477780 | 0.088328 |
# | dockscore_hybrid | 0.006733 | 0.573188 | 0.155289 |
# | dockscore_plants | 0.004411 | 0.486771 | 0.095651 |
# | dockscore_rdockint | 0.004707 | 0.500415 | 0.106783 |
# | dockscore_rdocktot | 0.011470 | 0.555950 | 0.165897 |
# | dockscore_smina | 0.007661 | 0.536561 | 0.138841 |
# | dockscore_surflex | 0.003717 | 0.406184 | 0.069794 |

# %%
EF_ratio_list = [0.02, 0.01, 0.0015, 0.001]
content = get_ef_table(file_path='../../output/docking/stage_1/lc123_rmi_all_docking_scores.csv',
                       target_name='Keck_RMI_cdd',
                       efr_list=EF_ratio_list,
                       ef_header=['EF_2', 'EF_1', 'EF_015', 'EF_01'],
                       title='Enrichment Factor for Docking Methods')
Markdown(content)
# Out:
# ## Enrichment Factor for Docking Methods
# | docking method | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | consensus_bcs_efr1_opt | 1.46341463415 | 1.46341463415 | 3.25203252033 | 4.87804878049 |
# | consensus_bcs_rocauc_opt | 1.46341463415 | 1.46341463415 | 3.25203252033 | 4.87804878049 |
# | consensus_dockscore_max | 3.17073170732 | 3.41463414634 | 9.75609756098 | 9.75609756098 |
# | consensus_dockscore_mean | 2.68292682927 | 2.92682926829 | 3.25203252033 | 4.87804878049 |
# | consensus_dockscore_median | 2.19512195122 | 1.9512195122 | 6.50406504065 | 4.87804878049 |
# | dockscore_ad4 | 2.43902439024 | 3.90243902439 | 13.0081300813 | 9.75609756098 |
# | dockscore_dock6 | 1.22549019608 | 1.96078431373 | 9.80392156863 | 14.7058823529 |
# | dockscore_fred | 0.975609756098 | 0.487804878049 | 0.0 | 0.0 |
# | dockscore_hybrid | 2.19512195122 | 2.43902439024 | 3.25203252033 | 4.87804878049 |
# | dockscore_plants | 0.731707317073 | 1.46341463415 | 0.0 | 0.0 |
# | dockscore_rdockint | 1.21951219512 | 0.975609756098 | 0.0 | 0.0 |
# | dockscore_rdocktot | 3.17073170732 | 2.92682926829 | 3.25203252033 | 4.87804878049 |
# | dockscore_smina | 2.19512195122 | 3.41463414634 | 9.75609756098 | 14.6341463415 |
# | dockscore_surflex | 0.731707317073 | 0.975609756098 | 3.25203252033 | 0.0 |

# %%
EF_ratio_list = [0.02, 0.01, 0.0015, 0.001]
content = get_nef_table(file_path='../../output/docking/stage_1/lc123_all_docking_scores.csv',
                        target_name='Keck_RMI_cdd',
                        nefr_list=EF_ratio_list,
                        nef_header=['NEF_2', 'NEF_1', 'NEF_015', 'NEF_01'],
                        title='Normalized Enrichment Factor for Docking Methods')
Markdown(content)
# Out:
# ## Normalized Enrichment Factor for Docking Methods
# | docking method | 0.02 | 0.01 | 0.0015 | 0.001 |
# | --- | --- | --- | --- | --- |
# | consensus_bcs_efr1_opt | 0.0292682926829 | 0.019512195122 | 0.0149253731343 | 0.0227272727273 |
# | consensus_bcs_rocauc_opt | 0.0292682926829 | 0.019512195122 | 0.0298507462687 | 0.0227272727273 |
# | consensus_dockscore_max | 0.0390243902439 | 0.0292682926829 | 0.044776119403 | 0.0681818181818 |
# | consensus_dockscore_mean | 0.0390243902439 | 0.019512195122 | 0.0298507462687 | 0.0454545454545 |
# | consensus_dockscore_median | 0.0341463414634 | 0.0292682926829 | 0.0149253731343 | 0.0227272727273 |
# | dockscore_ad4 | 0.0390243902439 | 0.0146341463415 | 0.0298507462687 | 0.0454545454545 |
# | dockscore_dock6 | 0.0196078431373 | 0.0147058823529 | 0.0151515151515 | 0.0 |
# | dockscore_fred | 0.0146341463415 | 0.00975609756098 | 0.0 | 0.0 |
# | dockscore_hybrid | 0.0439024390244 | 0.0341463414634 | 0.0149253731343 | 0.0 |
# | dockscore_plants | 0.0243902439024 | 0.0146341463415 | 0.0 | 0.0 |
# | dockscore_rdockint | 0.0341463414634 | 0.019512195122 | 0.0298507462687 | 0.0454545454545 |
# | dockscore_rdocktot | 0.0536585365854 | 0.0292682926829 | 0.0298507462687 | 0.0227272727273 |
# | dockscore_smina | 0.0390243902439 | 0.00975609756098 | 0.0298507462687 | 0.0454545454545 |
# | dockscore_surflex | 0.0146341463415 | 0.00487804878049 | 0.0 | 0.0 |

# %% [markdown]
# # Plot EF Curve

# %%
from EF_curve_support_loader import *

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 30.0)
# Out:
# Using Theano backend.

# %%
predictions_path = '../../output/stage_1_predictions/cross_validation_RMI'

model_names_list = ['single_classification_22',
                    'single_regression_2',
                    'multi_classification_15',
                    'sklearn_rf_390014_97',
                    'deepchem_irv_80']

# %%
EF_ratio_list = np.linspace(0.001, 0.15, 100)
N = len(model_names_list)
data_set_name = 'Keck_RMI'

data_pd_list = []
for i in range(N):
    temp_pd = get_EF_curve_in_pd(EF_ratio_list=EF_ratio_list,
                                 data_set_name=data_set_name,
                                 model_name=model_names_list[i],
                                 predictions_path=predictions_path,
                                 regenerate=True)
    data_pd_list.append(temp_pd)
    
whole_pd = data_pd_list[0]
for i in range(1, N):
    whole_pd = whole_pd.append(data_pd_list[i])
# Out:
# running single_classification_22
# running single_regression_2
# running multi_classification_15
# running sklearn_rf_390014_97
# running deepchem_irv_80

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 30.0)

sns.tsplot(data=whole_pd, time="EFR", unit="running process", condition="model", value="EF")

figure_dir = 'plottings/{}'.format(task_name)
if not os.path.isdir(figure_dir):
    os.makedirs(figure_dir)
plt.savefig('{}/EF_curve.png'.format(figure_dir), bbox_inches = 'tight')

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 15.0)

# Calculate Normalized EF, and add it to dataframe
whole_pd['Normalized EF'] = whole_pd.apply(lambda row: row['EF'] / row['EF max'], axis=1)
sns.tsplot(data=whole_pd, time="EFR", unit="running process", condition="model", value="Normalized EF")

figure_dir = 'plottings/{}'.format('Keck_RMI')
if not os.path.isdir(figure_dir):
    os.makedirs(figure_dir)
plt.savefig('{}/NEF_curve.png'.format(figure_dir), bbox_inches = 'tight')

# %%
focused_pd = whole_pd[whole_pd['EFR']<=0.06]
sns.tsplot(data=focused_pd, time="EFR", unit="running process", condition="model", value="Normalized EF")
plt.show()
