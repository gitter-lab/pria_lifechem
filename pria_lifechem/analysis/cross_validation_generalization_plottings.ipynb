# %%
from analysis import *
from docking_analysis import *
from IPython.display import Markdown
from cross_validation_generalization_plottings_support import *

task_name = 'Keck_Pria_AS_Retest'

file_paths = file_paths_dict[task_name]
folder_dict = {
    'Keck_Pria_AS_Retest': 'Keck_Pria_AS_Retest',
    'Keck_Pria_FP': 'Keck_FP',
    'Keck_RMI': 'RMI'
}

number = 20
evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01',
               13: 'NEF_2', 14: 'NEF_1', 15: 'NEF_015', 16:'NEF_01'}

paths = ['../../output/stage_1/cross_validation_{}/{}'.
         format(folder_dict[task_name], p)for p in file_paths.values()]

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (18.0, 10.0)
sns.set(font_scale=0.9)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
for k in range(len(file_paths)):
    print 'Check ', paths[k]
    if 'dock' in paths[k] or 'consensus' in paths[k]:
        check_result_completeness(file_path=paths[k], number=5)
    else:
        check_result_completeness(file_path=paths[k], number=20)
    print
# Out:
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/single_classification_22/45540945/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/single_classification_42/45539118/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/single_regression_2/45540957/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/single_regression_11/45540958/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/vanilla_lstm_8/46352274/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/vanilla_lstm_19/46495805/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/multi_classification_15/eval_keck/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/multi_classification_18/eval_keck/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_12/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_13/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_14/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_24/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_25/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_25/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_96/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/random_forest_97/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/irv_5/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/irv_10/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/irv_20/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/irv_40/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/irv_80/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_hybrid/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_fred/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_dock6/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_rdockint/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_rdocktot/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_surflex/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_ad4/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_plants/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/dockscore_smina/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/consensus_dockscore_max/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/consensus_bcs_efr1_opt/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/consensus_bcs_rocauc_opt/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/consensus_dockscore_median/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/consensus_dockscore_mean/
# All output result complete.
#
# Check  ../../output/stage_1/cross_validation_Keck_Pria_AS_Retest/baseline/
# All output result complete.

# %%
plot_generalization(paths,
                    evaluation=evaluations[6],
                    model_list=model_list,
                    title='AUC[PR]_generalization',
                    task_name=task_name)

# %%
plot_generalization(paths,
                    evaluation=evaluations[7],
                    model_list=model_list,
                    title='AUC[ROC]_generalization',
                    task_name=task_name)

# %%
plot_generalization(paths,
                    evaluation=evaluations[8],
                    model_list=model_list,
                    title='AUC[BED ROC]_generalization',
                    task_name=task_name)

# %%
plot_generalization(paths,
                    evaluation=evaluations[10],
                    model_list=model_list,
                    title='EF@1%_generalization',
                    task_name=task_name)

# %%
plot_generalization(paths,
                    evaluation=evaluations[14],
                    model_list=model_list,
                    title='NEF@1%_generalization',
                    task_name=task_name)
