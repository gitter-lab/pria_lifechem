# %%
from prospective_screening_analysis_support import *
import pandas as pd
import numpy as np
from IPython.display import HTML
import matplotlib
# %matplotlib inline
# Out:
# /home/sliu426/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
dir_ = '../../output/stage_2_predictions/Keck_Pria_AS_Retest'
metric_df = pd.read_csv('{}/complete_evaluation.csv'.format(dir_))

# %%
HTML(metric_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Model</th>
#       <th>roc_auc</th>
#       <th>bed_roc_auc</th>
#       <th>precision_auc_single</th>
#       <th>nef_001</th>
#       <th>nef_01</th>
#       <th>nef_02</th>
#       <th>number_of_hit_250</th>
#       <th>number_of_hit_500</th>
#       <th>number_of_hit_1000</th>
#       <th>ratio_of_hit_001</th>
#       <th>ratio_of_hit_01</th>
#       <th>ratio_of_hit_02</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Baseline</td>
#       <td>0.814382</td>
#       <td>0.566998</td>
#       <td>0.098279</td>
#       <td>0.392857</td>
#       <td>0.619048</td>
#       <td>0.690476</td>
#       <td>32</td>
#       <td>38</td>
#       <td>44</td>
#       <td>33</td>
#       <td>52</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ConsensusDocking_efr1_opt</td>
#       <td>0.570236</td>
#       <td>0.120576</td>
#       <td>0.003996</td>
#       <td>0.000000</td>
#       <td>0.095238</td>
#       <td>0.273810</td>
#       <td>0</td>
#       <td>3</td>
#       <td>4</td>
#       <td>0</td>
#       <td>8</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ConsensusDocking_max</td>
#       <td>0.569610</td>
#       <td>0.136192</td>
#       <td>0.004254</td>
#       <td>0.023810</td>
#       <td>0.130952</td>
#       <td>0.261905</td>
#       <td>2</td>
#       <td>3</td>
#       <td>7</td>
#       <td>2</td>
#       <td>11</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ConsensusDocking_mean</td>
#       <td>0.541936</td>
#       <td>0.102557</td>
#       <td>0.003584</td>
#       <td>0.011905</td>
#       <td>0.107143</td>
#       <td>0.190476</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#       <td>9</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ConsensusDocking_median</td>
#       <td>0.527666</td>
#       <td>0.098151</td>
#       <td>0.003590</td>
#       <td>0.023810</td>
#       <td>0.083333</td>
#       <td>0.250000</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>7</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ConsensusDocking_rocauc_opt</td>
#       <td>0.570306</td>
#       <td>0.122588</td>
#       <td>0.003996</td>
#       <td>0.000000</td>
#       <td>0.107143</td>
#       <td>0.273810</td>
#       <td>0</td>
#       <td>3</td>
#       <td>4</td>
#       <td>0</td>
#       <td>9</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Docking_ad4</td>
#       <td>0.424137</td>
#       <td>0.048916</td>
#       <td>0.002638</td>
#       <td>0.012658</td>
#       <td>0.025316</td>
#       <td>0.101266</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>IRV_c</td>
#       <td>0.703184</td>
#       <td>0.451209</td>
#       <td>0.124140</td>
#       <td>0.357143</td>
#       <td>0.583333</td>
#       <td>0.726190</td>
#       <td>30</td>
#       <td>36</td>
#       <td>44</td>
#       <td>30</td>
#       <td>49</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>IRV_d</td>
#       <td>0.752500</td>
#       <td>0.525661</td>
#       <td>0.130150</td>
#       <td>0.357143</td>
#       <td>0.583333</td>
#       <td>0.761905</td>
#       <td>30</td>
#       <td>39</td>
#       <td>45</td>
#       <td>30</td>
#       <td>49</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>IRV_e</td>
#       <td>0.798311</td>
#       <td>0.584919</td>
#       <td>0.140646</td>
#       <td>0.357143</td>
#       <td>0.654762</td>
#       <td>0.773810</td>
#       <td>30</td>
#       <td>40</td>
#       <td>49</td>
#       <td>30</td>
#       <td>55</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>LSTM_a</td>
#       <td>0.573868</td>
#       <td>0.147008</td>
#       <td>0.004342</td>
#       <td>0.011905</td>
#       <td>0.154762</td>
#       <td>0.333333</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>13</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>LSTM_b</td>
#       <td>0.578250</td>
#       <td>0.147887</td>
#       <td>0.004661</td>
#       <td>0.011905</td>
#       <td>0.178571</td>
#       <td>0.273810</td>
#       <td>1</td>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#       <td>15</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>MultiClassification_a</td>
#       <td>0.756792</td>
#       <td>0.487885</td>
#       <td>0.136309</td>
#       <td>0.309524</td>
#       <td>0.547619</td>
#       <td>0.619048</td>
#       <td>26</td>
#       <td>32</td>
#       <td>36</td>
#       <td>26</td>
#       <td>46</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>MultiClassification_b</td>
#       <td>0.764909</td>
#       <td>0.483585</td>
#       <td>0.144937</td>
#       <td>0.369048</td>
#       <td>0.500000</td>
#       <td>0.619048</td>
#       <td>31</td>
#       <td>34</td>
#       <td>37</td>

# %%
plot_metric_comparison(metric_df)
# Out:
# ['roc_auc', 'bed_roc_auc', 'precision_auc_single', 'nef_001', 'nef_01', 'nef_02', 'number_of_hit_250', 'number_of_hit_500', 'number_of_hit_1000', 'ratio_of_hit_001', 'ratio_of_hit_01', 'ratio_of_hit_02']

# %%
model_list = metric_df['Model'].tolist()
roc_auc_list = metric_df['roc_auc'].tolist()
bed_roc_auc_list = metric_df['bed_roc_auc'].tolist()
pr_auc_list = metric_df['precision_auc_single'].tolist()
nef_001_list = metric_df['nef_001'].tolist()

# %%
print('model&\tAUC[ROC]&\tAUC[BED ROC]&\tAUC[PR]&\tNEF@1\%\\\\')
print
for idx in range(len(model_list)):
    line = '{}&\t{:.5f}&\t{:.5f}&\t{:.5f}&\t{:.5f}\\\\'.format(model_list[idx], roc_auc_list[idx], bed_roc_auc_list[idx], pr_auc_list[idx], nef_001_list[idx])
    line = line.replace('_', '\_')
    print line
# Out:
# model&	AUC[ROC]&	AUC[BED ROC]&	AUC[PR]&	NEF@1\%\\
#
# Baseline&	0.81438&	0.56700&	0.09828&	0.39286\\
# ConsensusDocking\_efr1\_opt&	0.57024&	0.12058&	0.00400&	0.00000\\
# ConsensusDocking\_max&	0.56961&	0.13619&	0.00425&	0.02381\\
# ConsensusDocking\_mean&	0.54194&	0.10256&	0.00358&	0.01190\\
# ConsensusDocking\_median&	0.52767&	0.09815&	0.00359&	0.02381\\
# ConsensusDocking\_rocauc\_opt&	0.57031&	0.12259&	0.00400&	0.00000\\
# Docking\_ad4&	0.42414&	0.04892&	0.00264&	0.01266\\
# Docking\_dock6&	0.56425&	0.15214&	0.00528&	0.03571\\
# Docking\_fred&	0.46768&	0.09800&	0.00334&	0.02381\\
# Docking\_hybrid&	0.49163&	0.12848&	0.00377&	0.02381\\
# Docking\_plants&	0.49401&	0.08892&	0.00320&	0.01190\\
# Docking\_rdockint&	0.55647&	0.12877&	0.00423&	0.02381\\
# Docking\_rdocktot&	0.63695&	0.19413&	0.00562&	0.02381\\
# Docking\_smina&	0.45781&	0.05474&	0.00283&	0.00000\\
# Docking\_surflex&	0.54177&	0.12624&	0.00392&	0.01190\\
# IRV\_a&	0.59958&	0.27606&	0.05382&	0.20238\\
# IRV\_b&	0.64584&	0.35529&	0.08296&	0.29762\\
# IRV\_c&	0.70318&	0.45121&	0.12414&	0.35714\\
# IRV\_d&	0.75250&	0.52566&	0.13015&	0.35714\\
# IRV\_e&	0.79831&	0.58492&	0.14065&	0.35714\\
# LSTM\_a&	0.57387&	0.14701&	0.00434&	0.01190\\
# LSTM\_b&	0.57825&	0.14789&	0.00466&	0.01190\\
# MultiClassification\_a&	0.75679&	0.48789&	0.13631&	0.30952\\
# MultiClassification\_b&	0.76491&	0.48359&	0.14494&	0.36905\\
# RandomForest\_a&	0.81107&	0.59457&	0.18909&	0.46429\\
# RandomForest\_b&	0.81341&	0.59684&	0.19118&	0.46429\\
# RandomForest\_c&	0.81305&	0.59952&	0.19286&	0.46429\\
# RandomForest\_d&	0.82612&	0.60948&	0.19601&	0.45238\\
# RandomForest\_e&	0.81926&	0.60646&	0.19534&	0.46429\\
# RandomForest\_f&	0.79705&	0.54027&	0.13450&	0.32143\\
# RandomForest\_g&	0.82493&	0.61738&	0.24723&	0.47619\\
# RandomForest\_h&	0.83768&	0.61382&	0.24864&	0.48810\\
# SingleClassification\_a&	0.69442&	0.42680&	0.08836&	0.29762\\
# SingleClassification\_b&	0.74954&	0.47635&	0.18701&	0.40476\\
# SingleRegression\_a&	0.88992&	0.65319&	0.14743&	0.41667\\
# SingleRegression\_b&	0.88271&	0.63668&	0.18824&	0.41667\\
