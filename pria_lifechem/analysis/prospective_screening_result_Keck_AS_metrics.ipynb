# %%
from prospective_screening_analysis_support import *
import pandas as pd
import numpy as np
from IPython.display import HTML
import matplotlib
# %matplotlib inline
# Out:
# /home/sliu426/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/sliu426/anaconda/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error: package or namespace load failed for ‘RevoUtilsMath’:
#  .onLoad failed in loadNamespace() for 'RevoUtilsMath', details:
#   call: NULL
#   error: Remove Microsoft R and then re-install.
# Be sure to select MKL libraries as an install option.
#
#   warnings.warn(x, RRuntimeWarning)

# %%
dir_ = '../../output/stage_2_predictions/Keck_Pria_AS_Retest'
metric_df = pd.read_csv('{}/complete_evaluation.csv'.format(dir_))

# %%
HTML(metric_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Model</th>
#       <th>roc_auc</th>
#       <th>bed_roc_auc</th>
#       <th>precision_auc_single</th>
#       <th>nef_001</th>
#       <th>nef_01</th>
#       <th>nef_02</th>
#       <th>number_of_hit_250</th>
#       <th>number_of_hit_500</th>
#       <th>number_of_hit_1000</th>
#       <th>ratio_of_hit_001</th>
#       <th>ratio_of_hit_01</th>
#       <th>ratio_of_hit_02</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ConsensusDocking_max</td>
#       <td>0.579961</td>
#       <td>0.148101</td>
#       <td>0.003367</td>
#       <td>0.037037</td>
#       <td>0.148148</td>
#       <td>0.277778</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>5.0</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ConsensusDocking_mean</td>
#       <td>0.552875</td>
#       <td>0.095878</td>
#       <td>0.002608</td>
#       <td>0.000000</td>
#       <td>0.092593</td>
#       <td>0.203704</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>5.0</td>
#       <td>11.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ConsensusDocking_median</td>
#       <td>0.531291</td>
#       <td>0.074816</td>
#       <td>0.002455</td>
#       <td>0.000000</td>
#       <td>0.018519</td>
#       <td>0.240741</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ConsensusDocking_rocauc_opt</td>
#       <td>0.586345</td>
#       <td>0.119491</td>
#       <td>0.002984</td>
#       <td>0.000000</td>
#       <td>0.074074</td>
#       <td>0.314815</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>4.0</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Docking_ad4</td>
#       <td>0.362923</td>
#       <td>0.016431</td>
#       <td>0.001592</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.039216</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Docking_dock6</td>
#       <td>0.555414</td>
#       <td>0.132794</td>
#       <td>0.004543</td>
#       <td>0.018519</td>
#       <td>0.148148</td>
#       <td>0.222222</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>1.0</td>
#       <td>8.0</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Docking_fred</td>
#       <td>0.510089</td>
#       <td>0.121031</td>
#       <td>0.003011</td>
#       <td>0.037037</td>
#       <td>0.111111</td>
#       <td>0.203704</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>6.0</td>
#       <td>11.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>IRV_e</td>
#       <td>0.867181</td>
#       <td>0.714504</td>
#       <td>0.204418</td>
#       <td>0.537037</td>
#       <td>0.759259</td>
#       <td>0.814815</td>
#       <td>29.0</td>
#       <td>34.0</td>
#       <td>41.0</td>
#       <td>29.0</td>
#       <td>41.0</td>
#       <td>44.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>LSTM_a</td>
#       <td>0.589790</td>
#       <td>0.176337</td>
#       <td>0.003567</td>
#       <td>0.018519</td>
#       <td>0.185185</td>
#       <td>0.388889</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>10.0</td>
#       <td>21.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>LSTM_b</td>
#       <td>0.616391</td>
#       <td>0.182176</td>
#       <td>0.004401</td>
#       <td>0.018519</td>
#       <td>0.222222</td>
#       <td>0.333333</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>1.0</td>
#       <td>12.0</td>
#       <td>18.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>MultiClassification_a</td>
#       <td>0.832444</td>
#       <td>0.583681</td>
#       <td>0.184615</td>
#       <td>0.407407</td>
#       <td>0.648148</td>
#       <td>0.703704</td>
#       <td>22.0</td>
#       <td>27.0</td>
#       <td>30.0</td>
#       <td>22.0</td>
#       <td>35.0</td>
#       <td>38.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>MultiClassification_b</td>
#       <td>0.847504</td>
#       <td>0.613458</td>
#       <td>0.221993</td>
#       <td>0.500000</td>
#       <td>0.666667</td>
#       <td>0.703704</td>
#       <td>27.0</td>
#       <td>28.0</td>
#       <td>32.0</td>
#       <td>27.0</td>
#       <td>36.0</td>
#       <td>38.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>RandomForest_a</td>
#       <td>0.875785</td>
#       <td>0.736493</td>
#       <td>0.281650</td>
#       <td>0.666667</td>
#       <td>0.759259</td>
#       <td>0.814815</td>
#       <td>36.0</td>
#       <td>38.0</td>
#       <td>40.0</td>
#       <td>36.0</td>
#       <td>41.0</td>
#       <td>44.0</td

# %%
plot_metric_comparison(metric_df)
# Out:
# ['roc_auc', 'bed_roc_auc', 'precision_auc_single', 'nef_001', 'nef_01', 'nef_02', 'number_of_hit_250', 'number_of_hit_500', 'number_of_hit_1000', 'ratio_of_hit_001', 'ratio_of_hit_01', 'ratio_of_hit_02']
# prospective_screening_metric_names.py:46: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   eval_a = metric_df[metric_a].as_matrix()
# prospective_screening_metric_names.py:53: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   eval_b = metric_df[metric_b].as_matrix()

# %%
model_list = metric_df['Model'].tolist()
roc_auc_list = metric_df['roc_auc'].tolist()
bed_roc_auc_list = metric_df['bed_roc_auc'].tolist()
pr_auc_list = metric_df['precision_auc_single'].tolist()
nef_001_list = metric_df['nef_001'].tolist()

# %%
print('model&\tAUC[ROC]&\tAUC[BED ROC]&\tAUC[PR]&\tNEF@1\%\\\\')
print
for idx in range(len(model_list)):
    line = '{}&\t{:.5f}&\t{:.5f}&\t{:.5f}&\t{:.5f}\\\\'.format(model_list[idx], roc_auc_list[idx], bed_roc_auc_list[idx], pr_auc_list[idx], nef_001_list[idx])
    line = line.replace('_', '\_')
    print line
# Out:
# model&	AUC[ROC]&	AUC[BED ROC]&	AUC[PR]&	NEF@1\%\\
#
# ConsensusDocking\_max&	0.57996&	0.14810&	0.00337&	0.03704\\
# ConsensusDocking\_mean&	0.55288&	0.09588&	0.00261&	0.00000\\
# ConsensusDocking\_median&	0.53129&	0.07482&	0.00246&	0.00000\\
# ConsensusDocking\_rocauc\_opt&	0.58635&	0.11949&	0.00298&	0.00000\\
# Docking\_ad4&	0.36292&	0.01643&	0.00159&	0.00000\\
# Docking\_dock6&	0.55541&	0.13279&	0.00454&	0.01852\\
# Docking\_fred&	0.51009&	0.12103&	0.00301&	0.03704\\
# Docking\_hybrid&	0.49760&	0.13474&	0.00293&	0.01852\\
# Docking\_plants&	0.48162&	0.06959&	0.00223&	0.01852\\
# Docking\_rdockint&	0.56174&	0.12492&	0.00324&	0.01852\\
# Docking\_rdocktot&	0.68720&	0.21658&	0.00470&	0.01852\\
# Docking\_smina&	0.42361&	0.03394&	0.00188&	0.00000\\
# Docking\_surflex&	0.57940&	0.15061&	0.00341&	0.01852\\
# IRV\_a&	0.64669&	0.35955&	0.07617&	0.29630\\
# IRV\_b&	0.71961&	0.48510&	0.12394&	0.44444\\
# IRV\_c&	0.78292&	0.59296&	0.18787&	0.51852\\
# IRV\_d&	0.82602&	0.65816&	0.19050&	0.51852\\
# IRV\_e&	0.86718&	0.71450&	0.20442&	0.53704\\
# LSTM\_a&	0.58979&	0.17634&	0.00357&	0.01852\\
# LSTM\_b&	0.61639&	0.18218&	0.00440&	0.01852\\
# MultiClassification\_a&	0.83244&	0.58368&	0.18462&	0.40741\\
# MultiClassification\_b&	0.84750&	0.61346&	0.22199&	0.50000\\
# RandomForest\_a&	0.87578&	0.73649&	0.28165&	0.66667\\
# RandomForest\_b&	0.87065&	0.74287&	0.28530&	0.66667\\
# RandomForest\_c&	0.87524&	0.74433&	0.28648&	0.66667\\
# RandomForest\_d&	0.88677&	0.75521&	0.28425&	0.64815\\
# RandomForest\_e&	0.89007&	0.75693&	0.28200&	0.66667\\
# RandomForest\_f&	0.88105&	0.68324&	0.17308&	0.44444\\
# RandomForest\_g&	0.88903&	0.76547&	0.36893&	0.66667\\
# RandomForest\_h&	0.89689&	0.76886&	0.37933&	0.66667\\
# SingleClassification\_a&	0.76435&	0.51959&	0.11103&	0.37037\\
# SingleClassification\_b&	0.81857&	0.61809&	0.30469&	0.55556\\
# SingleRegression\_a&	0.92068&	0.73424&	0.18769&	0.53704\\
# SingleRegression\_b&	0.89712&	0.68403&	0.18575&	0.50000\\
