# %%
from prospective_screening_analysis_support import *
import pandas as pd
import numpy as np
from IPython.display import HTML
import matplotlib
# %matplotlib inline
# Out:
# /home/sliu426/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
dir_ = '../../output/stage_2_predictions/Keck_Pria_AS_Retest'
metric_df = pd.read_csv('{}/complete_evaluation.csv'.format(dir_))

# %%
HTML(metric_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Model</th>
#       <th>roc_auc</th>
#       <th>bed_roc_auc</th>
#       <th>precision_auc_single</th>
#       <th>nef_001</th>
#       <th>nef_01</th>
#       <th>nef_02</th>
#       <th>number_of_hit_250</th>
#       <th>number_of_hit_500</th>
#       <th>number_of_hit_1000</th>
#       <th>ratio_of_hit_001</th>
#       <th>ratio_of_hit_01</th>
#       <th>ratio_of_hit_02</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>inhibition</td>
#       <td>0.999745</td>
#       <td>0.985536</td>
#       <td>0.866789</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>62</td>
#       <td>62</td>
#       <td>62</td>
#       <td>62</td>
#       <td>62</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Baseline</td>
#       <td>0.852083</td>
#       <td>0.651116</td>
#       <td>0.106950</td>
#       <td>0.500000</td>
#       <td>0.709677</td>
#       <td>0.774194</td>
#       <td>31</td>
#       <td>34</td>
#       <td>38</td>
#       <td>31</td>
#       <td>44</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ConsensusDocking_efr1_opt</td>
#       <td>0.570300</td>
#       <td>0.116338</td>
#       <td>0.002895</td>
#       <td>0.000000</td>
#       <td>0.080645</td>
#       <td>0.290323</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>5</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ConsensusDocking_max</td>
#       <td>0.564259</td>
#       <td>0.141133</td>
#       <td>0.003215</td>
#       <td>0.032258</td>
#       <td>0.129032</td>
#       <td>0.274194</td>
#       <td>2</td>
#       <td>2</td>
#       <td>6</td>
#       <td>2</td>
#       <td>8</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ConsensusDocking_mean</td>
#       <td>0.527276</td>
#       <td>0.086967</td>
#       <td>0.002501</td>
#       <td>0.000000</td>
#       <td>0.080645</td>
#       <td>0.193548</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>5</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ConsensusDocking_median</td>
#       <td>0.504719</td>
#       <td>0.069615</td>
#       <td>0.002353</td>
#       <td>0.000000</td>
#       <td>0.032258</td>
#       <td>0.225806</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ConsensusDocking_rocauc_opt</td>
#       <td>0.568469</td>
#       <td>0.118370</td>
#       <td>0.002902</td>
#       <td>0.000000</td>
#       <td>0.096774</td>
#       <td>0.290323</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Docking_ad4</td>
#       <td>0.364189</td>
#       <td>0.019526</td>
#       <td>0.001614</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.051724</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>IRV_c</td>
#       <td>0.761341</td>
#       <td>0.552673</td>
#       <td>0.148237</td>
#       <td>0.467742</td>
#       <td>0.645161</td>
#       <td>0.790323</td>
#       <td>29</td>
#       <td>33</td>
#       <td>38</td>
#       <td>29</td>
#       <td>40</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>IRV_d</td>
#       <td>0.814293</td>
#       <td>0.633136</td>
#       <td>0.153812</td>
#       <td>0.467742</td>
#       <td>0.725806</td>
#       <td>0.822581</td>
#       <td>29</td>
#       <td>37</td>
#       <td>43</td>
#       <td>29</td>
#       <td>45</td>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>IRV_e</td>
#       <td>0.864690</td>
#       <td>0.698522</td>
#       <td>0.166219</td>
#       <td>0.467742</td>
#       <td>0.774194</td>
#       <td>0.838710</td>
#       <td>29</td>
#       <td>38</td>
#       <td>44</td>
#       <td>29</td>
#       <td>48</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>LSTM_a</td>
#       <td>0.594918</td>
#       <td>0.173401</td>
#       <td>0.003623</td>
#       <td>0.016129</td>
#       <td>0.177419</td>
#       <td>0.403226</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>11</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>LSTM_b</td>
#       <td>0.616909</td>
#       <td>0.180581</td>
#       <td>0.004236</td>
#       <td>0.016129</td>
#       <td>0.225806</td>
#       <td>0.322581</td>
#       <td>1</td>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#       <td>14</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>MultiClassification_a</td>
#       <td>0.813986</td>
#       <td>0.570453</td>
#       <td>0.170382</td>
#       <td>0.403226</td>
#       <td>0.629032</td>
#       <td>0.677419</td>
#       <td>25</td>
#       <td>29</td>
#       <td>32</td>
#       <td>25</td>

# %%
plot_metric_comparison(metric_df)
# Out:
# ['roc_auc', 'bed_roc_auc', 'precision_auc_single', 'nef_001', 'nef_01', 'nef_02', 'number_of_hit_250', 'number_of_hit_500', 'number_of_hit_1000', 'ratio_of_hit_001', 'ratio_of_hit_01', 'ratio_of_hit_02']

# %%
model_list = metric_df['Model'].tolist()
roc_auc_list = metric_df['roc_auc'].tolist()
bed_roc_auc_list = metric_df['bed_roc_auc'].tolist()
pr_auc_list = metric_df['precision_auc_single'].tolist()
nef_001_list = metric_df['nef_001'].tolist()

# %%
print('model&\tAUC[ROC]&\tAUC[BED ROC]&\tAUC[PR]&\tNEF@1\%\\\\')
print
for idx in range(len(model_list)):
    line = '{}&\t{:.5f}&\t{:.5f}&\t{:.5f}&\t{:.5f}\\\\'.format(model_list[idx], roc_auc_list[idx], bed_roc_auc_list[idx], pr_auc_list[idx], nef_001_list[idx])
    line = line.replace('_', '\_')
    print line
# Out:
# model&	AUC[ROC]&	AUC[BED ROC]&	AUC[PR]&	NEF@1\%\\
#
# inhibition&	0.99974&	0.98554&	0.86679&	1.00000\\
# Baseline&	0.85208&	0.65112&	0.10695&	0.50000\\
# ConsensusDocking\_efr1\_opt&	0.57030&	0.11634&	0.00290&	0.00000\\
# ConsensusDocking\_max&	0.56426&	0.14113&	0.00322&	0.03226\\
# ConsensusDocking\_mean&	0.52728&	0.08697&	0.00250&	0.00000\\
# ConsensusDocking\_median&	0.50472&	0.06962&	0.00235&	0.00000\\
# ConsensusDocking\_rocauc\_opt&	0.56847&	0.11837&	0.00290&	0.00000\\
# Docking\_ad4&	0.36419&	0.01953&	0.00161&	0.00000\\
# Docking\_dock6&	0.53686&	0.13285&	0.00388&	0.03226\\
# Docking\_fred&	0.49130&	0.11133&	0.00279&	0.03226\\
# Docking\_hybrid&	0.48581&	0.12150&	0.00273&	0.01613\\
# Docking\_plants&	0.47750&	0.08226&	0.00229&	0.01613\\
# Docking\_rdockint&	0.53691&	0.11386&	0.00302&	0.01613\\
# Docking\_rdocktot&	0.64839&	0.20491&	0.00436&	0.01613\\
# Docking\_smina&	0.41914&	0.03112&	0.00190&	0.00000\\
# Docking\_surflex&	0.53997&	0.12983&	0.00301&	0.01613\\
# IRV\_a&	0.62741&	0.32530&	0.05911&	0.25806\\
# IRV\_b&	0.69061&	0.43363&	0.09337&	0.38710\\
# IRV\_c&	0.76134&	0.55267&	0.14824&	0.46774\\
# IRV\_d&	0.81429&	0.63314&	0.15381&	0.46774\\
# IRV\_e&	0.86469&	0.69852&	0.16622&	0.46774\\
# LSTM\_a&	0.59492&	0.17340&	0.00362&	0.01613\\
# LSTM\_b&	0.61691&	0.18058&	0.00424&	0.01613\\
# MultiClassification\_a&	0.81399&	0.57045&	0.17038&	0.40323\\
# MultiClassification\_b&	0.82881&	0.58674&	0.17495&	0.48387\\
# RandomForest\_a&	0.86141&	0.70402&	0.23836&	0.61290\\
# RandomForest\_b&	0.86446&	0.71023&	0.24203&	0.61290\\
# RandomForest\_c&	0.87501&	0.71773&	0.24374&	0.61290\\
# RandomForest\_d&	0.87780&	0.72584&	0.24798&	0.59677\\
# RandomForest\_e&	0.88127&	0.72588&	0.24693&	0.61290\\
# RandomForest\_f&	0.88293&	0.67607&	0.17495&	0.41935\\
# RandomForest\_g&	0.87129&	0.73001&	0.31639&	0.62903\\
# RandomForest\_h&	0.88458&	0.73210&	0.31915&	0.64516\\
# SingleClassification\_a&	0.74376&	0.50001&	0.10606&	0.37097\\
# SingleClassification\_b&	0.80086&	0.58259&	0.24416&	0.51613\\
# SingleRegression\_a&	0.91908&	0.71866&	0.15933&	0.50000\\
# SingleRegression\_b&	0.90339&	0.69169&	0.19039&	0.46774\\
