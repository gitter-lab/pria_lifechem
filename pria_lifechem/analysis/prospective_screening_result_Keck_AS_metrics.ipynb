# %%
from prospective_screening_analysis_support import *
import pandas as pd
import numpy as np
from IPython.display import HTML
import matplotlib
# %matplotlib inline
# Out:
# /home/sliu426/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
dir_ = '../../output/stage_2_predictions/Keck_Pria_AS_Retest'
metric_df = pd.read_csv('{}/complete_evaluation.csv'.format(dir_))

# %%
HTML(metric_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Model</th>
#       <th>roc_auc</th>
#       <th>bed_roc_auc</th>
#       <th>precision_auc_single</th>
#       <th>nef_001</th>
#       <th>nef_01</th>
#       <th>nef_02</th>
#       <th>number_of_hit_250</th>
#       <th>number_of_hit_500</th>
#       <th>number_of_hit_1000</th>
#       <th>ratio_of_hit_001</th>
#       <th>ratio_of_hit_01</th>
#       <th>ratio_of_hit_02</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>inhibition</td>
#       <td>0.999760</td>
#       <td>0.985292</td>
#       <td>0.873160</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>64</td>
#       <td>64</td>
#       <td>64</td>
#       <td>64</td>
#       <td>64</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Baseline</td>
#       <td>0.856068</td>
#       <td>0.656078</td>
#       <td>0.108001</td>
#       <td>0.500000</td>
#       <td>0.718750</td>
#       <td>0.781250</td>
#       <td>31</td>
#       <td>35</td>
#       <td>40</td>
#       <td>32</td>
#       <td>46</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ConsensusDocking_efr1_opt</td>
#       <td>0.574677</td>
#       <td>0.118885</td>
#       <td>0.003030</td>
#       <td>0.000000</td>
#       <td>0.093750</td>
#       <td>0.296875</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ConsensusDocking_max</td>
#       <td>0.568463</td>
#       <td>0.140208</td>
#       <td>0.003317</td>
#       <td>0.031250</td>
#       <td>0.125000</td>
#       <td>0.281250</td>
#       <td>2</td>
#       <td>2</td>
#       <td>6</td>
#       <td>2</td>
#       <td>8</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ConsensusDocking_mean</td>
#       <td>0.534470</td>
#       <td>0.092895</td>
#       <td>0.002643</td>
#       <td>0.000000</td>
#       <td>0.093750</td>
#       <td>0.203125</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>6</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ConsensusDocking_median</td>
#       <td>0.510695</td>
#       <td>0.076185</td>
#       <td>0.002474</td>
#       <td>0.000000</td>
#       <td>0.046875</td>
#       <td>0.234375</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ConsensusDocking_rocauc_opt</td>
#       <td>0.574990</td>
#       <td>0.123307</td>
#       <td>0.003063</td>
#       <td>0.000000</td>
#       <td>0.109375</td>
#       <td>0.296875</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Docking_ad4</td>
#       <td>0.369437</td>
#       <td>0.019421</td>
#       <td>0.001684</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.050000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>IRV_c</td>
#       <td>0.752976</td>
#       <td>0.538160</td>
#       <td>0.143852</td>
#       <td>0.453125</td>
#       <td>0.625000</td>
#       <td>0.781250</td>
#       <td>29</td>
#       <td>33</td>
#       <td>38</td>
#       <td>29</td>
#       <td>40</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>IRV_d</td>
#       <td>0.804074</td>
#       <td>0.615805</td>
#       <td>0.149241</td>
#       <td>0.453125</td>
#       <td>0.656250</td>
#       <td>0.812500</td>
#       <td>29</td>
#       <td>37</td>
#       <td>40</td>
#       <td>29</td>
#       <td>42</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>IRV_e</td>
#       <td>0.867796</td>
#       <td>0.698078</td>
#       <td>0.162627</td>
#       <td>0.453125</td>
#       <td>0.781250</td>
#       <td>0.843750</td>
#       <td>29</td>
#       <td>38</td>
#       <td>45</td>
#       <td>29</td>
#       <td>50</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>LSTM_a</td>
#       <td>0.597888</td>
#       <td>0.171791</td>
#       <td>0.003734</td>
#       <td>0.015625</td>
#       <td>0.171875</td>
#       <td>0.406250</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>11</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>LSTM_b</td>
#       <td>0.611732</td>
#       <td>0.175070</td>
#       <td>0.004234</td>
#       <td>0.015625</td>
#       <td>0.218750</td>
#       <td>0.312500</td>
#       <td>1</td>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#       <td>14</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>MultiClassification_a</td>
#       <td>0.816828</td>
#       <td>0.564544</td>
#       <td>0.165659</td>
#       <td>0.390625</td>
#       <td>0.625000</td>
#       <td>0.687500</td>
#       <td>25</td>
#       <td>29</td>
#       <td>32</td>
#       <td>25</td>

# %%
plot_metric_comparison(metric_df)
# Out:
# ['roc_auc', 'bed_roc_auc', 'precision_auc_single', 'nef_001', 'nef_01', 'nef_02', 'number_of_hit_250', 'number_of_hit_500', 'number_of_hit_1000', 'ratio_of_hit_001', 'ratio_of_hit_01', 'ratio_of_hit_02']

# %%
model_list = metric_df['Model'].tolist()
roc_auc_list = metric_df['roc_auc'].tolist()
bed_roc_auc_list = metric_df['bed_roc_auc'].tolist()
pr_auc_list = metric_df['precision_auc_single'].tolist()
nef_001_list = metric_df['nef_001'].tolist()

# %%
print('model&\tAUC[ROC]&\tAUC[BED ROC]&\tAUC[PR]&\tNEF@1\%\\\\')
print
for idx in range(len(model_list)):
    line = '{}&\t{:.5f}&\t{:.5f}&\t{:.5f}&\t{:.5f}\\\\'.format(model_list[idx], roc_auc_list[idx], bed_roc_auc_list[idx], pr_auc_list[idx], nef_001_list[idx])
    line = line.replace('_', '\_')
    print line
# Out:
# model&	AUC[ROC]&	AUC[BED ROC]&	AUC[PR]&	NEF@1\%\\
#
# inhibition&	0.99976&	0.98529&	0.87316&	1.00000\\
# Baseline&	0.85607&	0.65608&	0.10800&	0.50000\\
# ConsensusDocking\_efr1\_opt&	0.57468&	0.11889&	0.00303&	0.00000\\
# ConsensusDocking\_max&	0.56846&	0.14021&	0.00332&	0.03125\\
# ConsensusDocking\_mean&	0.53447&	0.09290&	0.00264&	0.00000\\
# ConsensusDocking\_median&	0.51069&	0.07618&	0.00247&	0.00000\\
# ConsensusDocking\_rocauc\_opt&	0.57499&	0.12331&	0.00306&	0.00000\\
# Docking\_ad4&	0.36944&	0.01942&	0.00168&	0.00000\\
# Docking\_dock6&	0.54345&	0.13209&	0.00397&	0.03125\\
# Docking\_fred&	0.49595&	0.11140&	0.00287&	0.03125\\
# Docking\_hybrid&	0.48381&	0.11795&	0.00277&	0.01562\\
# Docking\_plants&	0.48307&	0.08491&	0.00239&	0.01562\\
# Docking\_rdockint&	0.54741&	0.11969&	0.00320&	0.01562\\
# Docking\_rdocktot&	0.64999&	0.20526&	0.00451&	0.01562\\
# Docking\_smina&	0.42579&	0.03120&	0.00198&	0.00000\\
# Docking\_surflex&	0.54351&	0.13819&	0.00319&	0.01562\\
# IRV\_a&	0.62337&	0.31815&	0.05748&	0.25000\\
# IRV\_b&	0.68455&	0.42300&	0.09069&	0.37500\\
# IRV\_c&	0.75298&	0.53816&	0.14385&	0.45312\\
# IRV\_d&	0.80407&	0.61580&	0.14924&	0.45312\\
# IRV\_e&	0.86780&	0.69808&	0.16263&	0.45312\\
# LSTM\_a&	0.59789&	0.17179&	0.00373&	0.01562\\
# LSTM\_b&	0.61173&	0.17507&	0.00423&	0.01562\\
# MultiClassification\_a&	0.81683&	0.56454&	0.16566&	0.39062\\
# MultiClassification\_b&	0.81845&	0.56959&	0.16967&	0.46875\\
# RandomForest\_a&	0.85472&	0.68304&	0.23112&	0.59375\\
# RandomForest\_b&	0.85390&	0.68834&	0.23463&	0.59375\\
# RandomForest\_c&	0.86040&	0.69539&	0.23625&	0.59375\\
# RandomForest\_d&	0.86189&	0.70333&	0.24036&	0.57812\\
# RandomForest\_e&	0.86801&	0.70339&	0.23936&	0.59375\\
# RandomForest\_f&	0.87570&	0.66028&	0.16986&	0.40625\\
# RandomForest\_g&	0.85924&	0.70837&	0.30669&	0.60938\\
# RandomForest\_h&	0.87670&	0.71014&	0.30938&	0.62500\\
# SingleClassification\_a&	0.73172&	0.48459&	0.10288&	0.35938\\
# SingleClassification\_b&	0.79100&	0.56463&	0.23668&	0.50000\\
# SingleRegression\_a&	0.91363&	0.70564&	0.15504&	0.48438\\
# SingleRegression\_b&	0.90383&	0.68809&	0.18944&	0.46875\\
