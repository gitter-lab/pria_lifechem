# %%
from analysis import *
from docking_analysis import *
from IPython.display import Markdown

file_paths = {0: 'single_classification/'}

number = 20

evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01'}

paths = ['../../output/cross_validation_Keck_hard/{}'.format(p) for p in file_paths.values()]
model_list = ['single_classification']

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
for k in range(len(paths)):
    print 'Check ', file_paths[k]
    check_result_completeness(dir_='../../output/cross_validation_Keck_hard/', file_path=file_paths[k], number=number)
    print
# Out:
# Check  single_classification/
# All output result complete.

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                      model_list=model_list,
                      title='AUC[PR]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[PR]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification | 0.942 | 0.274 | 0.314 |
#
# ## Model comparison
# ### median of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification | 0.975 | 0.276 | 0.319 |
#
# ## Model comparison
# ### std of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification | 0.081 | 0.007 | 0.017 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                      model_list=model_list,
                      title='AUC[ROC]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification | 0.998 | 0.799 | 0.833 |
#
# ## Model comparison
# ### median of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification | 1.000 | 0.797 | 0.838 |
#
# ## Model comparison
# ### std of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification | 0.005 | 0.020 | 0.019 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                      model_list=model_list,
                      title='AUC[BED ROC]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[BED ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification | 0.925 | 0.524 | 0.577 |
#
# ## Model comparison
# ### median of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification | 0.934 | 0.522 | 0.580 |
#
# ## Model comparison
# ### std of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification | 0.022 | 0.014 | 0.017 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                      model_list=model_list,
                      title='Enrichment Factor on Test Set')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='Enrichment Factor (Test-set)')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification | 21.671 | 32.446 | 63.768 | 69.293 |
#
# ## Model comparison
# ### median of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification | 21.875 | 32.065 | 65.217 | 70.652 |
#
# ## Model comparison
# ### std of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification | 0.881 | 1.799 | 5.564 | 3.893 |
