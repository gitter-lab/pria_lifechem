# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib
import os
from IPython.display import display
matplotlib.use('Agg')
# %matplotlib inline
import pandas as pd
pd.set_option('precision', 4)
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

from gather_metrics import *
def get_ranked_by_means_df(gather_df, metric_list):
    means_df = gather_df.xs(['test_metrics', 'Folds Mean'], level=['set','fold'])
    ranked_df = pd.DataFrame(data=np.zeros(shape=means_df.shape), columns=metric_list, dtype=str)
    for m, i in zip(metric_list, range(len(metric_list))):
        metric_df = means_df[m]
        sorted_df = metric_df.sort_values(ascending=False)
        mscore_list = sorted_df.tolist()
        models_ranked = sorted_df.index.tolist()
        m_order_mscore_list = [str(m) + ", " + str(round(r,4)) for m, r in zip(models_ranked, mscore_list)]
        ranked_df.iloc[:,i] = m_order_mscore_list
    return ranked_df

# %%
# load stage CV
model_directory = '../../../job_results_small/'
class_dirs = [model_directory+'/random_forest/stage_1/',
              model_directory+'/irv/stage_1/',
              model_directory+'/neural_networks/stage_1/',
              model_directory+'/docking/stage_1/']
k = 5
gather_df_2 = gather_dir_metrics(class_dirs[0], k)     
gather_df_2 = gather_df_2.append(gather_dir_metrics(class_dirs[1], k))   
gather_df_2 = gather_df_2.append(gather_dir_metrics(class_dirs[2], 20))
gather_df_2 = gather_df_2.append(gather_dir_metrics(class_dirs[3], k))

col_indices = list(range(10)) + list(range(15, 20)) + list(range(25, 105)) + list(range(145, 149)) + list(range(150, 183))
col_indices = [i for i in col_indices if 'Mean' not in gather_df_2.columns[i] and 'Median' not in gather_df_2.columns[i]]
col_indices = [i for i in col_indices if 'RMI-FANCM1' in gather_df_2.columns[i]]
metric_names = list(gather_df_2.columns.values[col_indices])

gather_df_2 = gather_df_2[metric_names]
gather_df_2 = gather_df_2.dropna(axis=0)

gather_df_cv = gather_df_2

#setup comparison matrix and overlaps
dtk_dict = dtk_multi_metrics(gather_df_cv, list(range(len(col_indices))))
dtk_analysis_dict = analyze_dtk_dict(dtk_dict)
mm_comp_dicts = get_mean_median_comps(gather_df_cv, list(range(len(col_indices))))
agg_comp_dict = get_agg_comp(mm_comp_dicts, dtk_analysis_dict, mean_w=1, median_w=0, tukey_w=1)

# %% [markdown]
# ---
# ## Compute Best Models for Each Metric Based on Mean VS DTK+Mean

# %%
simple_ranked_cv = get_ranked_by_means_df(gather_df_cv, metric_names)
complex_ranked_cv = get_model_ordering(agg_comp_dict, metric_names)

top_n = 1
req_metrics = ['ROC AUC RMI-FANCM1', 'BEDROC AUC RMI-FANCM1','PR auc.integral RMI-FANCM1', 
               'NEF AUC RMI-FANCM1', 'NEF_1 % RMI-FANCM1', 'EF_1 % RMI-FANCM1']

simple_top_n = simple_ranked_cv[req_metrics].iloc[:top_n,:]
complex_top_n = complex_ranked_cv[req_metrics].iloc[:top_n,:]

# %% [markdown]
# ### Ranking by Folds Mean Only

# %%
display('Ranking by Means. Shows model-mean pairs.', simple_ranked_cv[req_metrics])
# Out:
# 'Ranking by Means. Shows model-mean pairs.'
#                      ROC AUC RMI-FANCM1                BEDROC AUC RMI-FANCM1           PR auc.integral RMI-FANCM1                   NEF AUC RMI-FANCM1                   NEF_1 % RMI-FANCM1                    EF_1 % RMI-FANCM1
# 0                RandomForest_h, 0.8346               RandomForest_h, 0.5114               RandomForest_h, 0.1237               RandomForest_h, 0.6071               RandomForest_g, 0.3127              RandomForest_g, 31.2692
# 1                RandomForest_g, 0.8306               RandomForest_g, 0.5045               RandomForest_g, 0.1225               RandomForest_g, 0.5991               RandomForest_h, 0.3082              RandomForest_h, 30.8248
# 2                RandomForest_e, 0.8256               RandomForest_e, 0.5001               RandomForest_e, 0.1224                RandomForest_e, 0.596               RandomForest_d, 0.2997              RandomForest_d, 29.9737
# 3                RandomForest_d, 0.8225               RandomForest_d, 0.4967               RandomForest_b, 0.1219               RandomForest_d, 0.5919               RandomForest_e, 0.2996              RandomForest_e, 29.9644
# 4                RandomForest_f, 0.8207               RandomForest_b, 0.4908               RandomForest_a, 0.1218               RandomForest_a, 0.5722               RandomForest_a, 0.2953              RandomForest_a, 29.5297
# 5                RandomForest_c, 0.8161               RandomForest_a, 0.4898               RandomForest_d, 0.1213                RandomForest_b, 0.572                RandomForest_c, 0.291              RandomForest_c, 29.1041
# 6                RandomForest_b, 0.8159               RandomForest_c, 0.4897               RandomForest_c, 0.1208               RandomForest_c, 0.5712                RandomForest_b, 0.291              RandomForest_b, 29.1041
# 7                RandomForest_a, 0.8157               RandomForest_f, 0.4637                        IRV_d, 0.0841               RandomForest_f, 0.5546               RandomForest_f, 0.2868              RandomForest_f, 28.6782
# 8         MultiClassification_b, 0.7532                        IRV_e, 0.4356       SingleClassification_b, 0.0824                        IRV_e, 0.4994                        IRV_d, 0.2867                       IRV_d, 28.6693
# 9                         IRV_e, 0.7463                        IRV_d, 0.4324                        IRV_e, 0.0752                        IRV_d, 0.4646                        IRV_e, 0.2822                       IRV_e, 28.2249
# 10        MultiClassification_a, 0.7259                        IRV_c, 0.3931                        IRV_a, 0.0745        MultiClassification_b, 0.4526                        IRV_b, 0.2645                       IRV_b, 26.4471
# 11                        IRV_d, 0.7189                        IRV_b, 0.3727       SingleClassification_a, 0.0724        MultiClassification_a, 0.4055                        IRV_c, 0.2645                       IRV_c, 26.4471
# 12                        IRV_c, 0.6854        MultiClassification_b, 0.3582                        IRV_c, 0.0716       SingleClassification_b, 0.3935                        IRV_a, 0.2515                       IRV_a, 25.1516
# 13                        IRV_b, 0.6649       SingleClassification_a, 0.3393               RandomForest_f, 0.0681       SingleClassification_a, 0.3932       SingleClassification_b, 0.2227       SingleClassification_b, 22.272
# 14       SingleClassification_b, 0.6623       SingleClassification_b, 0.3373                        IRV_b, 0.0678                        IRV_c, 0.3929       SingleClassification_a, 0.2159      SingleClassification_a, 21.5942
# 15       SingleClassification_a, 0.6366                        IRV_a, 0.3288        MultiClassification_a, 0.0442                          IRV_b, 0.35        MultiClassification_b, 0.1574       MultiClassification_b, 15.7433
# 16                        IRV_a, 0.6339        MultiClassification_a, 0.3177        MultiClassification_b, 0.0405                         IRV_a, 0.284        MultiClassification_a, 0.1445       MultiClassification_a, 14.4456
# 17                  Docking_ad4, 0.5753              Docking_rdocktot, 0.169           SingleRegression_b, 0.0398             Docking_rdocktot, 0.2328            SingleRegression_b, 0.126          SingleRegression_b, 12.6018
# 18             Docking_rdocktot, 0.5603           SingleRegression_b, 0.1684                  Docking_ad4, 0.0117                   Docking_ad4, 0.231      ConsensusDocking_median, 0.0521      ConsensusDocking_median, 5.2102
# 19                       LSTM_a, 0.5576                  Docking_ad4, 0.1651             Docking_rdocktot, 0.0114                Docking_smina, 0.2068              Docking_rdocktot, 0.052             Docking_rdocktot, 5.2005
# 20                Docking_smina, 0.5478                Docking_smina, 0.1491                Docking_smina, 0.0109                       LSTM_a, 0.1952             Docking_rdockint, 0.0438              Docking_rdockint, 4.378
# 21         ConsensusDocking_max, 0.5229             Docking_rdockint, 0.1442      ConsensusDocking_median, 0.0103             Docking_rdockint, 0.1926                Docking_smina, 0.0305                 Docking_smina, 3.054
# 22              Docking_rdockint, 0.522                       LSTM_a, 0.1338  ConsensusDocking_rocauc_opt, 0.0102           SingleRegression_b, 0.1803                  Docking_ad4, 0.0304                  Docking_ad4, 3.0447
# 23                       LSTM_b, 0.5197         ConsensusDocking_max, 0.1254    ConsensusDocking_efr1_opt, 0.0098               Docking_hybrid, 0.1738         ConsensusDocking_max, 0.0304         ConsensusDocking_max, 3.0443
# 24       ConsensusDocking_median, 0.511      ConsensusDocking_median, 0.1216         ConsensusDocking_max, 0.0092                       LSTM_b, 0.1724  ConsensusDocking_rocauc_opt, 0.0257  ConsensusDocking_rocauc_opt, 2.5721
# 25               Docking_hybrid, 0.4964               Docking_hybrid, 0.1192             Docking_rdockint, 0.0073         ConsensusDocking_max, 0.1714        ConsensusDocking_mean, 0.0217        ConsensusDocking_mean, 2.1655
# 26        ConsensusDocking_mean, 0.4878                       LSTM_b, 0.1172        ConsensusDocking_mean, 0.0068      ConsensusDocking_median, 0.1643               Docking_plants, 0.0216               Docking_plants, 2.1558
# 27               Docking_plants, 0.4821        ConsensusDocking_mean, 0.1032                       LSTM_a, 0.0061        ConsensusDocking_mean, 0.1447    ConsensusDocking_efr1_opt, 0.0215    ConsensusDocking_efr1_opt, 2.1466
# 28  ConsensusDocking_rocauc_opt, 0.4788    ConsensusDocking_efr1_opt, 0.0934                       LSTM_b, 0.0055  ConsensusDocking_rocauc_opt, 0.1386                       LSTM_b, 0.0163                       LSTM_b, 1.6312
# 29    ConsensusDocking_efr1_opt, 0.4756  ConsensusDocking_rocauc_opt, 0.0899                Docking_hybrid, 0.005    ConsensusDocking_efr1_opt, 0.1324                       LSTM_a, 0.0153                       LSTM_a, 1.5295
# 30           SingleRegression_b, 0.4634               Docking_plants, 0.0832               Docking_plants, 0.0047               Docking_plants, 0.1222                 Docking_fred, 0.0133                 Docking_fred, 1.3333
# 31                 Docking_fred, 0.4516                 Docking_fred, 0.0814                 Docking_fred, 0.0044                  Docking_fred, 0.118                Docking_hybrid, 0.013               Docking_hybrid, 1.3048
# 32                Docking_dock6, 0.4376                Docking_dock6, 0.0669                Docking_dock6, 0.0042                Docking_dock6, 0.0962                 Docking_dock6, 0.013                Docking_dock6, 1.3043
# 33              Docking_surflex, 0.4196               Docking_surflex, 0.063              Docking_surflex, 0.0039              Docking_surflex, 0.0906           SingleRegression_a, 0.0076           SingleRegression_a, 0.7635
# 34           SingleRegression_a, 0.3876           SingleRegression_a, 0.0541           SingleRegression_a, 0.0036           SingleRegression_a, 0.0743              Docking_surflex, 0.0043              Docking_surflex, 0.4255

# %% [markdown]
# ### Ranking by DTK+Means

# %%
display('Ranking by DTK+Means. Shows model-rank pairs.', complex_ranked_cv[req_metrics])
# Out:
# 'Ranking by DTK+Means. Shows model-rank pairs.'
#                    ROC AUC RMI-FANCM1              BEDROC AUC RMI-FANCM1         PR auc.integral RMI-FANCM1                 NEF AUC RMI-FANCM1                 NEF_1 % RMI-FANCM1                  EF_1 % RMI-FANCM1
# 0                 RandomForest_h, 1.0                RandomForest_h, 1.0        SingleClassification_b, 1.0                RandomForest_h, 1.0                RandomForest_h, 1.0                RandomForest_h, 1.0
# 1                 RandomForest_g, 2.0                RandomForest_g, 2.0        SingleClassification_a, 2.0                RandomForest_g, 2.0                RandomForest_g, 1.0                RandomForest_g, 1.0
# 2                 RandomForest_e, 3.0                RandomForest_e, 3.0                RandomForest_h, 2.0                RandomForest_e, 3.0                RandomForest_e, 3.0                RandomForest_e, 3.0
# 3                 RandomForest_d, 4.0                RandomForest_d, 4.0                RandomForest_g, 4.0                RandomForest_d, 3.0                RandomForest_d, 3.0                RandomForest_d, 3.0
# 4                 RandomForest_c, 5.0                RandomForest_b, 5.0                RandomForest_e, 5.0                RandomForest_a, 5.0                RandomForest_a, 5.0                RandomForest_a, 5.0
# 5                 RandomForest_f, 6.0                RandomForest_c, 6.0                RandomForest_b, 6.0                RandomForest_b, 6.0                RandomForest_f, 6.0                RandomForest_f, 6.0
# 6                 RandomForest_b, 6.0                RandomForest_a, 6.0                RandomForest_a, 7.0                RandomForest_c, 7.0                RandomForest_c, 6.0                RandomForest_c, 6.0
# 7                 RandomForest_a, 8.0                RandomForest_f, 8.0                RandomForest_d, 8.0                RandomForest_f, 8.0                RandomForest_b, 6.0                RandomForest_b, 6.0
# 8          MultiClassification_b, 9.0                         IRV_d, 9.0                RandomForest_c, 9.0         MultiClassification_b, 9.0        SingleClassification_b, 9.0                         IRV_d, 9.0
# 9                         IRV_e, 10.0                        IRV_e, 10.0         MultiClassification_b, 9.0                        IRV_e, 10.0                        IRV_d, 10.0        SingleClassification_b, 9.0
# 10        MultiClassification_a, 11.0        MultiClassification_b, 11.0                        IRV_d, 11.0                        IRV_d, 11.0       SingleClassification_a, 10.0       SingleClassification_a, 11.0
# 11                        IRV_d, 12.0       SingleClassification_a, 12.0                        IRV_e, 12.0        MultiClassification_a, 12.0                        IRV_a, 10.0                        IRV_a, 11.0
# 12       SingleClassification_b, 13.0       SingleClassification_b, 13.0                        IRV_a, 13.0       SingleClassification_b, 12.0                        IRV_e, 13.0                        IRV_e, 13.0
# 13                        IRV_c, 14.0                        IRV_b, 14.0                        IRV_c, 14.0       SingleClassification_a, 14.0        MultiClassification_b, 13.0        MultiClassification_b, 13.0
# 14                        IRV_b, 15.0        MultiClassification_a, 15.0               RandomForest_f, 15.0                        IRV_c, 15.0           SingleRegression_b, 15.0           SingleRegression_b, 15.0
# 15       SingleClassification_a, 16.0                        IRV_c, 16.0                        IRV_b, 16.0                        IRV_b, 16.0        MultiClassification_a, 16.0        MultiClassification_a, 16.0
# 16                        IRV_a, 16.0                        IRV_a, 17.0           SingleRegression_b, 17.0                        IRV_a, 17.0                        IRV_c, 17.0                        IRV_c, 17.0
# 17                       LSTM_a, 18.0             Docking_rdocktot, 18.0        MultiClassification_a, 17.0             Docking_rdocktot, 17.0                        IRV_b, 17.0                        IRV_b, 17.0
# 18                  Docking_ad4, 19.0           SingleRegression_b, 18.0                  Docking_ad4, 19.0                Docking_smina, 19.0      ConsensusDocking_median, 19.0      ConsensusDocking_median, 19.0
# 19             Docking_rdocktot, 20.0                Docking_smina, 20.0             Docking_rdocktot, 20.0                  Docking_ad4, 19.0             Docking_rdocktot, 20.0             Docking_rdocktot, 20.0
# 20                Docking_smina, 21.0                  Docking_ad4, 20.0                Docking_smina, 21.0                       LSTM_a, 21.0             Docking_rdockint, 21.0             Docking_rdockint, 21.0
# 21         ConsensusDocking_max, 22.0                       LSTM_a, 22.0      ConsensusDocking_median, 22.0             Docking_rdockint, 22.0                Docking_smina, 22.0                Docking_smina, 22.0
# 22             Docking_rdockint, 23.0             Docking_rdockint, 22.0  ConsensusDocking_rocauc_opt, 23.0           SingleRegression_b, 22.0                  Docking_ad4, 23.0                  Docking_ad4, 23.0
# 23                       LSTM_b, 23.0         ConsensusDocking_max, 24.0    ConsensusDocking_efr1_opt, 24.0               Docking_hybrid, 24.0         ConsensusDocking_max, 24.0         ConsensusDocking_max, 24.0
# 24      ConsensusDocking_median, 25.0      ConsensusDocking_median, 25.0         ConsensusDocking_max, 25.0                       LSTM_b, 24.0  ConsensusDocking_rocauc_opt, 25.0  ConsensusDocking_rocauc_opt, 25.0
# 25               Docking_hybrid, 26.0                       LSTM_b, 26.0             Docking_rdockint, 26.0         ConsensusDocking_max, 26.0        ConsensusDocking_mean, 26.0        ConsensusDocking_mean, 26.0
# 26        ConsensusDocking_mean, 27.0               Docking_hybrid, 26.0        ConsensusDocking_mean, 27.0      ConsensusDocking_median, 27.0               Docking_plants, 27.0               Docking_plants, 27.0
# 27               Docking_plants, 28.0        ConsensusDocking_mean, 28.0                       LSTM_a, 28.0        ConsensusDocking_mean, 28.0    ConsensusDocking_efr1_opt, 28.0    ConsensusDocking_efr1_opt, 28.0
# 28  ConsensusDocking_rocauc_opt, 29.0    ConsensusDocking_efr1_opt, 29.0                       LSTM_b, 29.0  ConsensusDocking_rocauc_opt, 29.0                       LSTM_b, 29.0                       LSTM_b, 29.0
# 29           SingleRegression_b, 30.0  ConsensusDocking_rocauc_opt, 30.0               Docking_hybrid, 30.0    ConsensusDocking_efr1_opt, 30.0                       LSTM_a, 30.0                       LSTM_a, 30.0
# 30    ConsensusDocking_efr1_opt, 30.0               Docking_plants, 31.0               Docking_plants, 31.0               Docking_plants, 31.0                 Docking_fred, 31.0                 Docking_fred, 31.0
# 31                 Docking_fred, 32.0                 Docking_fred, 32.0                 Docking_fred, 32.0                 Docking_fred, 32.0               Docking_hybrid, 32.0               Docking_hybrid, 32.0
# 32                Docking_dock6, 33.0                Docking_dock6, 33.0                Docking_dock6, 33.0                Docking_dock6, 33.0                Docking_dock6, 33.0                Docking_dock6, 33.0
# 33              Docking_surflex, 34.0              Docking_surflex, 34.0              Docking_surflex, 34.0              Docking_surflex, 34.0           SingleRegression_a, 34.0           SingleRegression_a, 34.0
# 34           SingleRegression_a, 35.0           SingleRegression_a, 35.0           SingleRegression_a, 35.0           SingleRegression_a, 35.0              Docking_surflex, 35.0              Docking_surflex, 35.0

# %% [markdown]
# ---
# ## Regret of best model

# %%
for m in req_metrics:
    simple_model = simple_top_n[m].iloc[0]
    simple_model = simple_model[:simple_model.index(',')]
    simple_top_n[m].iloc[0] = simple_model
    complex_model = complex_top_n[m].iloc[0]
    complex_model = complex_model[:complex_model.index(',')]
    complex_top_n[m].iloc[0] = complex_model

# %%
final_df = simple_top_n.T
final_df = pd.merge(final_df, complex_top_n.T, left_index=True, right_index=True)
final_df.columns = ['Best by Mean','Best by DTK+Mean']
final_df.columns.name = 'Metric'
final_df.index = [s.replace(' PriA-SSB FP', '') for s in final_df.index]

display(final_df)
# Out:
# Metric                        Best by Mean        Best by DTK+Mean
# ROC AUC RMI-FANCM1          RandomForest_h          RandomForest_h
# BEDROC AUC RMI-FANCM1       RandomForest_h          RandomForest_h
# PR auc.integral RMI-FANCM1  RandomForest_h  SingleClassification_b
# NEF AUC RMI-FANCM1          RandomForest_h          RandomForest_h
# NEF_1 % RMI-FANCM1          RandomForest_g          RandomForest_h
# EF_1 % RMI-FANCM1           RandomForest_g          RandomForest_h
