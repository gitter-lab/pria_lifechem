# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
from gather_metrics import *

model_directory = './job_results_small/'
class_dirs = [model_directory+'/random_forest/stage_2/',
              model_directory+'/irv/stage_2/',
              model_directory+'/light_chem/stage_2/',
              model_directory+'/neural_networks/stage_2/',
              model_directory+'/docking/stage_2/',
              model_directory+'/baseline/stage_2/']
k = 5

# %%
#setup gather matrix
gather_df = gather_dir_metrics(class_dirs[0], 1)     
gather_df = gather_df.append(gather_dir_metrics(class_dirs[1], 1))   
gather_df = gather_df.append(gather_dir_metrics(class_dirs[2], 1))   
gather_df = gather_df.append(gather_dir_metrics(class_dirs[3], 1))
gather_df = gather_df.append(gather_dir_metrics(class_dirs[4], 1))
gather_df = gather_df.append(gather_dir_metrics(class_dirs[5], 1))

col_indices = list(range(10)) + list(range(15, 20)) + list(range(25, 65)) + list(range(145, 149)) + list(range(150, 183))
col_indices = [i for i in col_indices if 'Mean' not in gather_df.columns[i] and 'Median' not in gather_df.columns[i]]
col_indices = [i for i in col_indices if 'Keck_Pria_AS_Retest' in gather_df.columns[i]]
metric_names = list(gather_df.columns.values[col_indices])

gather_df = gather_df[metric_names]
gather_df = gather_df.dropna(axis=0)

#setup comparison matrix and overlaps
mm_comp_dicts = get_mean_median_comps(gather_df, col_indices=[i for i in range(len(metric_names))])
agg_comp_dict = get_agg_comp(mm_comp_dicts, None, mean_w=1, median_w=0, tukey_w=0)
overlapping_models = get_overlap(agg_comp_dict, N=1)
# Out:
# /home/sliu426/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 185 results
#   r = func(a, **kwargs)
# /home/sliu426/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 112 results
#   r = func(a, **kwargs)
# /home/sliu426/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 5 results
#   r = func(a, **kwargs)
# /home/sliu426/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 117 results
#   r = func(a, **kwargs)
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1730: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self.ix[indexer]
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:780: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_lowerdim(tup)

# %% [markdown]
# ---
# ## Model Ordering by Metric (Best-to-Worst)
# Shows table with model-winscore pairs in the cells.

# %%
ordered_df = get_model_ordering(agg_comp_dict, metric_names)
ordered_df
# Out:
#           ROC AUC Keck_Pria_AS_Retest     BEDROC AUC Keck_Pria_AS_Retest  \
# 0                    LightChem_d, 1.0                   LightChem_b, 1.0
# 1                    LightChem_c, 2.0                   LightChem_a, 2.0
# 2                    LightChem_e, 3.0                   LightChem_d, 3.0
# 3                    LightChem_b, 4.0                   LightChem_c, 4.0
# 4                    LightChem_f, 5.0                   LightChem_f, 5.0
# 5                    LightChem_a, 6.0                   LightChem_e, 6.0
# 6             SingleRegression_a, 7.0            SingleRegression_a, 7.0
# 7             SingleRegression_b, 8.0            SingleRegression_b, 8.0
# 8                 RandomForest_c, 9.0                RandomForest_d, 9.0
# 9                RandomForest_d, 10.0               RandomForest_c, 10.0
# 10               RandomForest_a, 11.0               RandomForest_a, 11.0
# 11               RandomForest_b, 12.0               RandomForest_b, 12.0
# 12               RandomForest_g, 13.0               RandomForest_e, 13.0
# 13               RandomForest_e, 14.0               RandomForest_g, 14.0
# 14                     baseline, 15.0               RandomForest_f, 15.0
# 15               RandomForest_f, 16.0                        IRV_e, 16.0
# 16                        IRV_e, 17.0                     baseline, 17.0
# 17        MultiClassification_b, 18.0                        IRV_d, 18.0
# 18        MultiClassification_a, 19.0        MultiClassification_a, 19.0
# 19                        IRV_d, 20.0        MultiClassification_b, 20.0
# 20       SingleClassification_b, 21.0       SingleClassification_b, 21.0
# 21                        IRV_c, 22.0                        IRV_c, 22.0
# 22       SingleClassification_a, 23.0       SingleClassification_a, 23.0
# 23                        IRV_b, 24.0                        IRV_b, 24.0
# 24             Docking_rdocktot, 25.0                        IRV_a, 25.0
# 25                        IRV_a, 26.0             Docking_rdocktot, 26.0
# 26                       LSTM_b, 27.0                       LSTM_b, 27.0
# 27                       LSTM_a, 28.0                Docking_dock6, 28.0
# 28         ConsensusDocking_max, 29.0                       LSTM_a, 29.0
# 29  ConsensusDocking_rocauc_opt, 30.0         ConsensusDocking_max, 30.0
# 30    ConsensusDocking_efr1_opt, 31.0               Docking_hybrid, 31.0
# 31                Docking_dock6, 32.0             Docking_rdockint, 32.0
# 32             Docking_rdockint, 33.0              Docking_surflex, 33.0
# 33        ConsensusDocking_mean, 34.0  ConsensusDocking_rocauc_opt, 34.0
# 34              Docking_surflex, 35.0    ConsensusDocking_efr1_opt, 35.0
# 35      ConsensusDocking_median, 36.0        ConsensusDocking_mean, 36.0
# 36               Docking_plants, 37.0                 Docking_fred, 37.0
# 37               Docking_hybrid, 38.0      ConsensusDocking_median, 38.0
# 38                 Docking_fred, 39.0               Docking_plants, 39.0
# 39                Docking_smina, 40.0                  Docking_ad4, 40.0
# 40                  Docking_ad4, 41.0                Docking_smina, 41.0
#
#    PR auc.integral Keck_Pria_AS_Retest      NEF_0.1 % Keck_Pria_AS_Retest  \
# 0                     LightChem_b, 1.0                   LightChem_a, 1.0
# 1                     LightChem_a, 2.0        SingleClassification_b, 1.0
# 2                     LightChem_d, 3.0                   LightChem_b, 1.0
# 3                     LightChem_f, 4.0                   LightChem_e, 1.0
# 4                     LightChem_e, 5.0                   LightChem_f, 1.0
# 5                     LightChem_c, 6.0                RandomForest_d, 1.0
# 6                  RandomForest_c, 7.0                RandomForest_c, 1.0
# 7                  RandomForest_d, 8.0         MultiClassification_a, 8.0
# 8                  RandomForest_a, 9.0                RandomForest_b, 9.0
# 9                 RandomForest_b, 10.0                   LightChem_d, 9.0
# 10                RandomForest_e, 11.0                RandomForest_a, 9.0
# 11                RandomForest_g, 12.0                RandomForest_e, 9.0
# 12                RandomForest_f, 13.0                RandomForest_f, 9.0
# 13            SingleRegression_b, 14.0                RandomForest_g, 9.0
# 14        SingleClassification_b, 15.0        MultiClassification_b, 15.0
# 15            SingleRegression_a, 16.0                  LightChem_c, 15.0
# 16         MultiClassification_b, 17.0           SingleRegression_b, 17.0
# 17                         IRV_e, 18.0                        IRV_c, 17.0
# 18         MultiClassification_a, 19.0                        IRV_e, 17.0
# 19                         IRV_d, 20.0                        IRV_d, 20.0
# 20                         IRV_c, 21.0                        IRV_b, 20.0
# 21                      baseline, 22.0       SingleClassification_a, 20.0
# 22        SingleClassification_a, 23.0           SingleRegression_a, 20.0
# 23                         IRV_b, 24.0                        IRV_a, 24.0
# 24                         IRV_a, 25.0                     baseline, 25.0
# 25              Docking_rdocktot, 26.0                Docking_dock6, 26.0
# 26                 Docking_dock6, 27.0             Docking_rdockint, 26.0
# 27                        LSTM_b, 28.0                       LSTM_b, 26.0
# 28                        LSTM_a, 29.0                Docking_smina, 29.0
# 29          ConsensusDocking_max, 30.0             Docking_rdocktot, 29.0
# 30              Docking_rdockint, 31.0              Docking_surflex, 29.0
# 31   ConsensusDocking_rocauc_opt, 32.0               Docking_plants, 29.0
# 32     ConsensusDocking_efr1_opt, 33.0               Docking_hybrid, 29.0
# 33               Docking_surflex, 34.0                 Docking_fred, 29.0
# 34                Docking_hybrid, 35.0                       LSTM_a, 29.0
# 35         ConsensusDocking_mean, 36.0                  Docking_ad4, 29.0
# 36       ConsensusDocking_median, 37.0  ConsensusDocking_rocauc_opt, 29.0
# 37                  Docking_fred, 38.0      ConsensusDocking_median, 29.0
# 38                Docking_plants, 39.0        ConsensusDocking_mean, 29.0
# 39                   Docking_ad4, 40.0         ConsensusDocking_max, 29.0
# 40                 Docking_smina, 41.0    ConsensusDocking_efr1_opt, 29.0
#
#        NEF_0.15 % Keck_Pria_AS_Retest      NEF_0.5 % Keck_Pria_AS_Retest  \
# 0                 RandomForest_d, 1.0                   LightChem_a, 1.0
# 1                    LightChem_b, 1.0                   LightChem_d, 2.0
# 2                 RandomForest_c, 3.0                   LightChem_c, 3.0
# 3                    LightChem_f, 4.0                   LightChem_b, 4.0
# 4         SingleClassification_b, 4.0                   LightChem_e, 4.0
# 5                    LightChem_a, 6.0                   LightChem_f, 6.0
# 6                    LightChem_e, 6.0                RandomForest_d, 7.0
# 7                    LightChem_d, 8.0                RandomForest_c, 7.0
# 8                 RandomForest_g, 9.0                RandomForest_f, 9.0
# 9                 RandomForest_e, 9.0               RandomForest_g, 10.0
# 10                RandomForest_b, 9.0               RandomForest_e, 10.0
# 11                RandomForest_a, 9.0               RandomForest_b, 10.0
# 12         MultiClassification_a, 9.0               RandomForest_a, 10.0
# 13               RandomForest_f, 14.0       SingleClassification_b, 14.0
# 14                  LightChem_c, 14.0           SingleRegression_b, 15.0
# 15                        IRV_e, 16.0                        IRV_d, 16.0
# 16        MultiClassification_b, 16.0                        IRV_e, 16.0
# 17           SingleRegression_a, 16.0                        IRV_c, 16.0
# 18                        IRV_c, 19.0                     baseline, 16.0
# 19           SingleRegression_b, 19.0           SingleRegression_a, 16.0
# 20                        IRV_d, 19.0        MultiClassification_b, 21.0
# 21       SingleClassification_a, 22.0        MultiClassification_a, 22.0
# 22                        IRV_a, 23.0                        IRV_b, 23.0
# 23                        IRV_b, 23.0       SingleClassification_a, 24.0
# 24                     baseline, 25.0                        IRV_a, 25.0
# 25                  Docking_ad4, 26.0                Docking_dock6, 26.0
# 26             Docking_rdockint, 27.0                 Docking_fred, 27.0
# 27                Docking_dock6, 27.0                  Docking_ad4, 28.0
# 28                       LSTM_b, 27.0               Docking_hybrid, 29.0
# 29             Docking_rdocktot, 30.0         ConsensusDocking_max, 29.0
# 30                Docking_smina, 30.0      ConsensusDocking_median, 29.0
# 31               Docking_plants, 30.0                       LSTM_b, 29.0
# 32               Docking_hybrid, 30.0             Docking_rdockint, 29.0
# 33                 Docking_fred, 30.0              Docking_surflex, 29.0
# 34              Docking_surflex, 30.0               Docking_plants, 35.0
# 35                       LSTM_a, 30.0             Docking_rdocktot, 35.0
# 36  ConsensusDocking_rocauc_opt, 30.0                Docking_smina, 35.0
# 37      ConsensusDocking_median, 30.0  ConsensusDocking_rocauc_opt, 35.0
# 38        ConsensusDocking_mean, 30.0        ConsensusDocking_mean, 35.0
# 39         ConsensusDocking_max, 30.0                       LSTM_a, 35.0
# 40    ConsensusDocking_efr1_opt, 30.0    ConsensusDocking_efr1_opt, 35.0
#
#           NEF_1 % Keck_Pria_AS_Retest        NEF_2 % Keck_Pria_AS_Retest  \
# 0                    LightChem_a, 1.0                   LightChem_a, 1.0
# 1                    LightChem_d, 2.0                   LightChem_c, 2.0
# 2                    LightChem_b, 2.0                   LightChem_b, 2.0
# 3                    LightChem_c, 4.0                   LightChem_d, 4.0
# 4                    LightChem_f, 4.0                   LightChem_f, 5.0
# 5                    LightChem_e, 6.0                   LightChem_e, 6.0
# 6                 RandomForest_c, 7.0            SingleRegression_a, 7.0
# 7                 RandomForest_d, 8.0                RandomForest_c, 8.0
# 8                 RandomForest_g, 9.0            SingleRegression_b, 8.0
# 9                 RandomForest_f, 9.0                RandomForest_d, 8.0
# 10                RandomForest_e, 9.0               RandomForest_f, 11.0
# 11                RandomForest_b, 9.0               RandomForest_e, 11.0
# 12               RandomForest_a, 13.0               RandomForest_g, 11.0
# 13           SingleRegression_a, 14.0               RandomForest_b, 11.0
# 14           SingleRegression_b, 14.0               RandomForest_a, 15.0
# 15       SingleClassification_b, 16.0                        IRV_e, 16.0
# 16                     baseline, 17.0                        IRV_d, 16.0
# 17        MultiClassification_b, 18.0                     baseline, 18.0
# 18                        IRV_e, 19.0                        IRV_c, 19.0
# 19                        IRV_d, 19.0       SingleClassification_b, 20.0
# 20                        IRV_c, 19.0        MultiClassification_b, 21.0
# 21                        IRV_b, 22.0        MultiClassification_a, 22.0
# 22        MultiClassification_a, 22.0       SingleClassification_a, 23.0
# 23       SingleClassification_a, 24.0                        IRV_b, 24.0
# 24                        IRV_a, 25.0                        IRV_a, 25.0
# 25                Docking_dock6, 26.0               Docking_hybrid, 26.0
# 26         ConsensusDocking_max, 27.0                Docking_dock6, 26.0
# 27      ConsensusDocking_median, 27.0         ConsensusDocking_max, 28.0
# 28             Docking_rdocktot, 27.0  ConsensusDocking_rocauc_opt, 28.0
# 29             Docking_rdockint, 27.0                 Docking_fred, 28.0
# 30               Docking_hybrid, 27.0                       LSTM_b, 28.0
# 31                 Docking_fred, 27.0             Docking_rdockint, 28.0
# 32                  Docking_ad4, 33.0             Docking_rdocktot, 28.0
# 33        ConsensusDocking_mean, 34.0    ConsensusDocking_efr1_opt, 28.0
# 34                       LSTM_b, 34.0      ConsensusDocking_median, 35.0
# 35               Docking_plants, 34.0        ConsensusDocking_mean, 35.0
# 36              Docking_surflex, 34.0                  Docking_ad4, 37.0
# 37                       LSTM_a, 34.0               Docking_plants, 38.0
# 38  ConsensusDocking_rocauc_opt, 39.0                Docking_smina, 38.0
# 39                Docking_smina, 39.0              Docking_surflex, 38.0
# 40    ConsensusDocking_efr1_opt, 39.0                       LSTM_a, 38.0
#
#           NEF_5 % Keck_Pria_AS_Retest       NEF_10 % Keck_Pria_AS_Retest  \
# 0                    LightChem_a, 1.0                   LightChem_d, 1.0
# 1                    LightChem_f, 2.0                   LightChem_e, 1.0
# 2                    LightChem_d, 2.0                   LightChem_f, 1.0
# 3                    LightChem_b, 2.0                   LightChem_b, 1.0
# 4                    LightChem_c, 2.0                   LightChem_c, 1.0
# 5                    LightChem_e, 6.0                   LightChem_a, 6.0
# 6             SingleRegression_b, 7.0            SingleRegression_a, 7.0
# 7             SingleRegression_a, 8.0            SingleRegression_b, 8.0
# 8                          IRV_e, 9.0                RandomForest_c, 9.0
# 9                RandomForest_f, 10.0               RandomForest_a, 10.0
# 10               RandomForest_d, 10.0               RandomForest_d, 10.0
# 11               RandomForest_g, 12.0               RandomForest_b, 12.0
# 12               RandomForest_c, 12.0               RandomForest_f, 13.0
# 13               RandomForest_b, 12.0               RandomForest_g, 13.0
# 14               RandomForest_e, 15.0                        IRV_e, 13.0
# 15               RandomForest_a, 15.0               RandomForest_e, 16.0
# 16                     baseline, 17.0                     baseline, 17.0
# 17                        IRV_d, 18.0        MultiClassification_a, 18.0
# 18        MultiClassification_a, 19.0                        IRV_d, 19.0
# 19        MultiClassification_b, 19.0       SingleClassification_b, 20.0
# 20       SingleClassification_b, 21.0        MultiClassification_b, 21.0
# 21                        IRV_c, 21.0                        IRV_c, 22.0
# 22       SingleClassification_a, 23.0       SingleClassification_a, 23.0
# 23                        IRV_b, 24.0                        IRV_b, 24.0
# 24                        IRV_a, 25.0                        IRV_a, 25.0
# 25         ConsensusDocking_max, 26.0             Docking_rdocktot, 26.0
# 26             Docking_rdocktot, 27.0                       LSTM_b, 27.0
# 27                Docking_dock6, 28.0                Docking_dock6, 28.0
# 28               Docking_hybrid, 28.0                       LSTM_a, 29.0
# 29                       LSTM_b, 28.0               Docking_hybrid, 30.0
# 30              Docking_surflex, 31.0              Docking_surflex, 31.0
# 31               Docking_plants, 32.0             Docking_rdockint, 31.0
# 32                 Docking_fred, 32.0         ConsensusDocking_max, 31.0
# 33  ConsensusDocking_rocauc_opt, 32.0  ConsensusDocking_rocauc_opt, 34.0
# 34        ConsensusDocking_mean, 32.0        ConsensusDocking_mean, 34.0
# 35    ConsensusDocking_efr1_opt, 32.0    ConsensusDocking_efr1_opt, 36.0
# 36             Docking_rdockint, 37.0               Docking_plants, 37.0
# 37                Docking_smina, 37.0      ConsensusDocking_median, 37.0
# 38                       LSTM_a, 37.0                 Docking_fred, 39.0
# 39                  Docking_ad4, 40.0                  Docking_ad4, 40.0
# 40      ConsensusDocking_median, 41.0                Docking_smina, 41.0
#
#          NEF_20 % Keck_Pria_AS_Retest        NEF AUC Keck_Pria_AS_Retest  \
# 0                    LightChem_f, 1.0                   LightChem_f, 1.0
# 1                    LightChem_e, 1.0                   LightChem_d, 2.0
# 2                    LightChem_c, 3.0                   LightChem_c, 3.0
# 3                    LightChem_d, 3.0                   LightChem_a, 4.0
# 4                    LightChem_a, 5.0                   LightChem_b, 5.0
# 5                    LightChem_b, 5.0                   LightChem_e, 6.0
# 6             SingleRegression_a, 7.0            SingleRegression_a, 7.0
# 7             SingleRegression_b, 8.0            SingleRegression_b, 8.0
# 8                 RandomForest_e, 9.0                RandomForest_c, 9.0
# 9                 RandomForest_a, 9.0               RandomForest_d, 10.0
# 10               RandomForest_d, 11.0               RandomForest_a, 11.0
# 11               RandomForest_c, 11.0               RandomForest_b, 12.0
# 12               RandomForest_b, 11.0               RandomForest_f, 13.0
# 13                     baseline, 14.0               RandomForest_e, 14.0
# 14               RandomForest_f, 14.0               RandomForest_g, 15.0
# 15               RandomForest_g, 14.0                        IRV_e, 16.0
# 16                        IRV_e, 17.0                     baseline, 17.0
# 17        MultiClassification_a, 18.0                        IRV_d, 18.0
# 18        MultiClassification_b, 19.0        MultiClassification_a, 19.0
# 19                        IRV_d, 19.0        MultiClassification_b, 20.0
# 20       SingleClassification_b, 21.0       SingleClassification_b, 21.0
# 21       SingleClassification_a, 22.0                        IRV_c, 22.0
# 22                        IRV_c, 22.0       SingleClassification_a, 23.0
# 23             Docking_rdocktot, 24.0                        IRV_b, 24.0
# 24                        IRV_b, 25.0                        IRV_a, 25.0
# 25                       LSTM_a, 26.0             Docking_rdocktot, 26.0
# 26                        IRV_a, 27.0                       LSTM_b, 27.0
# 27             Docking_rdockint, 28.0                Docking_dock6, 28.0
# 28                       LSTM_b, 28.0                       LSTM_a, 29.0
# 29                Docking_dock6, 30.0         ConsensusDocking_max, 30.0
# 30              Docking_surflex, 31.0               Docking_hybrid, 31.0
# 31  ConsensusDocking_rocauc_opt, 31.0             Docking_rdockint, 32.0
# 32    ConsensusDocking_efr1_opt, 31.0              Docking_surflex, 33.0
# 33         ConsensusDocking_max, 34.0  ConsensusDocking_rocauc_opt, 34.0
# 34               Docking_hybrid, 35.0    ConsensusDocking_efr1_opt, 35.0
# 35      ConsensusDocking_median, 35.0      ConsensusDocking_median, 36.0
# 36                 Docking_fred, 37.0        ConsensusDocking_mean, 37.0
# 37        ConsensusDocking_mean, 37.0                 Docking_fred, 38.0
# 38                  Docking_ad4, 39.0               Docking_plants, 39.0
# 39               Docking_plants, 40.0                  Docking_ad4, 40.0
# 40                Docking_smina, 41.0                Docking_smina, 41.0
#
#        n_hits_100 Keck_Pria_AS_Retest     n_hits_250 Keck_Pria_AS_Retest  \
# 0                    LightChem_a, 1.0                   LightChem_a, 1.0
# 1                    LightChem_d, 1.0                   LightChem_d, 2.0
# 2                    LightChem_c, 3.0                   LightChem_b, 2.0
# 3                    LightChem_b, 4.0                   LightChem_c, 4.0
# 4                    LightChem_f, 5.0                   LightChem_f, 4.0
# 5                    LightChem_e, 6.0                   LightChem_e, 6.0
# 6                 RandomForest_c, 7.0                RandomForest_c, 7.0
# 7                 RandomForest_d, 7.0                RandomForest_d, 8.0
# 8                 RandomForest_a, 9.0                RandomForest_g, 9.0
# 9                 RandomForest_b, 9.0                RandomForest_f, 9.0
# 10               RandomForest_e, 11.0                RandomForest_e, 9.0
# 11               RandomForest_f, 12.0                RandomForest_b, 9.0
# 12               RandomForest_g, 12.0               RandomForest_a, 13.0
# 13       SingleClassification_b, 14.0           SingleRegression_a, 14.0
# 14           SingleRegression_a, 15.0           SingleRegression_b, 14.0
# 15        MultiClassification_b, 16.0       SingleClassification_b, 16.0
# 16           SingleRegression_b, 17.0                     baseline, 17.0
# 17                        IRV_e, 18.0        MultiClassification_b, 18.0
# 18        MultiClassification_a, 18.0                        IRV_e, 19.0
# 19                        IRV_d, 18.0                        IRV_d, 19.0
# 20                        IRV_c, 18.0                        IRV_c, 19.0
# 21                     baseline, 22.0                        IRV_b, 22.0
# 22       SingleClassification_a, 23.0        MultiClassification_a, 22.0
# 23                        IRV_a, 24.0       SingleClassification_a, 24.0
# 24                        IRV_b, 25.0                        IRV_a, 25.0
# 25                Docking_dock6, 26.0                Docking_dock6, 26.0
# 26         ConsensusDocking_max, 27.0         ConsensusDocking_max, 27.0
# 27               Docking_hybrid, 27.0      ConsensusDocking_median, 27.0
# 28      ConsensusDocking_median, 27.0             Docking_rdocktot, 27.0
# 29                  Docking_ad4, 27.0             Docking_rdockint, 27.0
# 30                 Docking_fred, 27.0               Docking_hybrid, 27.0
# 31                       LSTM_b, 27.0                 Docking_fred, 27.0
# 32             Docking_rdockint, 27.0        ConsensusDocking_mean, 33.0
# 33              Docking_surflex, 27.0                  Docking_ad4, 33.0
# 34               Docking_plants, 35.0                       LSTM_b, 33.0
# 35             Docking_rdocktot, 35.0               Docking_plants, 33.0
# 36                Docking_smina, 35.0              Docking_surflex, 33.0
# 37  ConsensusDocking_rocauc_opt, 35.0                       LSTM_a, 33.0
# 38        ConsensusDocking_mean, 35.0  ConsensusDocking_rocauc_opt, 39.0
# 39                       LSTM_a, 35.0                Docking_smina, 39.0
# 40    ConsensusDocking_efr1_opt, 35.0    ConsensusDocking_efr1_opt, 39.0
#
#        n_hits_500 Keck_Pria_AS_Retest    n_hits_1000 Keck_Pria_AS_Retest  \
# 0                    LightChem_a, 1.0                   LightChem_b, 1.0
# 1                    LightChem_b, 2.0                   LightChem_a, 2.0
# 2                    LightChem_c, 3.0                   LightChem_d, 3.0
# 3                    LightChem_d, 4.0                   LightChem_c, 4.0
# 4                    LightChem_f, 5.0                   LightChem_f, 5.0
# 5                    LightChem_e, 6.0                   LightChem_e, 6.0
# 6             SingleRegression_a, 7.0            SingleRegression_b, 7.0
# 7                 RandomForest_c, 8.0            SingleRegression_a, 8.0
# 8             SingleRegression_b, 8.0                RandomForest_b, 9.0
# 9                 RandomForest_d, 8.0               RandomForest_f, 10.0
# 10               RandomForest_f, 11.0                        IRV_e, 10.0
# 11               RandomForest_e, 11.0               RandomForest_e, 12.0
# 12               RandomForest_g, 11.0               RandomForest_c, 12.0
# 13               RandomForest_b, 11.0               RandomForest_a, 12.0
# 14               RandomForest_a, 15.0               RandomForest_d, 12.0
# 15                        IRV_e, 16.0               RandomForest_g, 16.0
# 16                        IRV_d, 17.0                        IRV_d, 17.0
# 17                     baseline, 18.0                     baseline, 17.0
# 18                        IRV_c, 19.0        MultiClassification_a, 19.0
# 19       SingleClassification_b, 20.0        MultiClassification_b, 19.0
# 20        MultiClassification_b, 21.0       SingleClassification_a, 21.0
# 21        MultiClassification_a, 22.0       SingleClassification_b, 21.0
# 22       SingleClassification_a, 23.0                        IRV_c, 21.0
# 23                        IRV_b, 24.0                        IRV_b, 24.0
# 24                        IRV_a, 25.0                        IRV_a, 25.0
# 25               Docking_hybrid, 26.0         ConsensusDocking_max, 26.0
# 26                Docking_dock6, 26.0             Docking_rdocktot, 27.0
# 27         ConsensusDocking_max, 28.0               Docking_hybrid, 27.0
# 28  ConsensusDocking_rocauc_opt, 28.0                Docking_dock6, 29.0
# 29                 Docking_fred, 28.0                       LSTM_b, 29.0
# 30                       LSTM_b, 28.0                 Docking_fred, 31.0
# 31             Docking_rdockint, 28.0              Docking_surflex, 31.0
# 32             Docking_rdocktot, 28.0  ConsensusDocking_rocauc_opt, 31.0
# 33    ConsensusDocking_efr1_opt, 28.0    ConsensusDocking_efr1_opt, 31.0
# 34      ConsensusDocking_median, 35.0             Docking_rdockint, 35.0
# 35        ConsensusDocking_mean, 35.0               Docking_plants, 35.0
# 36               Docking_plants, 37.0                Docking_smina, 35.0
# 37                Docking_smina, 37.0        ConsensusDocking_mean, 35.0
# 38                  Docking_ad4, 37.0                  Docking_ad4, 39.0
# 39              Docking_surflex, 37.0      ConsensusDocking_median, 39.0
# 40                       LSTM_a, 37.0                       LSTM_a, 39.0
#
#       n_hits_2500 Keck_Pria_AS_Retest    n_hits_5000 Keck_Pria_AS_Retest  \
# 0                    LightChem_d, 1.0                   LightChem_e, 1.0
# 1                    LightChem_e, 1.0                   LightChem_f, 2.0
# 2                    LightChem_b, 1.0                   LightChem_c, 3.0
# 3                    LightChem_c, 1.0                   LightChem_d, 3.0
# 4                    LightChem_f, 5.0                   LightChem_a, 5.0
# 5                    LightChem_a, 5.0                   LightChem_b, 5.0
# 6             SingleRegression_a, 7.0            SingleRegression_a, 7.0
# 7             SingleRegression_b, 8.0            SingleRegression_b, 8.0
# 8                 RandomForest_a, 9.0                RandomForest_e, 9.0
# 9                 RandomForest_d, 9.0                RandomForest_a, 9.0
# 10               RandomForest_b, 11.0               RandomForest_d, 11.0
# 11               RandomForest_c, 11.0               RandomForest_c, 11.0
# 12               RandomForest_f, 13.0               RandomForest_b, 11.0
# 13               RandomForest_g, 13.0                     baseline, 14.0
# 14                        IRV_e, 13.0               RandomForest_f, 14.0
# 15               RandomForest_e, 16.0               RandomForest_g, 14.0
# 16                     baseline, 17.0                        IRV_e, 17.0
# 17        MultiClassification_a, 18.0        MultiClassification_a, 18.0
# 18                        IRV_d, 19.0        MultiClassification_b, 19.0
# 19       SingleClassification_b, 20.0                        IRV_d, 19.0
# 20        MultiClassification_b, 21.0       SingleClassification_b, 21.0
# 21                        IRV_c, 22.0       SingleClassification_a, 22.0
# 22       SingleClassification_a, 23.0                        IRV_c, 23.0
# 23                        IRV_b, 24.0             Docking_rdocktot, 24.0
# 24                        IRV_a, 25.0                        IRV_b, 25.0
# 25             Docking_rdocktot, 26.0                       LSTM_a, 26.0
# 26                       LSTM_b, 27.0                        IRV_a, 27.0
# 27                Docking_dock6, 28.0             Docking_rdockint, 28.0
# 28                       LSTM_a, 29.0                       LSTM_b, 28.0
# 29               Docking_hybrid, 30.0                Docking_dock6, 30.0
# 30              Docking_surflex, 31.0  ConsensusDocking_rocauc_opt, 31.0
# 31         ConsensusDocking_max, 31.0    ConsensusDocking_efr1_opt, 31.0
# 32             Docking_rdockint, 33.0              Docking_surflex, 33.0
# 33  ConsensusDocking_rocauc_opt, 34.0         ConsensusDocking_max, 33.0
# 34        ConsensusDocking_mean, 34.0      ConsensusDocking_median, 35.0
# 35    ConsensusDocking_efr1_opt, 36.0               Docking_hybrid, 36.0
# 36               Docking_plants, 37.0                 Docking_fred, 37.0
# 37      ConsensusDocking_median, 37.0        ConsensusDocking_mean, 37.0
# 38                 Docking_fred, 39.0                  Docking_ad4, 39.0
# 39                Docking_smina, 40.0               Docking_plants, 40.0
# 40                  Docking_ad4, 40.0                Docking_smina, 41.0
#
#      n_hits_10000 Keck_Pria_AS_Retest
# 0                    LightChem_d, 1.0
# 1                    LightChem_c, 1.0
# 2                    LightChem_f, 3.0
# 3                    LightChem_e, 4.0
# 4                    LightChem_b, 4.0
# 5                    LightChem_a, 6.0
# 6             SingleRegression_b, 7.0
# 7             SingleRegression_a, 8.0
# 8                 RandomForest_c, 9.0
# 9                      baseline, 10.0
# 10               RandomForest_d, 10.0
# 11               RandomForest_b, 12.0
# 12               RandomForest_e, 12.0
# 13               RandomForest_g, 12.0
# 14               RandomForest_a, 15.0
# 15                        IRV_e, 15.0
# 16               RandomForest_f, 17.0
# 17        MultiClassification_b, 18.0
# 18        MultiClassification_a, 18.0
# 19                        IRV_d, 20.0
# 20       SingleClassification_b, 21.0
# 21                        IRV_c, 22.0
# 22       SingleClassification_a, 23.0
# 23             Docking_rdocktot, 23.0
# 24                       LSTM_b, 25.0
# 25                        IRV_b, 26.0
# 26                       LSTM_a, 27.0
# 27                Docking_dock6, 27.0
# 28             Docking_rdockint, 29.0
# 29                        IRV_a, 30.0
# 30  ConsensusDocking_rocauc_opt, 30.0
# 31         ConsensusDocking_max, 30.0
# 32    ConsensusDocking_efr1_opt, 30.0
# 33              Docking_surflex, 34.0
# 34        ConsensusDocking_mean, 34.0
# 35      ConsensusDocking_median, 36.0
# 36               Docking_plants, 37.0
# 37               Docking_hybrid, 38.0
# 38                 Docking_fred, 38.0
# 39                  Docking_ad4, 40.0
# 40                Docking_smina, 41.0

# %% [markdown]
# ---
# ## Metrics Most Similar to N-Hits

# %%
get_similar_to_nhits(agg_comp_dict, metric_names[:-7], metric_names[-7:])
# Out:
#    n_hits_100 Keck_Pria_AS_Retest n_hits_250 Keck_Pria_AS_Retest  \
# 0                       NEF_0.5 %                        NEF_1 %
# 1                         NEF_1 %                      NEF_0.5 %
# 2                       NEF_0.1 %                        NEF_2 %
# 3                 PR auc.integral     PR auc.integral, NEF_0.1 %
# 4                         NEF_2 %                        NEF_5 %
# 5                      NEF_0.15 %         BEDROC AUC, NEF_0.15 %
# 6            BEDROC AUC, NEF_10 %                       NEF_10 %
# 7                         NEF AUC                        NEF AUC
# 8                         NEF_5 %                       NEF_20 %
# 9                        NEF_20 %                        ROC AUC
# 10                        ROC AUC
# 11
#
#    n_hits_500 Keck_Pria_AS_Retest n_hits_1000 Keck_Pria_AS_Retest  \
# 0                         NEF_2 %                         NEF_5 %
# 1                         NEF_5 %                         NEF_2 %
# 2                      BEDROC AUC                      BEDROC AUC
# 3                         NEF_1 %                        NEF_10 %
# 4                        NEF_10 %                         NEF AUC
# 5                       NEF_0.5 %                         NEF_1 %
# 6                         NEF AUC                        NEF_20 %
# 7                        NEF_20 %                         ROC AUC
# 8                         ROC AUC                       NEF_0.5 %
# 9                 PR auc.integral                 PR auc.integral
# 10                      NEF_0.1 %                       NEF_0.1 %
# 11                     NEF_0.15 %                      NEF_0.15 %
#
#    n_hits_2500 Keck_Pria_AS_Retest n_hits_5000 Keck_Pria_AS_Retest  \
# 0                         NEF_10 %                        NEF_20 %
# 1                       BEDROC AUC                        NEF_10 %
# 2                          NEF AUC                ROC AUC, NEF AUC
# 3                          ROC AUC                      BEDROC AUC
# 4                         NEF_20 %                         NEF_2 %
# 5                          NEF_5 %                 PR auc.integral
# 6                          NEF_2 %                         NEF_5 %
# 7                  PR auc.integral                       NEF_0.1 %
# 8                        NEF_0.5 %                       NEF_0.5 %
# 9                          NEF_1 %                         NEF_1 %
# 10                       NEF_0.1 %                      NEF_0.15 %
# 11                      NEF_0.15 %
#
#    n_hits_10000 Keck_Pria_AS_Retest
# 0                           ROC AUC
# 1                          NEF_20 %
# 2                          NEF_10 %
# 3                           NEF AUC
# 4                        BEDROC AUC
# 5                           NEF_2 %
# 6                           NEF_5 %
# 7                   PR auc.integral
# 8                         NEF_0.1 %
# 9                           NEF_1 %
# 10                        NEF_0.5 %
# 11                       NEF_0.15 %

# %% [markdown]
# ---
# ## Overlapping top 1 models over all metrics

# %%
overlapping_models
# Out:
#                 overlap_perc
# LightChem_a         0.421053
# LightChem_d         0.210526
# LightChem_b         0.157895
# LightChem_f         0.105263
# LightChem_e         0.052632
# RandomForest_d      0.052632

# %%
get_overlap(agg_comp_dict, N=5)
# Out:
#                         overlap_perc
# LightChem_f                 0.947368
# LightChem_b                 0.894737
# LightChem_d                 0.894737
# LightChem_c                 0.842105
# LightChem_a                 0.736842
# LightChem_e                 0.473684
# SingleClassification_b      0.105263
# RandomForest_c              0.052632
# RandomForest_d              0.052632

# %% [markdown]
# ## Spearman's Rank-order correlation coefficient

# %%
spearman_df, ordered_spearman_df = get_spearman_r(agg_comp_dict, metric_names[:-7], metric_names[-7:])

# %%
ordered_spearman_df
# Out:
#    n_hits_100 Keck_Pria_AS_Retest n_hits_250 Keck_Pria_AS_Retest  \
# 0                       NEF_0.5 %                        NEF_1 %
# 1                         NEF_1 %                      NEF_0.5 %
# 2                 PR auc.integral                        NEF_2 %
# 3                         NEF_2 %                PR auc.integral
# 4                      NEF_0.15 %                     BEDROC AUC
# 5                         NEF AUC                        NEF AUC
# 6                      BEDROC AUC                       NEF_10 %
# 7                       NEF_0.1 %                        NEF_5 %
# 8                        NEF_10 %                       NEF_20 %
# 9                         NEF_5 %                        ROC AUC
# 10                       NEF_20 %                     NEF_0.15 %
# 11                        ROC AUC                      NEF_0.1 %
#
#    n_hits_500 Keck_Pria_AS_Retest n_hits_1000 Keck_Pria_AS_Retest  \
# 0                         NEF_2 %                         NEF_5 %
# 1                      BEDROC AUC                         NEF_2 %
# 2                         NEF_5 %                      BEDROC AUC
# 3                         NEF AUC                         NEF AUC
# 4                        NEF_10 %                        NEF_10 %
# 5                         NEF_1 %                         ROC AUC
# 6                 PR auc.integral                        NEF_20 %
# 7                         ROC AUC                 PR auc.integral
# 8                        NEF_20 %                         NEF_1 %
# 9                       NEF_0.5 %                       NEF_0.5 %
# 10                     NEF_0.15 %                       NEF_0.1 %
# 11                      NEF_0.1 %                      NEF_0.15 %
#
#    n_hits_2500 Keck_Pria_AS_Retest n_hits_5000 Keck_Pria_AS_Retest  \
# 0                         NEF_10 %                        NEF_20 %
# 1                       BEDROC AUC                         ROC AUC
# 2                          NEF AUC                         NEF AUC
# 3                          ROC AUC                      BEDROC AUC
# 4                         NEF_20 %                        NEF_10 %
# 5                          NEF_5 %                 PR auc.integral
# 6                  PR auc.integral                         NEF_2 %
# 7                          NEF_2 %                         NEF_5 %
# 8                          NEF_1 %                         NEF_1 %
# 9                        NEF_0.5 %                       NEF_0.5 %
# 10                      NEF_0.15 %                       NEF_0.1 %
# 11                       NEF_0.1 %                      NEF_0.15 %
#
#    n_hits_10000 Keck_Pria_AS_Retest
# 0                           ROC AUC
# 1                          NEF_20 %
# 2                           NEF AUC
# 3                        BEDROC AUC
# 4                          NEF_10 %
# 5                   PR auc.integral
# 6                           NEF_5 %
# 7                           NEF_2 %
# 8                           NEF_1 %
# 9                         NEF_0.5 %
# 10                       NEF_0.15 %
# 11                        NEF_0.1 %

# %%
spearman_df
# Out:
#                  n_hits_100 Keck_Pria_AS_Retest  \
# ROC AUC                                0.905046
# BEDROC AUC                             0.931794
# PR auc.integral                        0.949859
# NEF_0.1 %                              0.926658
# NEF_0.15 %                             0.940026
# NEF_0.5 %                              0.989156
# NEF_1 %                                0.977699
# NEF_2 %                                0.946136
# NEF_5 %                                0.914949
# NEF_10 %                               0.925019
# NEF_20 %                               0.909298
# NEF AUC                                0.931881
#
#                  n_hits_250 Keck_Pria_AS_Retest  \
# ROC AUC                                0.922782
# BEDROC AUC                             0.947970
# PR auc.integral                        0.955929
# NEF_0.1 %                              0.905464
# NEF_0.15 %                             0.909873
# NEF_0.5 %                              0.976128
# NEF_1 %                                0.999342
# NEF_2 %                                0.959621
# NEF_5 %                                0.931428
# NEF_10 %                               0.940188
# NEF_20 %                               0.925071
# NEF AUC                                0.946920
#
#                  n_hits_500 Keck_Pria_AS_Retest  \
# ROC AUC                                0.950594
# BEDROC AUC                             0.971409
# PR auc.integral                        0.952168
# NEF_0.1 %                              0.873397
# NEF_0.15 %                             0.877580
# NEF_0.5 %                              0.943901
# NEF_1 %                                0.958098
# NEF_2 %                                0.999473
# NEF_5 %                                0.967752
# NEF_10 %                               0.961951
# NEF_20 %                               0.945337
# NEF AUC                                0.967648
#
#                  n_hits_1000 Keck_Pria_AS_Retest  \
# ROC AUC                                 0.949515
# BEDROC AUC                              0.969675
# PR auc.integral                         0.940264
# NEF_0.1 %                               0.842512
# NEF_0.15 %                              0.842102
# NEF_0.5 %                               0.915948
# NEF_1 %                                 0.928504
# NEF_2 %                                 0.971315
# NEF_5 %                                 0.992086
# NEF_10 %                                0.963777
# NEF_20 %                                0.940820
# NEF AUC                                 0.965922
#
#                  n_hits_2500 Keck_Pria_AS_Retest  \
# ROC AUC                                 0.982694
# BEDROC AUC                              0.993941
# PR auc.integral                         0.969180
# NEF_0.1 %                               0.868015
# NEF_0.15 %                              0.869595
# NEF_0.5 %                               0.913447
# NEF_1 %                                 0.933473
# NEF_2 %                                 0.957431
# NEF_5 %                                 0.970865
# NEF_10 %                                0.998429
# NEF_20 %                                0.980496
# NEF AUC                                 0.992633
#
#                  n_hits_5000 Keck_Pria_AS_Retest  \
# ROC AUC                                 0.985879
# BEDROC AUC                              0.981520
# PR auc.integral                         0.965743
# NEF_0.1 %                               0.858834
# NEF_0.15 %                              0.858794
# NEF_0.5 %                               0.896684
# NEF_1 %                                 0.920937
# NEF_2 %                                 0.944274
# NEF_5 %                                 0.937987
# NEF_10 %                                0.980972
# NEF_20 %                                0.999607
# NEF AUC                                 0.984571
#
#                  n_hits_10000 Keck_Pria_AS_Retest
# ROC AUC                                  0.987401
# BEDROC AUC                               0.975281
# PR auc.integral                          0.954790
# NEF_0.1 %                                0.842310
# NEF_0.15 %                               0.843799
# NEF_0.5 %                                0.883194
# NEF_1 %                                  0.910589
# NEF_2 %                                  0.938611
# NEF_5 %                                  0.941550
# NEF_10 %                                 0.974854
# NEF_20 %                                 0.982458
# NEF AUC                                  0.976937
