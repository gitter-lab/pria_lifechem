# %%
import os
from virtual_screening.function import read_merged_data
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit import Chem
# Out:
# /home/sliu426/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data_path = '../../../dataset/fixed_dataset/fold_5/file_{}.csv'
k = 5

output_file_list = [data_path.format(i) for i in range(k)]

# %%
data_pd_list = []
for i in range(k):
    temp_pd = read_merged_data(output_file_list[i:i+1])
    print temp_pd.shape
    data_pd_list.append(temp_pd)
# Out:
# (14486, 8)
# (14482, 8)
# (14484, 8)
# (14485, 8)
# (14486, 8)

# %% [markdown]
# # Scaffolds of Keck_RMI_cdd

# %%
Target_name = 'Keck_RMI_cdd'

# %%
smiles_list = []
for i in range(k):
    smiles_list.extend(data_pd_list[i][data_pd_list[i][Target_name]==1]['SMILES'].tolist())

scaffold_set = set()
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    core = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold = Chem.MolToSmiles(core)
    scaffold_set.add(scaffold)
    print 'Original SMILES is \t{}'.format(smiles)
    print 'The Scaffold is \t{}'.format(scaffold)
    print

print '{} total smiles'.format(len(smiles_list))
print '{} different scaffolds'.format(len(scaffold_set))
# Out:
# Original SMILES is 	c1cc(cc2c1CCCN2CCOC)N
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(cc5)OCC)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1C(=O)OC)sc(n2)NC(=O)c3ccc(cc3)N(C)C
# The Scaffold is 	O=C(Nc1nc2ccccc2s1)c1ccccc1
#
# Original SMILES is 	c1cc(ccc1C(=O)N=c2n(c3ccc(cc3s2)OC)CC(=O)OC)F
# The Scaffold is 	O=C(N=c1[nH]c2ccccc2s1)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)OCC)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(cc2c1CCCN2CCOC)NS(=O)(=O)c3ccc(cc3F)F
# The Scaffold is 	O=S(=O)(Nc1ccc2c(c1)NCCC2)c1ccccc1
#
# Original SMILES is 	c1cc(ccc1c2cc(nc3c2c(c(s3)C(=O)N4CCOCC4)N)c5ccc(cc5)Cl)OC
# The Scaffold is 	O=C(c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1)N1CCOCC1
#
# Original SMILES is 	c1ccc(cc1)c2nnc3n2nc(cc3)OCCNC(=O)COC
# The Scaffold is 	c1ccc(-c2nnc3cccnn23)cc1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccnn5C)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccn[nH]1
#
# Original SMILES is 	c1cc(cc(c1)Nc2nc(cs2)CC(=O)N)C(F)(F)F
# The Scaffold is 	c1ccc(Nc2nccs2)cc1
#
# Original SMILES is 	c1cc(cc2c1nc(n(c2=O)c3ccc(cc3)Cl)C)NC(=O)Nc4ccc5c(c4)OCO5
# The Scaffold is 	O=C(Nc1ccc2c(c1)OCO2)Nc1ccc2ncn(-c3ccccc3)c(=O)c2c1
#
# Original SMILES is 	c1cc2c(cc1c3csc(n3)NC(=O)COc4ccc(cc4Cl)Cl)OCCO2
# The Scaffold is 	O=C(COc1ccccc1)Nc1nc(-c2ccc3c(c2)OCCO3)cs1
#
# Original SMILES is 	C#CCn1c2ccc(cc2sc1=NC(=O)c3nc4ccccc4s3)NC(=O)C
# The Scaffold is 	O=C(N=c1[nH]c2ccccc2s1)c1nc2ccccc2s1
#
# Original SMILES is 	c1ccc2c(c1)nc3c4cc(ccc4n(c3n2)CCCC)C
# The Scaffold is 	c1ccc2nc3c(nc2c1)[nH]c1ccccc13
#
# Original SMILES is 	c1ccc2c(c1)-c3c4c(c(ccc4[nH]c(=O)c3C(=O)C)Cl)C2=O
# The Scaffold is 	O=C1c2ccccc2-c2cc(=O)[nH]c3cccc1c23
#
# Original SMILES is 	c1cc(cc(c1)Cl)N=Cc2cc(cc(c2O)Br)Br
# The Scaffold is 	C(=Nc1ccccc1)c1ccccc1
#
# Original SMILES is 	c1cc(c(c(c1)OC)O)c2nc3c(c(=S)[nH]2)Cc4cccc(c4O3)OCC
# The Scaffold is 	S=c1[nH]c(-c2ccccc2)nc2c1Cc1ccccc1O2
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3cc4c(nc5ccccn5c4=O)n(c3=N)Cc6ccco6
# The Scaffold is 	N=c1c(-c2nc3ccccc3s2)cc2c(=O)n3ccccc3nc2n1Cc1ccco1
#
# Original SMILES is 	c1cc(ccc1NC(=O)c2c(c3cc(c(cc3o2)C)C)C)[S-](=O)(Nc4cc(nc(n4)C)C)[O-]
# The Scaffold is 	O=C(Nc1ccc([SH-](=O)Nc2ccncn2)cc1)c1cc2ccccc2o1
#
# Original SMILES is 	c1cc(sc1C(=O)Nc2nc(cs2)c3cc(sc3Cl)Cl)[N+](=O)[O-]
# The Scaffold is 	O=C(Nc1nc(-c2ccsc2)cs1)c1cccs1
#
# Original SMILES is 	C#CCn1c2c(cccc2Cl)sc1=NC(=O)c3cc(=O)c4ccccc4o3
# The Scaffold is 	O=C(N=c1[nH]c2ccccc2s1)c1cc(=O)c2ccccc2o1
#
# Original SMILES is 	c1cc(oc1)C2c3c(=O)c4cc(ccc4oc3C(=O)N2CCN5CCOCC5)Cl
# The Scaffold is 	O=C1c2oc3ccccc3c(=O)c2C(c2ccco2)N1CCN1CCOCC1
#
# Original SMILES is 	c1ccc(cc1)C=CCSc2nnc(c(=O)n2N)C
# The Scaffold is 	O=c1cnnc(SCC=Cc2ccccc2)[nH]1
#
# Original SMILES is 	c1cc(c(c2c1c(cc(=O)o2)CN3CCCCC3)C)O
# The Scaffold is 	O=c1cc(CN2CCCCC2)c2ccccc2o1
#
# Original SMILES is 	c1cc(c(c2c1c(cc(=O)o2)CN3CCC4(CC3)OCCO4)C)O
# The Scaffold is 	O=c1cc(CN2CCC3(CC2)OCCO3)c2ccccc2o1
#
# Original SMILES is 	c1cc(sc1)CC(=O)Nc2c(nc3ccc(cn3c2=O)C)C
# The Scaffold is 	O=C(Cc1cccs1)Nc1cnc2ccccn2c1=O
#
# Original SMILES is 	c1ccc(cc1)c2nc(c(s2)C(=O)Nc3ccc(cc3)c4ccc5nnc(n5n4)c6ccncc6)C
# The Scaffold is 	O=C(Nc1ccc(-c2ccc3nnc(-c4ccncc4)n3n2)cc1)c1cnc(-c2ccccc2)s1
#
# Original SMILES is 	c1cn2c(cc1C)nc(nc2=O)SCC(=O)N3CCN(CC3)C(=O)OCC
# The Scaffold is 	O=C(CSc1nc(=O)n2ccccc2n1)N1CCNCC1
#
# Original SMILES is 	c1cc(cc(c1NC(=O)CSc2ccc(cc2)F)[N+](=O)[O-])OC
# The Scaffold is 	O=C(CSc1ccccc1)Nc1ccccc1
#
# Original SMILES is 	c1ccc(cc1)C(=O)Oc2ccc(cc2Cl)N[S-](=O)(c3ccc4ccccc4c3)[O-]
# The Scaffold is 	O=C(Oc1ccc(N[SH-](=O)c2ccc3ccccc3c2)cc1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(cc3c2oc(c3C(=O)C)C)N[S-](=O)(c4ccc(cc4)Br)[O-]
# The Scaffold is 	O=[SH-](Nc1cc2ccoc2c2ccccc12)c1ccccc1
#
# Original SMILES is 	c1cc(cc2c1C(=O)C(=Cc3ccc(cc3)Cl)O2)O
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2ccccc21
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c(cccn3)C(=O)Nc4ccc(cc4)C(=O)O
# The Scaffold is 	O=C(Nc1ccccc1)c1cccnc1-c1nc2ccccc2s1
#
# Original SMILES is 	c1cc2c(cc1NC(=O)CN3C(=O)C(NC3=O)(CC)CC)OCCO2
# The Scaffold is 	O=C(CN1C(=O)CNC1=O)Nc1ccc2c(c1)OCCO2
#
# Original SMILES is 	c1cc2c(c3c1cc(c(=O)o3)c4ccc(cc4)OC)CN(CO2)C(C)C
# The Scaffold is 	O=c1oc2c3c(ccc2cc1-c1ccccc1)OCNC3
#
# Original SMILES is 	C(#N)c1c2c(sc1NC(=O)CN3C(=O)CCC3=O)CN(CC2)C(C)C
# The Scaffold is 	O=C(CN1C(=O)CCC1=O)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1cc2c3c(c1)C(=O)N(C(=O)c3ccc2N4CCCCC4)CCOC(=O)c5ccc(cc5)[S-](=O)(N6CCCCC6)[O-]
# The Scaffold is 	O=C(OCCN1C(=O)c2cccc3c(N4CCCCC4)ccc(c23)C1=O)c1ccc([SH-](=O)N2CCCCC2)cc1
#
# Original SMILES is 	c1cc2c(cc1C(=O)Nc3nc(cs3)c4ccc(s4)Br)scn2
# The Scaffold is 	O=C(Nc1nc(-c2cccs2)cs1)c1ccc2ncsc2c1
#
# Original SMILES is 	c1ccc2c(c1)CCCN2C(=O)CSc3nc4c(c(=O)n3c5ccc(cc5)[N+](=O)[O-])SCC4
# The Scaffold is 	O=C(CSc1nc2c(c(=O)n1-c1ccccc1)SCC2)N1CCCc2ccccc21
#
# Original SMILES is 	c1cc(c2c(c1)sc(n2)Nc3nc4c(cc(cc4s3)F)F)OC
# The Scaffold is 	c1ccc2sc(Nc3nc4ccccc4s3)nc2c1
#
# Original SMILES is 	c1ccc(c(c1)C(=O)NCc2ccc3c(c2)cc(n3C)C)Cl
# The Scaffold is 	O=C(NCc1ccc2[nH]ccc2c1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(c(s2)C(=O)OC)NC(=O)c3cc(sc3Cl)Cl
# The Scaffold is 	O=C(Nc1csc2ccccc12)c1ccsc1
#
# Original SMILES is 	c1ccc2c(c1)C3c4ccccc4C2C5C3C(=O)N(C5=O)C(C(=O)O)Cc6cnc[nH]6
# The Scaffold is 	O=C1C2C3c4ccccc4C(c4ccccc43)C2C(=O)N1CCc1cnc[nH]1
#
# Original SMILES is 	c1ccc(cc1)CN2C(=O)c3cccc(c3C2=O)N
# The Scaffold is 	O=C1c2ccccc2C(=O)N1Cc1ccccc1
#
# Original SMILES is 	C(#N)c1c(nc(nc1O)N2CCCCC2)c3ccc4c(c3)OCO4
# The Scaffold is 	c1cc(-c2ccc3c(c2)OCO3)nc(N2CCCCC2)n1
#
# Original SMILES is 	C(#N)C1=C(N2C(=C(C1c3ccccc3)C#N)SCCC2)N
# The Scaffold is 	C1=CN2CCCSC2=CC1c1ccccc1
#
# Original SMILES is 	c1cc(oc1)C(=O)C2=C(C(=O)N(C2c3ccc(cc3)Br)c4nnc(s4)C)O
# The Scaffold is 	O=C(C1=CC(=O)N(c2nncs2)C1c1ccccc1)c1ccco1
#
# Original SMILES is 	c1cc(ccc1C(=O)Nc2nc3c(s2)CCCC3)OCCCC
# The Scaffold is 	O=C(Nc1nc2c(s1)CCCC2)c1ccccc1
#
# Original SMILES is 	c1ccc(c(c1)c2csc(n2)NC(=O)C(C)C)OC
# The Scaffold is 	c1ccc(-c2cscn2)cc1
#
# Original SMILES is 	c1ccc2c(c1)-c3c(sc(n3)NC(=O)c4nc5ccccc5s4)C2
# The Scaffold is 	O=C(Nc1nc2c(s1)Cc1ccccc1-2)c1nc2ccccc2s1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)C(=O)NCCOC)CCCN2CC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(cc(c1)S(=O)(=O)NCCc2ccc3c(c2)CCCN3CCC)F
# The Scaffold is 	O=S(=O)(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc(ccc1CSc2nc(cs2)CC(=O)Nc3nccs3)Br
# The Scaffold is 	O=C(Cc1csc(SCc2ccccc2)n1)Nc1nccs1
#
# Original SMILES is 	c1ccnc(c1)CNC(=O)Cc2csc(n2)SCc3ccc(cc3)Br
# The Scaffold is 	O=C(Cc1csc(SCc2ccccc2)n1)NCc1ccccn1
#
# Original SMILES is 	c1cc2cc(oc2c(c1)OC)C(=O)Nc3nnc(o3)c4ccc(cc4)SC
# The Scaffold is 	O=C(Nc1nnc(-c2ccccc2)o1)c1cc2ccccc2o1
#
# Original SMILES is 	c1ccc(cc1)c2csc3c2ncn(c3=O)Cc4cc(=O)n5ccccc5n4
# The Scaffold is 	O=c1c2scc(-c3ccccc3)c2ncn1Cc1cc(=O)n2ccccc2n1
#
# Original SMILES is 	c1cc(cc(c1)Cl)c2csc3c2ncn(c3=O)Cc4cc(=O)n5ccccc5n4
# The Scaffold is 	O=c1c2scc(-c3ccccc3)c2ncn1Cc1cc(=O)n2ccccc2n1
#
# Original SMILES is 	c1cc2c(cc1CN3CCN(CC3)C(=O)CCc4nc5c(c6c(s5)CCCCC6)c(=O)[nH]4)OCO2
# The Scaffold is 	O=C(CCc1nc2sc3c(c2c(=O)[nH]1)CCCCC3)N1CCN(Cc2ccc3c(c2)OCO3)CC1
#
# Original SMILES is 	c1cc(ccc1c2c3c(c(sc3nc4c2C(=O)CC(C4)(C)C)C(=O)c5ccc6c(c5)OCCO6)N)OC
# The Scaffold is 	O=C(c1ccc2c(c1)OCCO2)c1cc2c(-c3ccccc3)c3c(nc2s1)CCCC3=O
#
# Original SMILES is 	c1ccnc(c1)CNC(=O)Cc2csc(n2)Nc3ccc(cc3)F
# The Scaffold is 	O=C(Cc1csc(Nc2ccccc2)n1)NCc1ccccn1
#
# Original SMILES is 	c1ccc(cc1)CN2Cc3c(c(c(s3)NC(=O)c4ccc(s4)c5nc6ccccc6s5)C(=O)OC)CC2
# The Scaffold is 	O=C(Nc1cc2c(s1)CN(Cc1ccccc1)CC2)c1ccc(-c2nc3ccccc3s2)s1
#
# Original SMILES is 	c1cc2c(cc1C(=O)Nc3c(c4c(s3)CN(CC4)C(=O)OCC)C(=O)OCC)scn2
# The Scaffold is 	O=C(Nc1cc2c(s1)CNCC2)c1ccc2ncsc2c1
#
# Original SMILES is 	C(#N)c1ccsc1NC(=O)c2cccs2
# The Scaffold is 	O=C(Nc1cccs1)c1cccs1
#
# Original SMILES is 	c1cc(nc2c1c(cc(n2)O)C)N
# The Scaffold is 	c1cnc2ncccc2c1
#
# Original SMILES is 	C(#N)c1ccsc1NC(=O)c2cc(cc(c2)Cl)Cl
# The Scaffold is 	O=C(Nc1cccs1)c1ccccc1
#
# Original SMILES is 	C(#N)c1c2nc3ccccc3n2c(cc1C)SCC(=O)c4ccc(c(c4)OC)OC
# The Scaffold is 	O=C(CSc1cccc2nc3ccccc3n12)c1ccccc1
#
# Original SMILES is 	c1c2c(cc3c1OCCO3)sc(n2)NN
# The Scaffold is 	c1nc2cc3c(cc2s1)OCCO3
#
# Original SMILES is 	c1ccc2c(c1)CCN2[S-](=O)(c3ccc(cc3)C(=O)Nc4nnc(o4)c5cc(ccc5C)C)[O-]
# The Scaffold is 	O=C(Nc1nnc(-c2ccccc2)o1)c1ccc([SH-](=O)N2CCc3ccccc32)cc1
#
# Original SMILES is 	c1cc(sc1)[S-](=O)(N2CCCC2C(=O)Nc3c(c4c(s3)CN(CC4)C(=O)C)C(=O)N)[O-]
# The Scaffold is 	O=C(Nc1cc2c(s1)CNCC2)C1CCCN1[SH-](=O)c1cccs1
#
# Original SMILES is 	c1ccc2c(c1)c(c[nH]2)NC(=O)NCc3ccccn3
# The Scaffold is 	O=C(NCc1ccccn1)Nc1c[nH]c2ccccc12
#
# Original SMILES is 	c1cc(oc1)c2c(sc(n2)NC(=O)CSc3c4cn[nH]c4ncn3)c5ccco5
# The Scaffold is 	O=C(CSc1ncnc2[nH]ncc12)Nc1nc(-c2ccco2)c(-c2ccco2)s1
#
# Original SMILES is 	c1ccc2c(c1)CC(N2C(=O)Nc3cccs3)C(=O)N
# The Scaffold is 	O=C(Nc1cccs1)N1CCc2ccccc21
#
# Original SMILES is 	c1ccc(cc1)C2c3cc(ccc3NC(N2CC(=O)OCC)c4ccccc4F)Br
# The Scaffold is 	c1ccc(C2Nc3ccccc3C(c3ccccc3)N2)cc1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)CC(=O)c3ccc(cc3O)O
# The Scaffold is 	O=C(Cc1nc2ccccc2s1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)[S-](=O)(c5cccc(c5)Cl)[O-]
# The Scaffold is 	O=[SH-](c1ccccc1)c1cn(Cc2ccco2)c2nc3ccccc3nc12
#
# Original SMILES is 	C(#N)C(c1c(nc2ccccc2n1)N3CCN(CC3)c4ccccc4)C(=O)OCC=C
# The Scaffold is 	c1ccc(N2CCN(c3cnc4ccccc4n3)CC2)cc1
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)C(=O)OCCC
# The Scaffold is 	c1coc(Cn2ccc3nc4ccccc4nc32)c1
#
# Original SMILES is 	c1ccc2c(c1)c3cc4c(cc3n2C)cc(nc4C)O
# The Scaffold is 	c1ccc2c(c1)[nH]c1cc3ccncc3cc12
#
# Original SMILES is 	c1cc(oc1)CN2Cc3c(ccc4c3oc(=O)c(c4)c5ccc(c(c5)OC)OC)OC2
# The Scaffold is 	O=c1oc2c3c(ccc2cc1-c1ccccc1)OCN(Cc1ccco1)C3
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(cc5)[S-](=O)(N6CCCCCC6)[O-])CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccc([SH-](=O)N2CCCCCC2)cc1
#
# Original SMILES is 	c1cc(ccc1NC(=O)c2cnc3n(c2=O)CCS3)[S-](=O)(Nc4ncccn4)[O-]
# The Scaffold is 	O=C(Nc1ccc([SH-](=O)Nc2ncccn2)cc1)c1cnc2n(c1=O)CCS2
#
# Original SMILES is 	c1cc(ccc1C(=O)N=c2c(cc3c(n2CC4CCCO4)nc5ccccn5c3=O)C(=O)OCC)Br
# The Scaffold is 	O=C(N=c1ccc2c(=O)n3ccccc3nc2n1CC1CCCO1)c1ccccc1
#
# Original SMILES is 	c1ccc(c(c1)c2nnc(o2)Nc3nc4ccc(cc4s3)F)OC
# The Scaffold is 	c1ccc(-c2nnc(Nc3nc4ccccc4s3)o2)cc1
#
# Original SMILES is 	c1ccc2c(c1)ccc(n2)C(=O)Nc3ccc(cc3C)c4nc5cccnc5s4
# The Scaffold is 	O=C(Nc1ccc(-c2nc3cccnc3s2)cc1)c1ccc2ccccc2n1
#
# Original SMILES is 	c1cc(c(cc1C)[N+](=O)[O-])N2C(=O)C=CC2=O
# The Scaffold is 	O=C1C=CC(=O)N1c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)[S-](=O)(N=Cc2cc(ccc2O)Br)[O-]
# The Scaffold is 	O=[SH-](N=Cc1ccccc1)c1ccccc1
#
# Original SMILES is 	c1cc(sc1)C(=O)NC(=S)Nc2cc(c(s2)C(=O)OCC)C
# The Scaffold is 	O=C(NC(=S)Nc1cccs1)c1cccs1
#
# Original SMILES is 	c1cc(sc1C=Nc2nnc(s2)NC(=O)c3cc(cc(c3)C)C)Br
# The Scaffold is 	O=C(Nc1nnc(N=Cc2cccs2)s1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)cccc2NC(=N[S-](=O)(c3ccc(cc3)Cl)[O-])CSC(=O)N
# The Scaffold is 	O=[SH-](N=CNc1cccc2ccccc12)c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2c(nnc(n2)NN=CC=Cc3ccco3)c4ccccc4
# The Scaffold is 	C(=Cc1ccco1)C=NNc1nnc(-c2ccccc2)c(-c2ccccc2)n1
#
# Original SMILES is 	c1ccc(c(c1)N=Cc2cc(cc(c2O)Br)Br)F
# The Scaffold is 	C(=Nc1ccccc1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c3c(c(c(o3)C)C(=O)OCC)c4c2OCN(C4)C5CCCCC5
# The Scaffold is 	c1ccc2c(c1)c1c(c3ccoc32)CN(C2CCCCC2)CO1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5c(cccc5F)F)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(s5)Cl)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cccs1
#
# Original SMILES is 	c1cc2c(c(c1)N)C(=O)N(C2=O)C
# The Scaffold is 	O=C1NC(=O)c2ccccc21
#
# Original SMILES is 	c1c2c3c(cc1N)CCCN3C(=O)CC2
# The Scaffold is 	O=C1CCc2cccc3c2N1CCC3
#
# Original SMILES is 	c1ccc(c(c1)C(=O)NCCc2ccc3c(c2)CCCN3CCC)OCC
# The Scaffold is 	O=C(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)Cc3ccc(cc3)F)CCCN2CCC
# The Scaffold is 	O=C(Cc1ccccc1)NCCc1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(cc2c1CCCN2CCOC)NS(=O)(=O)Cc3ccc(cc3)Cl
# The Scaffold is 	O=S(=O)(Cc1ccccc1)Nc1ccc2c(c1)NCCC2
#
# Original SMILES is 	c1cc(ccc1SCC(=O)Nc2c(c3c(s2)CN(CC3)C(=O)C)C(=O)N)Cl
# The Scaffold is 	O=C(CSc1ccccc1)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1cc(ccc1S(=O)(=O)CC(=O)Nc2c(c3c(s2)CN(CC3)C(=O)C)C(=O)N)Cl
# The Scaffold is 	O=C(CS(=O)(=O)c1ccccc1)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1cc(ccc1F)S(=O)(=O)CC(=O)Nc2c(c3c(s2)CN(CC3)CC)C(=O)N
# The Scaffold is 	O=C(CS(=O)(=O)c1ccccc1)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1ccc2c(c1)cc(cn2)NC(=O)C3CCN(CC3)c4ccc(nn4)c5ccco5
# The Scaffold is 	O=C(Nc1cnc2ccccc2c1)C1CCN(c2ccc(-c3ccco3)nn2)CC1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)cc(o2)C(=O)Nc3c(c4c(s3)CN(CC4)C(=O)C)c5nc6ccccc6s5
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cc(=O)c2ccccc2o1
#
# Original SMILES is 	c1ccc(cc1)C(c2ccccc2)C(=O)Nc3ccc(cc3)[S-](=O)(N4CCCC4)[O-]
# The Scaffold is 	O=C(Nc1ccc([SH-](=O)N2CCCC2)cc1)C(c1ccccc1)c1ccccc1
#
# Original SMILES is 	c1cc(oc1)C2C3C(=O)N(C(=O)C3ON2c4ccc(cc4)Cl)c5c(c(c(s5)C)C)C(=O)OC
# The Scaffold is 	O=C1C2ON(c3ccccc3)C(c3ccco3)C2C(=O)N1c1cccs1
#
# Original SMILES is 	c1cc(ccc1c2cc(c3c(c(sc3n2)C(=O)Nc4nccs4)N)c5ccc(c(c5)OC)OC)OC
# The Scaffold is 	O=C(Nc1nccs1)c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(ccc1c2nc3c(c(=S)[nH]2)Cc4cc(ccc4O3)Br)F
# The Scaffold is 	S=c1[nH]c(-c2ccccc2)nc2c1Cc1ccccc1O2
#
# Original SMILES is 	c1cc(cc(c1)F)C2C3=C(CC(CC3=O)(C)C)Nc4c2c(=O)n(c(=O)n4C)C
# The Scaffold is 	O=C1CCCC2=C1C(c1ccccc1)c1c([nH]c(=O)[nH]c1=O)N2
#
# Original SMILES is 	c1cc(oc1)CNC(=O)CSc2nnc(s2)NC(=O)C(C)(C)C
# The Scaffold is 	O=C(CSc1nncs1)NCc1ccco1
#
# Original SMILES is 	c1ccc2c(c1)cc(n2CCNC(=O)c3cc4c(o3)ccc(n4)C)C
# The Scaffold is 	O=C(NCCn1ccc2ccccc21)c1cc2ncccc2o1
#
# Original SMILES is 	c1cc2n(c1)CCN(C2c3ccc(cc3)F)C(=O)Nc4cccs4
# The Scaffold is 	O=C(Nc1cccs1)N1CCn2cccc2C1c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)CCN(C2)[S-](=O)(c3ccc(cc3)C(=O)NNc4nc5c(ccc(c5s4)Cl)OC)[O-]
# The Scaffold is 	O=C(NNc1nc2ccccc2s1)c1ccc([SH-](=O)N2CCc3ccccc3C2)cc1
#
# Original SMILES is 	c1ccc(cc1)CN2CCN(CC2)C(=O)Nc3c[nH]c4c3cccc4
# The Scaffold is 	O=C(Nc1c[nH]c2ccccc12)N1CCN(Cc2ccccc2)CC1
#
# Original SMILES is 	c1cc(cc(c1)[N+](=O)[O-])NC(=O)C(=O)Nc2ccc3c(c2)OCO3
# The Scaffold is 	O=C(Nc1ccccc1)C(=O)Nc1ccc2c(c1)OCO2
#
# Original SMILES is 	c1ccc2cc(ccc2c1)[S-](=O)(Nc3cc(c(c4c3cccc4)O)Br)[O-]
# The Scaffold is 	O=[SH-](Nc1cccc2ccccc12)c1ccc2ccccc2c1
#
# Original SMILES is 	c1ccc(cc1)C(=O)c2ccc3c4c2cccc4C(=O)N(C3=O)c5ccc6c7c5cccc7CC6
# The Scaffold is 	O=C(c1ccccc1)c1ccc2c3c(cccc13)C(=O)N(c1ccc3c4c(cccc14)CC3)C2=O
#
# Original SMILES is 	c1cc(sc1)C=C2C(=O)c3ccc(cc3O2)OC(=O)N4CCOCC4
# The Scaffold is 	O=C1C(=Cc2cccs2)Oc2cc(OC(=O)N3CCOCC3)ccc21
#
# Original SMILES is 	c1ccc(cc1)CNC(=O)Cn2c3cc4c(cc3cc(c2=O)CNc5ccc(cc5)CC)OCCO4
# The Scaffold is 	O=C(Cn1c(=O)c(CNc2ccccc2)cc2cc3c(cc21)OCCO3)NCc1ccccc1
#
# Original SMILES is 	c1cc(cc(c1c2cc(c(o2)C)C(=O)Nc3ccc(cc3)[S-](=O)(N)[O-])[N+](=O)[O-])Cl
# The Scaffold is 	O=C(Nc1ccccc1)c1coc(-c2ccccc2)c1
#
# Original SMILES is 	c1ccc2c(c1)nc3c4cc(ccc4n(c3n2)CC(=O)OCCCC)OC
# The Scaffold is 	c1ccc2nc3c(nc2c1)[nH]c1ccccc13
#
# Original SMILES is 	c1ccc(c(c1)c2ccc(o2)c3nnc(o3)c4ccco4)[N+](=O)[O-]
# The Scaffold is 	c1ccc(-c2ccc(-c3nnc(-c4ccco4)o3)o2)cc1
#
# Original SMILES is 	c1ccc2c(c1)cc(o2)C(=O)Nc3c(c4c(s3)CN(CC4)C)c5nc6ccccc6s5
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cc2ccccc2o1
#
# Original SMILES is 	c1ccc(c(c1)CN2c3c(cccc3Cl)C4(C2=O)N(N=C(S4)NC(=O)C)C(=O)C)OCC
# The Scaffold is 	O=C1N(Cc2ccccc2)c2ccccc2C12NN=CS2
#
# Original SMILES is 	c1ccnc(c1)c2cc([nH]c2c3cc(cc(c3)Cl)Cl)C
# The Scaffold is 	c1ccc(-c2[nH]ccc2-c2ccccn2)cc1
#
# Original SMILES is 	c1cc2cc(cc(c2nc1)NC(=O)CCC(=O)O)OC
# The Scaffold is 	c1ccc2ncccc2c1
#
# Original SMILES is 	c1ccnc(c1)CC(=O)c2cc(cc(c2)Cl)Cl
# The Scaffold is 	O=C(Cc1ccccn1)c1ccccc1
#
# Original SMILES is 	c1cc(sc1)CC(=O)Nc2cc(nc3c2cc(cc3C)C)C
# The Scaffold is 	O=C(Cc1cccs1)Nc1ccnc2ccccc12
#
# Original SMILES is 	c1cc(cc(c1)F)C=C2C(=O)c3ccc4c(c3O2)CN(CO4)C5CC5
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2c1ccc1c2CN(C2CC2)CO1
#
# Original SMILES is 	c1ccc(cc1)N=C2NC(=O)C(S2)Cc3cccc(c3)[N+](=O)[O-]
# The Scaffold is 	O=C1NC(=Nc2ccccc2)SC1Cc1ccccc1
#
# Original SMILES is 	c1cc2c(c(c1)OCC)oc(=O)c(c2)c3nnc(s3)Nc4ccc(cc4)C(=O)OCC
# The Scaffold is 	O=c1oc2ccccc2cc1-c1nnc(Nc2ccccc2)s1
#
# Original SMILES is 	c1cc2c(c(c1)[N+](=O)[O-])C(=O)N(C2=O)c3cccc(c3)C(=O)C
# The Scaffold is 	O=C1c2ccccc2C(=O)N1c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)c3ccc(cc3)OC(=O)CC
# The Scaffold is 	O=C1c2ccccc2C(=O)N1c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2c([n+]3c4ccccc4nc(c3s2)C)[O-]
# The Scaffold is 	c1ccc(-c2c[n+]3c(cnc4ccccc43)s2)cc1
#
# Original SMILES is 	c1ccc(c(c1)C2C3=C(CCCC3=O)Nc4c2c(=O)[nH]c(=O)[nH]4)[N+](=O)[O-]
# The Scaffold is 	O=C1CCCC2=C1C(c1ccccc1)c1c([nH]c(=O)[nH]c1=O)N2
#
# Original SMILES is 	C(#N)C(=C1Nc2ccccc2N1)C(=O)c3ccccc3Br
# The Scaffold is 	O=C(C=C1Nc2ccccc2N1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(cc(c2O)Cl)N[S-](=O)(c3cc(c(cc3C)C)C)[O-]
# The Scaffold is 	O=[SH-](Nc1cccc2ccccc12)c1ccccc1
#
# Original SMILES is 	c1cc(cc(c1)CS(=O)(=O)Nc2ccc3c(c2)N(CCC3)CCOC)C
# The Scaffold is 	O=S(=O)(Cc1ccccc1)Nc1ccc2c(c1)NCCC2
#
# Original SMILES is 	c1ccc(cc1)N(C)S(=O)(=O)c2ccc(cc2)C(=O)Nc3c(c4c(s3)CN(CC4)CCC)C(=O)NC
# The Scaffold is 	O=C(Nc1cc2c(s1)CNCC2)c1ccc(S(=O)(=O)Nc2ccccc2)cc1
#
# Original SMILES is 	c1(c(c([nH]c1C)C(=O)CN2CCCCCC2)C)C(=O)OC
# The Scaffold is 	O=C(CN1CCCCCC1)c1ccc[nH]1
#
# Original SMILES is 	c1ccc(c(c1)C(=O)NCCc2ccc3c(c2)CCCN3CC)C(F)(F)F
# The Scaffold is 	O=C(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)C(C)(C)C)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1ccc(cc1)CCNC(=O)c2c(c3c(cc(nc3s2)c4ccc(cc4)Cl)c5ccc(cc5)OC)N
# The Scaffold is 	O=C(NCCc1ccccc1)c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1ccc(c(c1)C(=O)Nc2cc(ccc2OC)c3cn4c(n3)ccc(n4)OC)Cl
# The Scaffold is 	O=C(Nc1cccc(-c2cn3ncccc3n2)c1)c1ccccc1
#
# Original SMILES is 	c1cc(cc(c1OC)S(=O)(=O)N2CCN(CC2)c3ccc(nn3)c4ccncc4)Cl
# The Scaffold is 	O=S(=O)(c1ccccc1)N1CCN(c2ccc(-c3ccncc3)nn2)CC1
#
# Original SMILES is 	c1ccc(cc1)C(C(=O)Nc2cc(nn2c3nc(c(c(=O)[nH]3)C)C)c4ccco4)CC
# The Scaffold is 	O=C(Cc1ccccc1)Nc1cc(-c2ccco2)nn1-c1nccc(=O)[nH]1
#
# Original SMILES is 	c1ccc(cc1)c2c(c3ccccc3n2O)C(c4ccccn4)N5CCN(CC5)C(=O)OCC
# The Scaffold is 	c1ccc(-c2[nH]c3ccccc3c2C(c2ccccn2)N2CCNCC2)cc1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)CCCn3c4ccc(cc4c5c3nc6ccccc6n5)C
# The Scaffold is 	O=C1c2ccccc2C(=O)N1CCCn1c2ccccc2c2nc3ccccc3nc21
#
# Original SMILES is 	c1cc(cc(c1N=Cc2c(nc3c(cccn3c2=O)C)NC(C)CC)Cl)[N+](=O)[O-]
# The Scaffold is 	O=c1c(C=Nc2ccccc2)cnc2ccccn12
#
# Original SMILES is 	c1ccc(c(c1)C=C2C(=O)c3cc(ccc3O2)C(=O)OC)F
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2ccccc21
#
# Original SMILES is 	c1cc(ccc1CN(C(=O)C(C)C)C2CC[S-](=O)(C2)[O-])Cl
# The Scaffold is 	O=[SH-]1CCC(NCc2ccccc2)C1
#
# Original SMILES is 	c1cc(ccc1c2nc([nH]n2)SC(c3ccc(cc3)OC)CC(=O)NCCN4CCOCC4)OC
# The Scaffold is 	O=C(CC(Sc1nc(-c2ccccc2)n[nH]1)c1ccccc1)NCCN1CCOCC1
#
# Original SMILES is 	C1(=C(CC2C(=O)N(C(=O)C2C1)CC)C)C
# The Scaffold is 	O=C1NC(=O)C2CC=CCC12
#
# Original SMILES is 	c1cc(cc(c1C(=O)CN2CCN(CC2)C(=O)OCC)O)O
# The Scaffold is 	O=C(CN1CCNCC1)c1ccccc1
#
# Original SMILES is 	c1ccc2cc3c(cc2c1)c(=O)n(c(n3)C)N=CN(C)C
# The Scaffold is 	O=c1[nH]cnc2cc3ccccc3cc12
#
# Original SMILES is 	c1c2c(nccn2)nc(c1Br)C(=O)O
# The Scaffold is 	c1cnc2nccnc2c1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)cc(o2)C(=O)Nc3cc(nn3c4nc5c(c(=O)[nH]4)CCC5)C
# The Scaffold is 	O=C(Nc1ccnn1-c1nc2c(c(=O)[nH]1)CCC2)c1cc(=O)c2ccccc2o1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)c(co2)C=C3C(=O)OC(=N3)C=Cc4ccccc4OC
# The Scaffold is 	O=C1OC(C=Cc2ccccc2)=NC1=Cc1coc2ccccc2c1=O
#
# Original SMILES is 	c1ccc(cc1)CN2Cc3c(c(c(s3)NC(=O)C[S-](=O)(c4ccccc4)[O-])C(=O)N)CC2
# The Scaffold is 	O=C(C[SH-](=O)c1ccccc1)Nc1cc2c(s1)CN(Cc1ccccc1)CC2
#
# Original SMILES is 	c1ccc2c(c1)c(c[nH]2)NC(=O)N3CCN(CC3)c4ccccc4Cl
# The Scaffold is 	O=C(Nc1c[nH]c2ccccc12)N1CCN(c2ccccc2)CC1
#
# Original SMILES is 	c1cc2c(nc1)n(c(=O)c(c2)C(=O)Nc3ccc(cc3)c4nc5ccc(cc5s4)C)C
# The Scaffold is 	O=C(Nc1ccc(-c2nc3ccccc3s2)cc1)c1cc2cccnc2[nH]c1=O
#
# Original SMILES is 	c1cc(nc(c1)C(=O)Nc2nc3c(s2)C(=O)CC(C3)(C)C)C(=O)Nc4nc5c(s4)C(=O)CC(C5)(C)C
# The Scaffold is 	O=C(Nc1nc2c(s1)C(=O)CCC2)c1cccc(C(=O)Nc2nc3c(s2)C(=O)CCC3)n1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3nc4ccc(cc4s3)OC
# The Scaffold is 	c1ccc2sc(-c3nc4ccccc4s3)nc2c1
#
# Original SMILES is 	c1cc(cc(c1)NC(=O)CSc2ccc(cc2[N+](=O)[O-])[N+](=O)[O-])C(F)(F)F
# The Scaffold is 	O=C(CSc1ccccc1)Nc1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)nc3c4cc(ccc4n(c3n2)CC)OC
# The Scaffold is 	c1ccc2nc3c(nc2c1)[nH]c1ccccc13
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)c5nc6ccccc6n5C
# The Scaffold is 	c1coc(Cn2cc(-c3nc4ccccc4[nH]3)c3nc4ccccc4nc32)c1
#
# Original SMILES is 	c1ccc(cc1)C2C(=C(C(=O)N2c3nccs3)O)C(=O)c4cc5ccccc5o4
# The Scaffold is 	O=C(C1=CC(=O)N(c2nccs2)C1c1ccccc1)c1cc2ccccc2o1
#
# Original SMILES is 	c1cc(ccc1c2c3cc(ccc3no2)Cl)O
# The Scaffold is 	c1ccc(-c2onc3ccccc23)cc1
#
# Original SMILES is 	c1ccnc(c1)N2C(=O)c3c(c(=O)c4cc(ccc4o3)Cl)C2c5ccc(cc5)C(=O)OC
# The Scaffold is 	O=C1c2oc3ccccc3c(=O)c2C(c2ccccc2)N1c1ccccn1
#
# Original SMILES is 	c1ccc2c(c1)c-3n[nH]c(nc3n2)SCC(=O)c4ccc(cc4)C
# The Scaffold is 	O=C(CSc1nc2nc3ccccc3c-2n[nH]1)c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2cc(n3c(n2)c(cn3)c4ccc(cc4)Cl)N5CCN(CC5)CCO
# The Scaffold is 	c1ccc(-c2cc(N3CCNCC3)n3ncc(-c4ccccc4)c3n2)cc1
#
# Original SMILES is 	c1c2c(nc3ccccn3c2=O)sc1C(=O)Nc4nnc(s4)C5CC5
# The Scaffold is 	O=C(Nc1nnc(C2CC2)s1)c1cc2c(=O)n3ccccc3nc2s1
#
# Original SMILES is 	c1cc(cc(c1)[N+](=O)[O-])c2nnc(s2)NC(=O)CSc3nnc(s3)NC(=O)COc4ccc(cc4Cl)Cl
# The Scaffold is 	O=C(COc1ccccc1)Nc1nnc(SCC(=O)Nc2nnc(-c3ccccc3)s2)s1
#
# Original SMILES is 	c1cc(cc(c1)Br)C(=O)c2c(c3c(c4c(nc3s2)CCCC4)c5cccs5)N
# The Scaffold is 	O=C(c1ccccc1)c1cc2c(-c3cccs3)c3c(nc2s1)CCCC3
#
# Original SMILES is 	c1cc(ccc1C(=O)NNc2nc3c(ccc(c3s2)C)OC)[S-](=O)(N4CCCC4)[O-]
# The Scaffold is 	O=C(NNc1nc2ccccc2s1)c1ccc([SH-](=O)N2CCCC2)cc1
#
# Original SMILES is 	C(#N)c1c(c(sc1N=Cc2ccco2)C)C
# The Scaffold is 	C(=Nc1cccs1)c1ccco1
#
# Original SMILES is 	c1c(cc(cc1Cl)Cl)C(=O)Nc2c(c3c(s2)CCCCC3)C(=O)OCC
# The Scaffold is 	O=C(Nc1cc2c(s1)CCCCC2)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)C(C(=O)O)C
# The Scaffold is 	O=C1NC(=O)c2ccccc21
#
# Original SMILES is 	c1cc(cc2c1C(=O)N(C2=O)c3ccc(cc3)OC)C(=O)c4ccc5c(c4)C(=O)N(C5=O)c6ccc(cc6)OC
# The Scaffold is 	O=C(c1ccc2c(c1)C(=O)N(c1ccccc1)C2=O)c1ccc2c(c1)C(=O)N(c1ccccc1)C2=O
#
# Original SMILES is 	c1ccc(cc1)c2cc[n+]3c(c(sc3n2)c4ccccc4)N
# The Scaffold is 	c1ccc(-c2cc[n+]3cc(-c4ccccc4)sc3n2)cc1
#
# Original SMILES is 	c1ccc2c(c1)ccc(c2C=Nc3ccc(cc3)CC)O
# The Scaffold is 	C(=Nc1ccccc1)c1cccc2ccccc12
#
# Original SMILES is 	c1cc(cc(c1)NC(=O)C)C2=CC(n3c(ncn3)N2)c4cccc(c4)Br
# The Scaffold is 	C1=C(c2ccccc2)Nc2ncnn2C1c1ccccc1
#
# Original SMILES is 	c1c(n2c(s1)nc(=O)c(n2)C)N
# The Scaffold is 	O=c1cnn2ccsc2n1
#
# Original SMILES is 	c1ccnc(c1)CN2Cc3c(ccc4c3OC(=Cc5cccc(c5)F)C4=O)OC2
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2c1ccc1c2CN(Cc2ccccn2)CO1
#
# Original SMILES is 	C(#N)c1ccc(cc1)C(=O)Nc2c(c3c(s2)CCCC3)C#N
# The Scaffold is 	O=C(Nc1cc2c(s1)CCCC2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)COCC)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(ccc1C(=O)NCCc2ccc3c(c2)CCCN3CC)OC(C)C
# The Scaffold is 	O=C(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNS(=O)(=O)C)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cscc1C(CNC(=O)c2cc(cc(c2)OC)OC)N3CCCC3
# The Scaffold is 	O=C(NCC(c1ccsc1)N1CCCC1)c1ccccc1
#
# Original SMILES is 	c1cc(c(cc1c2csc3c2ncn(c3=O)Cc4cc(=O)n5ccccc5n4)OC)OC
# The Scaffold is 	O=c1c2scc(-c3ccccc3)c2ncn1Cc1cc(=O)n2ccccc2n1
#
# Original SMILES is 	c1ccc(cc1)c2cc(c3c(c(sc3n2)C(=O)NCC4CCCO4)N)c5ccc(cc5)OC
# The Scaffold is 	O=C(NCC1CCCO1)c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(c(cc1C(=O)c2c(c3c(c4c(nc3s2)CC(CC4=O)(C)C)CC)N)Cl)Cl
# The Scaffold is 	O=C(c1ccccc1)c1cc2cc3c(nc2s1)CCCC3=O
#
# Original SMILES is 	c1ccnc(c1)CNC(=O)Cc2csc(n2)Nc3ccc(cc3)OC(F)(F)F
# The Scaffold is 	O=C(Cc1csc(Nc2ccccc2)n1)NCc1ccccn1
#
# Original SMILES is 	c1ccc2c(c1)cc(n2C)c3nc(cs3)C(=O)NN4CCOCC4
# The Scaffold is 	O=C(NN1CCOCC1)c1csc(-c2cc3ccccc3[nH]2)n1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(s5)Br)CN(CC4)C(=O)OCC
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cccs1
#
# Original SMILES is 	c1ccc2c(c1)c(c[nH]2)C=NNC(=O)CCC(C3CCC4C3(CCC5C4C(CC6C5(CCC(C6)O)C)O)C)C
# The Scaffold is 	O=C(CCCC1CCC2C1CCC1C3CCCCC3CCC21)NN=Cc1c[nH]c2ccccc12
#
# Original SMILES is 	c1cc(ccc1c2cc(c3c(c(sc3n2)C(=O)Nc4ccc(cc4)OCC)N)C(F)(F)F)Cl
# The Scaffold is 	O=C(Nc1ccccc1)c1cc2ccc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(ccc1c2cc(c3c(c(sc3n2)C(=O)c4ccc(c(c4)Br)OC)N)C(F)(F)F)C
# The Scaffold is 	O=C(c1ccccc1)c1cc2ccc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)O[S-](=O)(c3ccc(cc3C)F)[O-]
# The Scaffold is 	O=C1c2ccccc2C(=O)N1O[SH-](=O)c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2c3cc(ccc3nc(n2)N4C(CC(=N4)c5cccc(c5)N[S-](=O)(C)[O-])c6ccco6)Cl
# The Scaffold is 	c1ccc(C2=NN(c3nc(-c4ccccc4)c4ccccc4n3)C(c3ccco3)C2)cc1
#
# Original SMILES is 	c1ccc(cc1)c2nc3c(c(n2)SCC(=O)Nc4cccc(c4)C(=O)O)Cc5cc(ccc5O3)C
# The Scaffold is 	O=C(CSc1nc(-c2ccccc2)nc2c1Cc1ccccc1O2)Nc1ccccc1
#
# Original SMILES is 	c1ccc(cc1)n2cc(c(n2)c3ccc(c(c3)F)OC)C=C4C(=O)c5cc(ccc5O4)C(=O)OC
# The Scaffold is 	O=C1C(=Cc2cn(-c3ccccc3)nc2-c2ccccc2)Oc2ccccc21
#
# Original SMILES is 	c1ccc(cc1)N=C2NC(=O)C(=CC=Cc3ccco3)S2
# The Scaffold is 	O=C1NC(=Nc2ccccc2)SC1=CC=Cc1ccco1
#
# Original SMILES is 	C1(=NO)CC2(CCC1(C2(C)C)C)C(=O)N3CCCCC3C
# The Scaffold is 	N=C1CC2(C(=O)N3CCCCC3)CCC1C2
#
# Original SMILES is 	c1ccc2c(c1)cc(oc2=O)C(=O)Nc3ncc(s3)Cc4ccc(cc4)C
# The Scaffold is 	O=C(Nc1ncc(Cc2ccccc2)s1)c1cc2ccccc2c(=O)o1
#
# Original SMILES is 	C(#N)c1c(c2c(nc1N)CCN(C2)C)c3ccco3
# The Scaffold is 	c1coc(-c2ccnc3c2CNCC3)c1
#
# Original SMILES is 	c1cc2cc(oc2c(c1)OC)c3csc(n3)NC(=O)c4ccc(cc4)[S-](=O)(N5CCCCC5CC)[O-]
# The Scaffold is 	O=C(Nc1nc(-c2cc3ccccc3o2)cs1)c1ccc([SH-](=O)N2CCCCC2)cc1
#
# Original SMILES is 	c1ccc(c(c1)C)Cn2cccc(c2=O)C(=O)Nc3cccc(c3Cl)Cl
# The Scaffold is 	O=C(Nc1ccccc1)c1cccn(Cc2ccccc2)c1=O
#
# Original SMILES is 	c1ccc(cc1)Cn2c3c(cccn3)cc(c2=O)C(=O)Nc4ccc(cc4OC)[N+](=O)[O-]
# The Scaffold is 	O=C(Nc1ccccc1)c1cc2cccnc2n(Cc2ccccc2)c1=O
#
# Original SMILES is 	c1cc2cc(cc3c2c(c1)C(=O)N(C3=O)O)N
# The Scaffold is 	O=C1NC(=O)c2cccc3cccc1c23
#
# Original SMILES is 	c1cc(oc1)c2cc(nc3c2c(c(s3)C(=O)Nc4ccc(cc4)C(=O)OCC)N)c5ccc(cc5)C
# The Scaffold is 	O=C(Nc1ccccc1)c1cc2c(-c3ccco3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(sc1)c2c3c(c4c(c(sc4n2)C(=O)NCc5ccc6c(c5)OCO6)N)CCCC3
# The Scaffold is 	O=C(NCc1ccc2c(c1)OCO2)c1cc2c3c(c(-c4cccs4)nc2s1)CCCC3
#
# Original SMILES is 	c1cc(oc1)c2c3c(c4c(c(sc4n2)C(=O)C)N)CCCC3
# The Scaffold is 	c1coc(-c2nc3sccc3c3c2CCCC3)c1
#
# Original SMILES is 	c1cc(sc1)C=C2C(=O)c3ccc(cc3O2)O
# The Scaffold is 	O=C1C(=Cc2cccs2)Oc2ccccc21
#
# Original SMILES is 	c1cc(ccc1C)NCc2cc3cc(c(cc3n(c2=O)CC(=O)Nc4ccc(cc4F)F)OC)OC
# The Scaffold is 	O=C(Cn1c(=O)c(CNc2ccccc2)cc2ccccc21)Nc1ccccc1
#
# Original SMILES is 	c1cc2c3c(c1)C(=O)N(C(=O)c3ccc2[N+](=O)[O-])OC(=O)C
# The Scaffold is 	O=C1NC(=O)c2cccc3cccc1c23
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)[S-](=O)(c5cccs5)[O-]
# The Scaffold is 	O=[SH-](c1cccs1)c1cn(Cc2ccco2)c2nc3ccccc3nc12
#
# Original SMILES is 	C(#N)C(c1c(nc2ccccc2n1)N3CCCC3)[S-](=O)(c4cc(ccc4C)C)[O-]
# The Scaffold is 	O=[SH-](Cc1nc2ccccc2nc1N1CCCC1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)c(c(s2)NC(=O)c3ccc(cc3)[N+](=O)[O-])c4cccs4
# The Scaffold is 	O=C(Nc1sc2ccccc2c(=O)c1-c1cccs1)c1ccccc1
#
# Original SMILES is 	C(#N)c1c(c2c(nc1N)CCN(C2)C)c3ccc(c(c3OC)OC)OC
# The Scaffold is 	c1ccc(-c2ccnc3c2CNCC3)cc1
#
# Original SMILES is 	c1cc2c(c3c1cc(c(=O)o3)c4ccc(c(c4)OC)OC)CN(CO2)CC5CCCO5
# The Scaffold is 	O=c1oc2c3c(ccc2cc1-c1ccccc1)OCN(CC1CCCO1)C3
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)CC(=O)Nc3c(c4c(s3)CN(CC4)C(C)C)C(=O)N
# The Scaffold is 	O=C(CN1C(=O)c2ccccc2C1=O)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1ccc(cc1)CN2Cc3c(c(c(s3)NC(=O)COc4ccc(cc4Cl)Cl)c5nc6ccccc6s5)CC2
# The Scaffold is 	O=C(COc1ccccc1)Nc1sc2c(c1-c1nc3ccccc3s1)CCN(Cc1ccccc1)C2
#
# Original SMILES is 	c1ccc2c(c1)ccc3c2cc(c(=O)o3)C(=O)Nc4nnc(o4)c5ccncc5
# The Scaffold is 	O=C(Nc1nnc(-c2ccncc2)o1)c1cc2c(ccc3ccccc32)oc1=O
#
# Original SMILES is 	c1cc(c(cc1C=NN=C2NC(=O)CS2)OC)OC
# The Scaffold is 	O=C1CSC(=NN=Cc2ccccc2)N1
#
# Original SMILES is 	c1ccc2c(c1)nc(o2)Sc3c4c5c(sc4nc(n3)C)CCCC5
# The Scaffold is 	c1ccc2oc(Sc3ncnc4sc5c(c34)CCCC5)nc2c1
#
# Original SMILES is 	c1ccc2c[n+](ccc2c1)CC(=O)N
# The Scaffold is 	c1ccc2c[nH+]ccc2c1
#
# Original SMILES is 	c1cc(oc1)CN[S-](=O)(c2ccc(c(c2)C(=O)O)OC)[O-]
# The Scaffold is 	O=[SH-](NCc1ccco1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)ccc(c2C=Nc3ccc(cc3OC)OC)O
# The Scaffold is 	C(=Nc1ccccc1)c1cccc2ccccc12
#
# Original SMILES is 	c1ccc2c(c1)c3c(c(c(o3)C)C(=O)C)c4c2OCN(C4)CCO
# The Scaffold is 	c1ccc2c(c1)c1c(c3ccoc32)CNCO1
#
# 230 total smiles
# 205 different scaffolds

# %% [markdown]
# # Below is scaffold for each fold

# %% [markdown]
# # Scaffold for fold 0

# %%
i = 0

smiles_list = data_pd_list[i][data_pd_list[i][Target_name]==1]['SMILES'].tolist()
scaffold_set = set()
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    core = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold = Chem.MolToSmiles(core)
    scaffold_set.add(scaffold)
    print 'Original SMILES is \t{}'.format(smiles)
    print 'The Scaffold is \t{}'.format(scaffold)
    print

print '{} total smiles'.format(len(smiles_list))
print '{} different scaffolds'.format(len(scaffold_set))
# Out:
# Original SMILES is 	c1cc(cc2c1CCCN2CCOC)N
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(cc5)OCC)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1C(=O)OC)sc(n2)NC(=O)c3ccc(cc3)N(C)C
# The Scaffold is 	O=C(Nc1nc2ccccc2s1)c1ccccc1
#
# Original SMILES is 	c1cc(ccc1C(=O)N=c2n(c3ccc(cc3s2)OC)CC(=O)OC)F
# The Scaffold is 	O=C(N=c1[nH]c2ccccc2s1)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)OCC)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(cc2c1CCCN2CCOC)NS(=O)(=O)c3ccc(cc3F)F
# The Scaffold is 	O=S(=O)(Nc1ccc2c(c1)NCCC2)c1ccccc1
#
# Original SMILES is 	c1cc(ccc1c2cc(nc3c2c(c(s3)C(=O)N4CCOCC4)N)c5ccc(cc5)Cl)OC
# The Scaffold is 	O=C(c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1)N1CCOCC1
#
# Original SMILES is 	c1ccc(cc1)c2nnc3n2nc(cc3)OCCNC(=O)COC
# The Scaffold is 	c1ccc(-c2nnc3cccnn23)cc1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccnn5C)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccn[nH]1
#
# Original SMILES is 	c1cc(cc(c1)Nc2nc(cs2)CC(=O)N)C(F)(F)F
# The Scaffold is 	c1ccc(Nc2nccs2)cc1
#
# Original SMILES is 	c1cc(cc2c1nc(n(c2=O)c3ccc(cc3)Cl)C)NC(=O)Nc4ccc5c(c4)OCO5
# The Scaffold is 	O=C(Nc1ccc2c(c1)OCO2)Nc1ccc2ncn(-c3ccccc3)c(=O)c2c1
#
# Original SMILES is 	c1cc2c(cc1c3csc(n3)NC(=O)COc4ccc(cc4Cl)Cl)OCCO2
# The Scaffold is 	O=C(COc1ccccc1)Nc1nc(-c2ccc3c(c2)OCCO3)cs1
#
# Original SMILES is 	C#CCn1c2ccc(cc2sc1=NC(=O)c3nc4ccccc4s3)NC(=O)C
# The Scaffold is 	O=C(N=c1[nH]c2ccccc2s1)c1nc2ccccc2s1
#
# Original SMILES is 	c1ccc2c(c1)nc3c4cc(ccc4n(c3n2)CCCC)C
# The Scaffold is 	c1ccc2nc3c(nc2c1)[nH]c1ccccc13
#
# Original SMILES is 	c1ccc2c(c1)-c3c4c(c(ccc4[nH]c(=O)c3C(=O)C)Cl)C2=O
# The Scaffold is 	O=C1c2ccccc2-c2cc(=O)[nH]c3cccc1c23
#
# Original SMILES is 	c1cc(cc(c1)Cl)N=Cc2cc(cc(c2O)Br)Br
# The Scaffold is 	C(=Nc1ccccc1)c1ccccc1
#
# Original SMILES is 	c1cc(c(c(c1)OC)O)c2nc3c(c(=S)[nH]2)Cc4cccc(c4O3)OCC
# The Scaffold is 	S=c1[nH]c(-c2ccccc2)nc2c1Cc1ccccc1O2
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3cc4c(nc5ccccn5c4=O)n(c3=N)Cc6ccco6
# The Scaffold is 	N=c1c(-c2nc3ccccc3s2)cc2c(=O)n3ccccc3nc2n1Cc1ccco1
#
# Original SMILES is 	c1cc(ccc1NC(=O)c2c(c3cc(c(cc3o2)C)C)C)[S-](=O)(Nc4cc(nc(n4)C)C)[O-]
# The Scaffold is 	O=C(Nc1ccc([SH-](=O)Nc2ccncn2)cc1)c1cc2ccccc2o1
#
# Original SMILES is 	c1cc(sc1C(=O)Nc2nc(cs2)c3cc(sc3Cl)Cl)[N+](=O)[O-]
# The Scaffold is 	O=C(Nc1nc(-c2ccsc2)cs1)c1cccs1
#
# Original SMILES is 	C#CCn1c2c(cccc2Cl)sc1=NC(=O)c3cc(=O)c4ccccc4o3
# The Scaffold is 	O=C(N=c1[nH]c2ccccc2s1)c1cc(=O)c2ccccc2o1
#
# Original SMILES is 	c1cc(oc1)C2c3c(=O)c4cc(ccc4oc3C(=O)N2CCN5CCOCC5)Cl
# The Scaffold is 	O=C1c2oc3ccccc3c(=O)c2C(c2ccco2)N1CCN1CCOCC1
#
# Original SMILES is 	c1ccc(cc1)C=CCSc2nnc(c(=O)n2N)C
# The Scaffold is 	O=c1cnnc(SCC=Cc2ccccc2)[nH]1
#
# Original SMILES is 	c1cc(c(c2c1c(cc(=O)o2)CN3CCCCC3)C)O
# The Scaffold is 	O=c1cc(CN2CCCCC2)c2ccccc2o1
#
# Original SMILES is 	c1cc(c(c2c1c(cc(=O)o2)CN3CCC4(CC3)OCCO4)C)O
# The Scaffold is 	O=c1cc(CN2CCC3(CC2)OCCO3)c2ccccc2o1
#
# Original SMILES is 	c1cc(sc1)CC(=O)Nc2c(nc3ccc(cn3c2=O)C)C
# The Scaffold is 	O=C(Cc1cccs1)Nc1cnc2ccccn2c1=O
#
# Original SMILES is 	c1ccc(cc1)c2nc(c(s2)C(=O)Nc3ccc(cc3)c4ccc5nnc(n5n4)c6ccncc6)C
# The Scaffold is 	O=C(Nc1ccc(-c2ccc3nnc(-c4ccncc4)n3n2)cc1)c1cnc(-c2ccccc2)s1
#
# Original SMILES is 	c1cn2c(cc1C)nc(nc2=O)SCC(=O)N3CCN(CC3)C(=O)OCC
# The Scaffold is 	O=C(CSc1nc(=O)n2ccccc2n1)N1CCNCC1
#
# Original SMILES is 	c1cc(cc(c1NC(=O)CSc2ccc(cc2)F)[N+](=O)[O-])OC
# The Scaffold is 	O=C(CSc1ccccc1)Nc1ccccc1
#
# Original SMILES is 	c1ccc(cc1)C(=O)Oc2ccc(cc2Cl)N[S-](=O)(c3ccc4ccccc4c3)[O-]
# The Scaffold is 	O=C(Oc1ccc(N[SH-](=O)c2ccc3ccccc3c2)cc1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(cc3c2oc(c3C(=O)C)C)N[S-](=O)(c4ccc(cc4)Br)[O-]
# The Scaffold is 	O=[SH-](Nc1cc2ccoc2c2ccccc12)c1ccccc1
#
# Original SMILES is 	c1cc(cc2c1C(=O)C(=Cc3ccc(cc3)Cl)O2)O
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2ccccc21
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c(cccn3)C(=O)Nc4ccc(cc4)C(=O)O
# The Scaffold is 	O=C(Nc1ccccc1)c1cccnc1-c1nc2ccccc2s1
#
# Original SMILES is 	c1cc2c(cc1NC(=O)CN3C(=O)C(NC3=O)(CC)CC)OCCO2
# The Scaffold is 	O=C(CN1C(=O)CNC1=O)Nc1ccc2c(c1)OCCO2
#
# Original SMILES is 	c1cc2c(c3c1cc(c(=O)o3)c4ccc(cc4)OC)CN(CO2)C(C)C
# The Scaffold is 	O=c1oc2c3c(ccc2cc1-c1ccccc1)OCNC3
#
# Original SMILES is 	C(#N)c1c2c(sc1NC(=O)CN3C(=O)CCC3=O)CN(CC2)C(C)C
# The Scaffold is 	O=C(CN1C(=O)CCC1=O)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1cc2c3c(c1)C(=O)N(C(=O)c3ccc2N4CCCCC4)CCOC(=O)c5ccc(cc5)[S-](=O)(N6CCCCC6)[O-]
# The Scaffold is 	O=C(OCCN1C(=O)c2cccc3c(N4CCCCC4)ccc(c23)C1=O)c1ccc([SH-](=O)N2CCCCC2)cc1
#
# Original SMILES is 	c1cc2c(cc1C(=O)Nc3nc(cs3)c4ccc(s4)Br)scn2
# The Scaffold is 	O=C(Nc1nc(-c2cccs2)cs1)c1ccc2ncsc2c1
#
# Original SMILES is 	c1ccc2c(c1)CCCN2C(=O)CSc3nc4c(c(=O)n3c5ccc(cc5)[N+](=O)[O-])SCC4
# The Scaffold is 	O=C(CSc1nc2c(c(=O)n1-c1ccccc1)SCC2)N1CCCc2ccccc21
#
# Original SMILES is 	c1cc(c2c(c1)sc(n2)Nc3nc4c(cc(cc4s3)F)F)OC
# The Scaffold is 	c1ccc2sc(Nc3nc4ccccc4s3)nc2c1
#
# Original SMILES is 	c1ccc(c(c1)C(=O)NCc2ccc3c(c2)cc(n3C)C)Cl
# The Scaffold is 	O=C(NCc1ccc2[nH]ccc2c1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(c(s2)C(=O)OC)NC(=O)c3cc(sc3Cl)Cl
# The Scaffold is 	O=C(Nc1csc2ccccc12)c1ccsc1
#
# Original SMILES is 	c1ccc2c(c1)C3c4ccccc4C2C5C3C(=O)N(C5=O)C(C(=O)O)Cc6cnc[nH]6
# The Scaffold is 	O=C1C2C3c4ccccc4C(c4ccccc43)C2C(=O)N1CCc1cnc[nH]1
#
# Original SMILES is 	c1ccc(cc1)CN2C(=O)c3cccc(c3C2=O)N
# The Scaffold is 	O=C1c2ccccc2C(=O)N1Cc1ccccc1
#
# Original SMILES is 	C(#N)c1c(nc(nc1O)N2CCCCC2)c3ccc4c(c3)OCO4
# The Scaffold is 	c1cc(-c2ccc3c(c2)OCO3)nc(N2CCCCC2)n1
#
# Original SMILES is 	C(#N)C1=C(N2C(=C(C1c3ccccc3)C#N)SCCC2)N
# The Scaffold is 	C1=CN2CCCSC2=CC1c1ccccc1
#
# Original SMILES is 	c1cc(oc1)C(=O)C2=C(C(=O)N(C2c3ccc(cc3)Br)c4nnc(s4)C)O
# The Scaffold is 	O=C(C1=CC(=O)N(c2nncs2)C1c1ccccc1)c1ccco1
#
# 47 total smiles
# 46 different scaffolds

# %% [markdown]
# # Scaffold for fold 1

# %%
i = 1

smiles_list = data_pd_list[i][data_pd_list[i][Target_name]==1]['SMILES'].tolist()
scaffold_set = set()
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    core = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold = Chem.MolToSmiles(core)
    scaffold_set.add(scaffold)
    print 'Original SMILES is \t{}'.format(smiles)
    print 'The Scaffold is \t{}'.format(scaffold)
    print

print '{} total smiles'.format(len(smiles_list))
print '{} different scaffolds'.format(len(scaffold_set))
# Out:
# Original SMILES is 	c1cc(ccc1C(=O)Nc2nc3c(s2)CCCC3)OCCCC
# The Scaffold is 	O=C(Nc1nc2c(s1)CCCC2)c1ccccc1
#
# Original SMILES is 	c1ccc(c(c1)c2csc(n2)NC(=O)C(C)C)OC
# The Scaffold is 	c1ccc(-c2cscn2)cc1
#
# Original SMILES is 	c1ccc2c(c1)-c3c(sc(n3)NC(=O)c4nc5ccccc5s4)C2
# The Scaffold is 	O=C(Nc1nc2c(s1)Cc1ccccc1-2)c1nc2ccccc2s1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)C(=O)NCCOC)CCCN2CC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(cc(c1)S(=O)(=O)NCCc2ccc3c(c2)CCCN3CCC)F
# The Scaffold is 	O=S(=O)(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc(ccc1CSc2nc(cs2)CC(=O)Nc3nccs3)Br
# The Scaffold is 	O=C(Cc1csc(SCc2ccccc2)n1)Nc1nccs1
#
# Original SMILES is 	c1ccnc(c1)CNC(=O)Cc2csc(n2)SCc3ccc(cc3)Br
# The Scaffold is 	O=C(Cc1csc(SCc2ccccc2)n1)NCc1ccccn1
#
# Original SMILES is 	c1cc2cc(oc2c(c1)OC)C(=O)Nc3nnc(o3)c4ccc(cc4)SC
# The Scaffold is 	O=C(Nc1nnc(-c2ccccc2)o1)c1cc2ccccc2o1
#
# Original SMILES is 	c1ccc(cc1)c2csc3c2ncn(c3=O)Cc4cc(=O)n5ccccc5n4
# The Scaffold is 	O=c1c2scc(-c3ccccc3)c2ncn1Cc1cc(=O)n2ccccc2n1
#
# Original SMILES is 	c1cc(cc(c1)Cl)c2csc3c2ncn(c3=O)Cc4cc(=O)n5ccccc5n4
# The Scaffold is 	O=c1c2scc(-c3ccccc3)c2ncn1Cc1cc(=O)n2ccccc2n1
#
# Original SMILES is 	c1cc2c(cc1CN3CCN(CC3)C(=O)CCc4nc5c(c6c(s5)CCCCC6)c(=O)[nH]4)OCO2
# The Scaffold is 	O=C(CCc1nc2sc3c(c2c(=O)[nH]1)CCCCC3)N1CCN(Cc2ccc3c(c2)OCO3)CC1
#
# Original SMILES is 	c1cc(ccc1c2c3c(c(sc3nc4c2C(=O)CC(C4)(C)C)C(=O)c5ccc6c(c5)OCCO6)N)OC
# The Scaffold is 	O=C(c1ccc2c(c1)OCCO2)c1cc2c(-c3ccccc3)c3c(nc2s1)CCCC3=O
#
# Original SMILES is 	c1ccnc(c1)CNC(=O)Cc2csc(n2)Nc3ccc(cc3)F
# The Scaffold is 	O=C(Cc1csc(Nc2ccccc2)n1)NCc1ccccn1
#
# Original SMILES is 	c1ccc(cc1)CN2Cc3c(c(c(s3)NC(=O)c4ccc(s4)c5nc6ccccc6s5)C(=O)OC)CC2
# The Scaffold is 	O=C(Nc1cc2c(s1)CN(Cc1ccccc1)CC2)c1ccc(-c2nc3ccccc3s2)s1
#
# Original SMILES is 	c1cc2c(cc1C(=O)Nc3c(c4c(s3)CN(CC4)C(=O)OCC)C(=O)OCC)scn2
# The Scaffold is 	O=C(Nc1cc2c(s1)CNCC2)c1ccc2ncsc2c1
#
# Original SMILES is 	C(#N)c1ccsc1NC(=O)c2cccs2
# The Scaffold is 	O=C(Nc1cccs1)c1cccs1
#
# Original SMILES is 	c1cc(nc2c1c(cc(n2)O)C)N
# The Scaffold is 	c1cnc2ncccc2c1
#
# Original SMILES is 	C(#N)c1ccsc1NC(=O)c2cc(cc(c2)Cl)Cl
# The Scaffold is 	O=C(Nc1cccs1)c1ccccc1
#
# Original SMILES is 	C(#N)c1c2nc3ccccc3n2c(cc1C)SCC(=O)c4ccc(c(c4)OC)OC
# The Scaffold is 	O=C(CSc1cccc2nc3ccccc3n12)c1ccccc1
#
# Original SMILES is 	c1c2c(cc3c1OCCO3)sc(n2)NN
# The Scaffold is 	c1nc2cc3c(cc2s1)OCCO3
#
# Original SMILES is 	c1ccc2c(c1)CCN2[S-](=O)(c3ccc(cc3)C(=O)Nc4nnc(o4)c5cc(ccc5C)C)[O-]
# The Scaffold is 	O=C(Nc1nnc(-c2ccccc2)o1)c1ccc([SH-](=O)N2CCc3ccccc32)cc1
#
# Original SMILES is 	c1cc(sc1)[S-](=O)(N2CCCC2C(=O)Nc3c(c4c(s3)CN(CC4)C(=O)C)C(=O)N)[O-]
# The Scaffold is 	O=C(Nc1cc2c(s1)CNCC2)C1CCCN1[SH-](=O)c1cccs1
#
# Original SMILES is 	c1ccc2c(c1)c(c[nH]2)NC(=O)NCc3ccccn3
# The Scaffold is 	O=C(NCc1ccccn1)Nc1c[nH]c2ccccc12
#
# Original SMILES is 	c1cc(oc1)c2c(sc(n2)NC(=O)CSc3c4cn[nH]c4ncn3)c5ccco5
# The Scaffold is 	O=C(CSc1ncnc2[nH]ncc12)Nc1nc(-c2ccco2)c(-c2ccco2)s1
#
# Original SMILES is 	c1ccc2c(c1)CC(N2C(=O)Nc3cccs3)C(=O)N
# The Scaffold is 	O=C(Nc1cccs1)N1CCc2ccccc21
#
# Original SMILES is 	c1ccc(cc1)C2c3cc(ccc3NC(N2CC(=O)OCC)c4ccccc4F)Br
# The Scaffold is 	c1ccc(C2Nc3ccccc3C(c3ccccc3)N2)cc1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)CC(=O)c3ccc(cc3O)O
# The Scaffold is 	O=C(Cc1nc2ccccc2s1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)[S-](=O)(c5cccc(c5)Cl)[O-]
# The Scaffold is 	O=[SH-](c1ccccc1)c1cn(Cc2ccco2)c2nc3ccccc3nc12
#
# Original SMILES is 	C(#N)C(c1c(nc2ccccc2n1)N3CCN(CC3)c4ccccc4)C(=O)OCC=C
# The Scaffold is 	c1ccc(N2CCN(c3cnc4ccccc4n3)CC2)cc1
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)C(=O)OCCC
# The Scaffold is 	c1coc(Cn2ccc3nc4ccccc4nc32)c1
#
# Original SMILES is 	c1ccc2c(c1)c3cc4c(cc3n2C)cc(nc4C)O
# The Scaffold is 	c1ccc2c(c1)[nH]c1cc3ccncc3cc12
#
# Original SMILES is 	c1cc(oc1)CN2Cc3c(ccc4c3oc(=O)c(c4)c5ccc(c(c5)OC)OC)OC2
# The Scaffold is 	O=c1oc2c3c(ccc2cc1-c1ccccc1)OCN(Cc1ccco1)C3
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(cc5)[S-](=O)(N6CCCCCC6)[O-])CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccc([SH-](=O)N2CCCCCC2)cc1
#
# Original SMILES is 	c1cc(ccc1NC(=O)c2cnc3n(c2=O)CCS3)[S-](=O)(Nc4ncccn4)[O-]
# The Scaffold is 	O=C(Nc1ccc([SH-](=O)Nc2ncccn2)cc1)c1cnc2n(c1=O)CCS2
#
# Original SMILES is 	c1cc(ccc1C(=O)N=c2c(cc3c(n2CC4CCCO4)nc5ccccn5c3=O)C(=O)OCC)Br
# The Scaffold is 	O=C(N=c1ccc2c(=O)n3ccccc3nc2n1CC1CCCO1)c1ccccc1
#
# Original SMILES is 	c1ccc(c(c1)c2nnc(o2)Nc3nc4ccc(cc4s3)F)OC
# The Scaffold is 	c1ccc(-c2nnc(Nc3nc4ccccc4s3)o2)cc1
#
# Original SMILES is 	c1ccc2c(c1)ccc(n2)C(=O)Nc3ccc(cc3C)c4nc5cccnc5s4
# The Scaffold is 	O=C(Nc1ccc(-c2nc3cccnc3s2)cc1)c1ccc2ccccc2n1
#
# Original SMILES is 	c1cc(c(cc1C)[N+](=O)[O-])N2C(=O)C=CC2=O
# The Scaffold is 	O=C1C=CC(=O)N1c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)[S-](=O)(N=Cc2cc(ccc2O)Br)[O-]
# The Scaffold is 	O=[SH-](N=Cc1ccccc1)c1ccccc1
#
# Original SMILES is 	c1cc(sc1)C(=O)NC(=S)Nc2cc(c(s2)C(=O)OCC)C
# The Scaffold is 	O=C(NC(=S)Nc1cccs1)c1cccs1
#
# Original SMILES is 	c1cc(sc1C=Nc2nnc(s2)NC(=O)c3cc(cc(c3)C)C)Br
# The Scaffold is 	O=C(Nc1nnc(N=Cc2cccs2)s1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)cccc2NC(=N[S-](=O)(c3ccc(cc3)Cl)[O-])CSC(=O)N
# The Scaffold is 	O=[SH-](N=CNc1cccc2ccccc12)c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2c(nnc(n2)NN=CC=Cc3ccco3)c4ccccc4
# The Scaffold is 	C(=Cc1ccco1)C=NNc1nnc(-c2ccccc2)c(-c2ccccc2)n1
#
# Original SMILES is 	c1ccc(c(c1)N=Cc2cc(cc(c2O)Br)Br)F
# The Scaffold is 	C(=Nc1ccccc1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c3c(c(c(o3)C)C(=O)OCC)c4c2OCN(C4)C5CCCCC5
# The Scaffold is 	c1ccc2c(c1)c1c(c3ccoc32)CN(C2CCCCC2)CO1
#
# 45 total smiles
# 44 different scaffolds

# %% [markdown]
# # Scaffold for fold 2

# %%
i = 2

smiles_list = data_pd_list[i][data_pd_list[i][Target_name]==1]['SMILES'].tolist()
scaffold_set = set()
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    core = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold = Chem.MolToSmiles(core)
    scaffold_set.add(scaffold)
    print 'Original SMILES is \t{}'.format(smiles)
    print 'The Scaffold is \t{}'.format(scaffold)
    print

print '{} total smiles'.format(len(smiles_list))
print '{} different scaffolds'.format(len(scaffold_set))
# Out:
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5c(cccc5F)F)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(s5)Cl)CN(CC4)C(C)C
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cccs1
#
# Original SMILES is 	c1cc2c(c(c1)N)C(=O)N(C2=O)C
# The Scaffold is 	O=C1NC(=O)c2ccccc21
#
# Original SMILES is 	c1c2c3c(cc1N)CCCN3C(=O)CC2
# The Scaffold is 	O=C1CCc2cccc3c2N1CCC3
#
# Original SMILES is 	c1ccc(c(c1)C(=O)NCCc2ccc3c(c2)CCCN3CCC)OCC
# The Scaffold is 	O=C(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)Cc3ccc(cc3)F)CCCN2CCC
# The Scaffold is 	O=C(Cc1ccccc1)NCCc1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(cc2c1CCCN2CCOC)NS(=O)(=O)Cc3ccc(cc3)Cl
# The Scaffold is 	O=S(=O)(Cc1ccccc1)Nc1ccc2c(c1)NCCC2
#
# Original SMILES is 	c1cc(ccc1SCC(=O)Nc2c(c3c(s2)CN(CC3)C(=O)C)C(=O)N)Cl
# The Scaffold is 	O=C(CSc1ccccc1)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1cc(ccc1S(=O)(=O)CC(=O)Nc2c(c3c(s2)CN(CC3)C(=O)C)C(=O)N)Cl
# The Scaffold is 	O=C(CS(=O)(=O)c1ccccc1)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1cc(ccc1F)S(=O)(=O)CC(=O)Nc2c(c3c(s2)CN(CC3)CC)C(=O)N
# The Scaffold is 	O=C(CS(=O)(=O)c1ccccc1)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1ccc2c(c1)cc(cn2)NC(=O)C3CCN(CC3)c4ccc(nn4)c5ccco5
# The Scaffold is 	O=C(Nc1cnc2ccccc2c1)C1CCN(c2ccc(-c3ccco3)nn2)CC1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)cc(o2)C(=O)Nc3c(c4c(s3)CN(CC4)C(=O)C)c5nc6ccccc6s5
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cc(=O)c2ccccc2o1
#
# Original SMILES is 	c1ccc(cc1)C(c2ccccc2)C(=O)Nc3ccc(cc3)[S-](=O)(N4CCCC4)[O-]
# The Scaffold is 	O=C(Nc1ccc([SH-](=O)N2CCCC2)cc1)C(c1ccccc1)c1ccccc1
#
# Original SMILES is 	c1cc(oc1)C2C3C(=O)N(C(=O)C3ON2c4ccc(cc4)Cl)c5c(c(c(s5)C)C)C(=O)OC
# The Scaffold is 	O=C1C2ON(c3ccccc3)C(c3ccco3)C2C(=O)N1c1cccs1
#
# Original SMILES is 	c1cc(ccc1c2cc(c3c(c(sc3n2)C(=O)Nc4nccs4)N)c5ccc(c(c5)OC)OC)OC
# The Scaffold is 	O=C(Nc1nccs1)c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(ccc1c2nc3c(c(=S)[nH]2)Cc4cc(ccc4O3)Br)F
# The Scaffold is 	S=c1[nH]c(-c2ccccc2)nc2c1Cc1ccccc1O2
#
# Original SMILES is 	c1cc(cc(c1)F)C2C3=C(CC(CC3=O)(C)C)Nc4c2c(=O)n(c(=O)n4C)C
# The Scaffold is 	O=C1CCCC2=C1C(c1ccccc1)c1c([nH]c(=O)[nH]c1=O)N2
#
# Original SMILES is 	c1cc(oc1)CNC(=O)CSc2nnc(s2)NC(=O)C(C)(C)C
# The Scaffold is 	O=C(CSc1nncs1)NCc1ccco1
#
# Original SMILES is 	c1ccc2c(c1)cc(n2CCNC(=O)c3cc4c(o3)ccc(n4)C)C
# The Scaffold is 	O=C(NCCn1ccc2ccccc21)c1cc2ncccc2o1
#
# Original SMILES is 	c1cc2n(c1)CCN(C2c3ccc(cc3)F)C(=O)Nc4cccs4
# The Scaffold is 	O=C(Nc1cccs1)N1CCn2cccc2C1c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)CCN(C2)[S-](=O)(c3ccc(cc3)C(=O)NNc4nc5c(ccc(c5s4)Cl)OC)[O-]
# The Scaffold is 	O=C(NNc1nc2ccccc2s1)c1ccc([SH-](=O)N2CCc3ccccc3C2)cc1
#
# Original SMILES is 	c1ccc(cc1)CN2CCN(CC2)C(=O)Nc3c[nH]c4c3cccc4
# The Scaffold is 	O=C(Nc1c[nH]c2ccccc12)N1CCN(Cc2ccccc2)CC1
#
# Original SMILES is 	c1cc(cc(c1)[N+](=O)[O-])NC(=O)C(=O)Nc2ccc3c(c2)OCO3
# The Scaffold is 	O=C(Nc1ccccc1)C(=O)Nc1ccc2c(c1)OCO2
#
# Original SMILES is 	c1ccc2cc(ccc2c1)[S-](=O)(Nc3cc(c(c4c3cccc4)O)Br)[O-]
# The Scaffold is 	O=[SH-](Nc1cccc2ccccc12)c1ccc2ccccc2c1
#
# Original SMILES is 	c1ccc(cc1)C(=O)c2ccc3c4c2cccc4C(=O)N(C3=O)c5ccc6c7c5cccc7CC6
# The Scaffold is 	O=C(c1ccccc1)c1ccc2c3c(cccc13)C(=O)N(c1ccc3c4c(cccc14)CC3)C2=O
#
# Original SMILES is 	c1cc(sc1)C=C2C(=O)c3ccc(cc3O2)OC(=O)N4CCOCC4
# The Scaffold is 	O=C1C(=Cc2cccs2)Oc2cc(OC(=O)N3CCOCC3)ccc21
#
# Original SMILES is 	c1ccc(cc1)CNC(=O)Cn2c3cc4c(cc3cc(c2=O)CNc5ccc(cc5)CC)OCCO4
# The Scaffold is 	O=C(Cn1c(=O)c(CNc2ccccc2)cc2cc3c(cc21)OCCO3)NCc1ccccc1
#
# Original SMILES is 	c1cc(cc(c1c2cc(c(o2)C)C(=O)Nc3ccc(cc3)[S-](=O)(N)[O-])[N+](=O)[O-])Cl
# The Scaffold is 	O=C(Nc1ccccc1)c1coc(-c2ccccc2)c1
#
# Original SMILES is 	c1ccc2c(c1)nc3c4cc(ccc4n(c3n2)CC(=O)OCCCC)OC
# The Scaffold is 	c1ccc2nc3c(nc2c1)[nH]c1ccccc13
#
# Original SMILES is 	c1ccc(c(c1)c2ccc(o2)c3nnc(o3)c4ccco4)[N+](=O)[O-]
# The Scaffold is 	c1ccc(-c2ccc(-c3nnc(-c4ccco4)o3)o2)cc1
#
# Original SMILES is 	c1ccc2c(c1)cc(o2)C(=O)Nc3c(c4c(s3)CN(CC4)C)c5nc6ccccc6s5
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cc2ccccc2o1
#
# Original SMILES is 	c1ccc(c(c1)CN2c3c(cccc3Cl)C4(C2=O)N(N=C(S4)NC(=O)C)C(=O)C)OCC
# The Scaffold is 	O=C1N(Cc2ccccc2)c2ccccc2C12NN=CS2
#
# Original SMILES is 	c1ccnc(c1)c2cc([nH]c2c3cc(cc(c3)Cl)Cl)C
# The Scaffold is 	c1ccc(-c2[nH]ccc2-c2ccccn2)cc1
#
# Original SMILES is 	c1cc2cc(cc(c2nc1)NC(=O)CCC(=O)O)OC
# The Scaffold is 	c1ccc2ncccc2c1
#
# Original SMILES is 	c1ccnc(c1)CC(=O)c2cc(cc(c2)Cl)Cl
# The Scaffold is 	O=C(Cc1ccccn1)c1ccccc1
#
# Original SMILES is 	c1cc(sc1)CC(=O)Nc2cc(nc3c2cc(cc3C)C)C
# The Scaffold is 	O=C(Cc1cccs1)Nc1ccnc2ccccc12
#
# Original SMILES is 	c1cc(cc(c1)F)C=C2C(=O)c3ccc4c(c3O2)CN(CO4)C5CC5
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2c1ccc1c2CN(C2CC2)CO1
#
# Original SMILES is 	c1ccc(cc1)N=C2NC(=O)C(S2)Cc3cccc(c3)[N+](=O)[O-]
# The Scaffold is 	O=C1NC(=Nc2ccccc2)SC1Cc1ccccc1
#
# Original SMILES is 	c1cc2c(c(c1)OCC)oc(=O)c(c2)c3nnc(s3)Nc4ccc(cc4)C(=O)OCC
# The Scaffold is 	O=c1oc2ccccc2cc1-c1nnc(Nc2ccccc2)s1
#
# Original SMILES is 	c1cc2c(c(c1)[N+](=O)[O-])C(=O)N(C2=O)c3cccc(c3)C(=O)C
# The Scaffold is 	O=C1c2ccccc2C(=O)N1c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)c3ccc(cc3)OC(=O)CC
# The Scaffold is 	O=C1c2ccccc2C(=O)N1c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2c([n+]3c4ccccc4nc(c3s2)C)[O-]
# The Scaffold is 	c1ccc(-c2c[n+]3c(cnc4ccccc43)s2)cc1
#
# Original SMILES is 	c1ccc(c(c1)C2C3=C(CCCC3=O)Nc4c2c(=O)[nH]c(=O)[nH]4)[N+](=O)[O-]
# The Scaffold is 	O=C1CCCC2=C1C(c1ccccc1)c1c([nH]c(=O)[nH]c1=O)N2
#
# Original SMILES is 	C(#N)C(=C1Nc2ccccc2N1)C(=O)c3ccccc3Br
# The Scaffold is 	O=C(C=C1Nc2ccccc2N1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(cc(c2O)Cl)N[S-](=O)(c3cc(c(cc3C)C)C)[O-]
# The Scaffold is 	O=[SH-](Nc1cccc2ccccc12)c1ccccc1
#
# 45 total smiles
# 42 different scaffolds

# %% [markdown]
# # Scaffold for fold 3

# %%
i = 3

smiles_list = data_pd_list[i][data_pd_list[i][Target_name]==1]['SMILES'].tolist()
scaffold_set = set()
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    core = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold = Chem.MolToSmiles(core)
    scaffold_set.add(scaffold)
    print 'Original SMILES is \t{}'.format(smiles)
    print 'The Scaffold is \t{}'.format(scaffold)
    print

print '{} total smiles'.format(len(smiles_list))
print '{} different scaffolds'.format(len(scaffold_set))
# Out:
# Original SMILES is 	c1cc(cc(c1)CS(=O)(=O)Nc2ccc3c(c2)N(CCC3)CCOC)C
# The Scaffold is 	O=S(=O)(Cc1ccccc1)Nc1ccc2c(c1)NCCC2
#
# Original SMILES is 	c1ccc(cc1)N(C)S(=O)(=O)c2ccc(cc2)C(=O)Nc3c(c4c(s3)CN(CC4)CCC)C(=O)NC
# The Scaffold is 	O=C(Nc1cc2c(s1)CNCC2)c1ccc(S(=O)(=O)Nc2ccccc2)cc1
#
# Original SMILES is 	c1(c(c([nH]c1C)C(=O)CN2CCCCCC2)C)C(=O)OC
# The Scaffold is 	O=C(CN1CCCCCC1)c1ccc[nH]1
#
# Original SMILES is 	c1ccc(c(c1)C(=O)NCCc2ccc3c(c2)CCCN3CC)C(F)(F)F
# The Scaffold is 	O=C(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)C(C)(C)C)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1ccc(cc1)CCNC(=O)c2c(c3c(cc(nc3s2)c4ccc(cc4)Cl)c5ccc(cc5)OC)N
# The Scaffold is 	O=C(NCCc1ccccc1)c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1ccc(c(c1)C(=O)Nc2cc(ccc2OC)c3cn4c(n3)ccc(n4)OC)Cl
# The Scaffold is 	O=C(Nc1cccc(-c2cn3ncccc3n2)c1)c1ccccc1
#
# Original SMILES is 	c1cc(cc(c1OC)S(=O)(=O)N2CCN(CC2)c3ccc(nn3)c4ccncc4)Cl
# The Scaffold is 	O=S(=O)(c1ccccc1)N1CCN(c2ccc(-c3ccncc3)nn2)CC1
#
# Original SMILES is 	c1ccc(cc1)C(C(=O)Nc2cc(nn2c3nc(c(c(=O)[nH]3)C)C)c4ccco4)CC
# The Scaffold is 	O=C(Cc1ccccc1)Nc1cc(-c2ccco2)nn1-c1nccc(=O)[nH]1
#
# Original SMILES is 	c1ccc(cc1)c2c(c3ccccc3n2O)C(c4ccccn4)N5CCN(CC5)C(=O)OCC
# The Scaffold is 	c1ccc(-c2[nH]c3ccccc3c2C(c2ccccn2)N2CCNCC2)cc1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)CCCn3c4ccc(cc4c5c3nc6ccccc6n5)C
# The Scaffold is 	O=C1c2ccccc2C(=O)N1CCCn1c2ccccc2c2nc3ccccc3nc21
#
# Original SMILES is 	c1cc(cc(c1N=Cc2c(nc3c(cccn3c2=O)C)NC(C)CC)Cl)[N+](=O)[O-]
# The Scaffold is 	O=c1c(C=Nc2ccccc2)cnc2ccccn12
#
# Original SMILES is 	c1ccc(c(c1)C=C2C(=O)c3cc(ccc3O2)C(=O)OC)F
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2ccccc21
#
# Original SMILES is 	c1cc(ccc1CN(C(=O)C(C)C)C2CC[S-](=O)(C2)[O-])Cl
# The Scaffold is 	O=[SH-]1CCC(NCc2ccccc2)C1
#
# Original SMILES is 	c1cc(ccc1c2nc([nH]n2)SC(c3ccc(cc3)OC)CC(=O)NCCN4CCOCC4)OC
# The Scaffold is 	O=C(CC(Sc1nc(-c2ccccc2)n[nH]1)c1ccccc1)NCCN1CCOCC1
#
# Original SMILES is 	C1(=C(CC2C(=O)N(C(=O)C2C1)CC)C)C
# The Scaffold is 	O=C1NC(=O)C2CC=CCC12
#
# Original SMILES is 	c1cc(cc(c1C(=O)CN2CCN(CC2)C(=O)OCC)O)O
# The Scaffold is 	O=C(CN1CCNCC1)c1ccccc1
#
# Original SMILES is 	c1ccc2cc3c(cc2c1)c(=O)n(c(n3)C)N=CN(C)C
# The Scaffold is 	O=c1[nH]cnc2cc3ccccc3cc12
#
# Original SMILES is 	c1c2c(nccn2)nc(c1Br)C(=O)O
# The Scaffold is 	c1cnc2nccnc2c1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)cc(o2)C(=O)Nc3cc(nn3c4nc5c(c(=O)[nH]4)CCC5)C
# The Scaffold is 	O=C(Nc1ccnn1-c1nc2c(c(=O)[nH]1)CCC2)c1cc(=O)c2ccccc2o1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)c(co2)C=C3C(=O)OC(=N3)C=Cc4ccccc4OC
# The Scaffold is 	O=C1OC(C=Cc2ccccc2)=NC1=Cc1coc2ccccc2c1=O
#
# Original SMILES is 	c1ccc(cc1)CN2Cc3c(c(c(s3)NC(=O)C[S-](=O)(c4ccccc4)[O-])C(=O)N)CC2
# The Scaffold is 	O=C(C[SH-](=O)c1ccccc1)Nc1cc2c(s1)CN(Cc1ccccc1)CC2
#
# Original SMILES is 	c1ccc2c(c1)c(c[nH]2)NC(=O)N3CCN(CC3)c4ccccc4Cl
# The Scaffold is 	O=C(Nc1c[nH]c2ccccc12)N1CCN(c2ccccc2)CC1
#
# Original SMILES is 	c1cc2c(nc1)n(c(=O)c(c2)C(=O)Nc3ccc(cc3)c4nc5ccc(cc5s4)C)C
# The Scaffold is 	O=C(Nc1ccc(-c2nc3ccccc3s2)cc1)c1cc2cccnc2[nH]c1=O
#
# Original SMILES is 	c1cc(nc(c1)C(=O)Nc2nc3c(s2)C(=O)CC(C3)(C)C)C(=O)Nc4nc5c(s4)C(=O)CC(C5)(C)C
# The Scaffold is 	O=C(Nc1nc2c(s1)C(=O)CCC2)c1cccc(C(=O)Nc2nc3c(s2)C(=O)CCC3)n1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3nc4ccc(cc4s3)OC
# The Scaffold is 	c1ccc2sc(-c3nc4ccccc4s3)nc2c1
#
# Original SMILES is 	c1cc(cc(c1)NC(=O)CSc2ccc(cc2[N+](=O)[O-])[N+](=O)[O-])C(F)(F)F
# The Scaffold is 	O=C(CSc1ccccc1)Nc1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)nc3c4cc(ccc4n(c3n2)CC)OC
# The Scaffold is 	c1ccc2nc3c(nc2c1)[nH]c1ccccc13
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)c5nc6ccccc6n5C
# The Scaffold is 	c1coc(Cn2cc(-c3nc4ccccc4[nH]3)c3nc4ccccc4nc32)c1
#
# Original SMILES is 	c1ccc(cc1)C2C(=C(C(=O)N2c3nccs3)O)C(=O)c4cc5ccccc5o4
# The Scaffold is 	O=C(C1=CC(=O)N(c2nccs2)C1c1ccccc1)c1cc2ccccc2o1
#
# Original SMILES is 	c1cc(ccc1c2c3cc(ccc3no2)Cl)O
# The Scaffold is 	c1ccc(-c2onc3ccccc23)cc1
#
# Original SMILES is 	c1ccnc(c1)N2C(=O)c3c(c(=O)c4cc(ccc4o3)Cl)C2c5ccc(cc5)C(=O)OC
# The Scaffold is 	O=C1c2oc3ccccc3c(=O)c2C(c2ccccc2)N1c1ccccn1
#
# Original SMILES is 	c1ccc2c(c1)c-3n[nH]c(nc3n2)SCC(=O)c4ccc(cc4)C
# The Scaffold is 	O=C(CSc1nc2nc3ccccc3c-2n[nH]1)c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2cc(n3c(n2)c(cn3)c4ccc(cc4)Cl)N5CCN(CC5)CCO
# The Scaffold is 	c1ccc(-c2cc(N3CCNCC3)n3ncc(-c4ccccc4)c3n2)cc1
#
# Original SMILES is 	c1c2c(nc3ccccn3c2=O)sc1C(=O)Nc4nnc(s4)C5CC5
# The Scaffold is 	O=C(Nc1nnc(C2CC2)s1)c1cc2c(=O)n3ccccc3nc2s1
#
# Original SMILES is 	c1cc(cc(c1)[N+](=O)[O-])c2nnc(s2)NC(=O)CSc3nnc(s3)NC(=O)COc4ccc(cc4Cl)Cl
# The Scaffold is 	O=C(COc1ccccc1)Nc1nnc(SCC(=O)Nc2nnc(-c3ccccc3)s2)s1
#
# Original SMILES is 	c1cc(cc(c1)Br)C(=O)c2c(c3c(c4c(nc3s2)CCCC4)c5cccs5)N
# The Scaffold is 	O=C(c1ccccc1)c1cc2c(-c3cccs3)c3c(nc2s1)CCCC3
#
# Original SMILES is 	c1cc(ccc1C(=O)NNc2nc3c(ccc(c3s2)C)OC)[S-](=O)(N4CCCC4)[O-]
# The Scaffold is 	O=C(NNc1nc2ccccc2s1)c1ccc([SH-](=O)N2CCCC2)cc1
#
# Original SMILES is 	C(#N)c1c(c(sc1N=Cc2ccco2)C)C
# The Scaffold is 	C(=Nc1cccs1)c1ccco1
#
# Original SMILES is 	c1c(cc(cc1Cl)Cl)C(=O)Nc2c(c3c(s2)CCCCC3)C(=O)OCC
# The Scaffold is 	O=C(Nc1cc2c(s1)CCCCC2)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)C(C(=O)O)C
# The Scaffold is 	O=C1NC(=O)c2ccccc21
#
# Original SMILES is 	c1cc(cc2c1C(=O)N(C2=O)c3ccc(cc3)OC)C(=O)c4ccc5c(c4)C(=O)N(C5=O)c6ccc(cc6)OC
# The Scaffold is 	O=C(c1ccc2c(c1)C(=O)N(c1ccccc1)C2=O)c1ccc2c(c1)C(=O)N(c1ccccc1)C2=O
#
# Original SMILES is 	c1ccc(cc1)c2cc[n+]3c(c(sc3n2)c4ccccc4)N
# The Scaffold is 	c1ccc(-c2cc[n+]3cc(-c4ccccc4)sc3n2)cc1
#
# Original SMILES is 	c1ccc2c(c1)ccc(c2C=Nc3ccc(cc3)CC)O
# The Scaffold is 	C(=Nc1ccccc1)c1cccc2ccccc12
#
# Original SMILES is 	c1cc(cc(c1)NC(=O)C)C2=CC(n3c(ncn3)N2)c4cccc(c4)Br
# The Scaffold is 	C1=C(c2ccccc2)Nc2ncnn2C1c1ccccc1
#
# Original SMILES is 	c1c(n2c(s1)nc(=O)c(n2)C)N
# The Scaffold is 	O=c1cnn2ccsc2n1
#
# 46 total smiles
# 46 different scaffolds

# %% [markdown]
# # Scaffold for fold 4

# %%
i = 4

smiles_list = data_pd_list[i][data_pd_list[i][Target_name]==1]['SMILES'].tolist()
scaffold_set = set()
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    core = MurckoScaffold.GetScaffoldForMol(mol)
    scaffold = Chem.MolToSmiles(core)
    scaffold_set.add(scaffold)
    print 'Original SMILES is \t{}'.format(smiles)
    print 'The Scaffold is \t{}'.format(scaffold)
    print

print '{} total smiles'.format(len(smiles_list))
print '{} different scaffolds'.format(len(scaffold_set))
# Out:
# Original SMILES is 	c1ccnc(c1)CN2Cc3c(ccc4c3OC(=Cc5cccc(c5)F)C4=O)OC2
# The Scaffold is 	O=C1C(=Cc2ccccc2)Oc2c1ccc1c2CN(Cc2ccccn2)CO1
#
# Original SMILES is 	C(#N)c1ccc(cc1)C(=O)Nc2c(c3c(s2)CCCC3)C#N
# The Scaffold is 	O=C(Nc1cc2c(s1)CCCC2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNC(=O)COCC)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cc(ccc1C(=O)NCCc2ccc3c(c2)CCCN3CC)OC(C)C
# The Scaffold is 	O=C(NCCc1ccc2c(c1)CCCN2)c1ccccc1
#
# Original SMILES is 	c1cc2c(cc1CCNS(=O)(=O)C)CCCN2CCC
# The Scaffold is 	c1ccc2c(c1)CCCN2
#
# Original SMILES is 	c1cscc1C(CNC(=O)c2cc(cc(c2)OC)OC)N3CCCC3
# The Scaffold is 	O=C(NCC(c1ccsc1)N1CCCC1)c1ccccc1
#
# Original SMILES is 	c1cc(c(cc1c2csc3c2ncn(c3=O)Cc4cc(=O)n5ccccc5n4)OC)OC
# The Scaffold is 	O=c1c2scc(-c3ccccc3)c2ncn1Cc1cc(=O)n2ccccc2n1
#
# Original SMILES is 	c1ccc(cc1)c2cc(c3c(c(sc3n2)C(=O)NCC4CCCO4)N)c5ccc(cc5)OC
# The Scaffold is 	O=C(NCC1CCCO1)c1cc2c(-c3ccccc3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(c(cc1C(=O)c2c(c3c(c4c(nc3s2)CC(CC4=O)(C)C)CC)N)Cl)Cl
# The Scaffold is 	O=C(c1ccccc1)c1cc2cc3c(nc2s1)CCCC3=O
#
# Original SMILES is 	c1ccnc(c1)CNC(=O)Cc2csc(n2)Nc3ccc(cc3)OC(F)(F)F
# The Scaffold is 	O=C(Cc1csc(Nc2ccccc2)n1)NCc1ccccn1
#
# Original SMILES is 	c1ccc2c(c1)cc(n2C)c3nc(cs3)C(=O)NN4CCOCC4
# The Scaffold is 	O=C(NN1CCOCC1)c1csc(-c2cc3ccccc3[nH]2)n1
#
# Original SMILES is 	c1ccc2c(c1)nc(s2)c3c4c(sc3NC(=O)c5ccc(s5)Br)CN(CC4)C(=O)OCC
# The Scaffold is 	O=C(Nc1sc2c(c1-c1nc3ccccc3s1)CCNC2)c1cccs1
#
# Original SMILES is 	c1ccc2c(c1)c(c[nH]2)C=NNC(=O)CCC(C3CCC4C3(CCC5C4C(CC6C5(CCC(C6)O)C)O)C)C
# The Scaffold is 	O=C(CCCC1CCC2C1CCC1C3CCCCC3CCC21)NN=Cc1c[nH]c2ccccc12
#
# Original SMILES is 	c1cc(ccc1c2cc(c3c(c(sc3n2)C(=O)Nc4ccc(cc4)OCC)N)C(F)(F)F)Cl
# The Scaffold is 	O=C(Nc1ccccc1)c1cc2ccc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(ccc1c2cc(c3c(c(sc3n2)C(=O)c4ccc(c(c4)Br)OC)N)C(F)(F)F)C
# The Scaffold is 	O=C(c1ccccc1)c1cc2ccc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)O[S-](=O)(c3ccc(cc3C)F)[O-]
# The Scaffold is 	O=C1c2ccccc2C(=O)N1O[SH-](=O)c1ccccc1
#
# Original SMILES is 	c1ccc(cc1)c2c3cc(ccc3nc(n2)N4C(CC(=N4)c5cccc(c5)N[S-](=O)(C)[O-])c6ccco6)Cl
# The Scaffold is 	c1ccc(C2=NN(c3nc(-c4ccccc4)c4ccccc4n3)C(c3ccco3)C2)cc1
#
# Original SMILES is 	c1ccc(cc1)c2nc3c(c(n2)SCC(=O)Nc4cccc(c4)C(=O)O)Cc5cc(ccc5O3)C
# The Scaffold is 	O=C(CSc1nc(-c2ccccc2)nc2c1Cc1ccccc1O2)Nc1ccccc1
#
# Original SMILES is 	c1ccc(cc1)n2cc(c(n2)c3ccc(c(c3)F)OC)C=C4C(=O)c5cc(ccc5O4)C(=O)OC
# The Scaffold is 	O=C1C(=Cc2cn(-c3ccccc3)nc2-c2ccccc2)Oc2ccccc21
#
# Original SMILES is 	c1ccc(cc1)N=C2NC(=O)C(=CC=Cc3ccco3)S2
# The Scaffold is 	O=C1NC(=Nc2ccccc2)SC1=CC=Cc1ccco1
#
# Original SMILES is 	C1(=NO)CC2(CCC1(C2(C)C)C)C(=O)N3CCCCC3C
# The Scaffold is 	N=C1CC2(C(=O)N3CCCCC3)CCC1C2
#
# Original SMILES is 	c1ccc2c(c1)cc(oc2=O)C(=O)Nc3ncc(s3)Cc4ccc(cc4)C
# The Scaffold is 	O=C(Nc1ncc(Cc2ccccc2)s1)c1cc2ccccc2c(=O)o1
#
# Original SMILES is 	C(#N)c1c(c2c(nc1N)CCN(C2)C)c3ccco3
# The Scaffold is 	c1coc(-c2ccnc3c2CNCC3)c1
#
# Original SMILES is 	c1cc2cc(oc2c(c1)OC)c3csc(n3)NC(=O)c4ccc(cc4)[S-](=O)(N5CCCCC5CC)[O-]
# The Scaffold is 	O=C(Nc1nc(-c2cc3ccccc3o2)cs1)c1ccc([SH-](=O)N2CCCCC2)cc1
#
# Original SMILES is 	c1ccc(c(c1)C)Cn2cccc(c2=O)C(=O)Nc3cccc(c3Cl)Cl
# The Scaffold is 	O=C(Nc1ccccc1)c1cccn(Cc2ccccc2)c1=O
#
# Original SMILES is 	c1ccc(cc1)Cn2c3c(cccn3)cc(c2=O)C(=O)Nc4ccc(cc4OC)[N+](=O)[O-]
# The Scaffold is 	O=C(Nc1ccccc1)c1cc2cccnc2n(Cc2ccccc2)c1=O
#
# Original SMILES is 	c1cc2cc(cc3c2c(c1)C(=O)N(C3=O)O)N
# The Scaffold is 	O=C1NC(=O)c2cccc3cccc1c23
#
# Original SMILES is 	c1cc(oc1)c2cc(nc3c2c(c(s3)C(=O)Nc4ccc(cc4)C(=O)OCC)N)c5ccc(cc5)C
# The Scaffold is 	O=C(Nc1ccccc1)c1cc2c(-c3ccco3)cc(-c3ccccc3)nc2s1
#
# Original SMILES is 	c1cc(sc1)c2c3c(c4c(c(sc4n2)C(=O)NCc5ccc6c(c5)OCO6)N)CCCC3
# The Scaffold is 	O=C(NCc1ccc2c(c1)OCO2)c1cc2c3c(c(-c4cccs4)nc2s1)CCCC3
#
# Original SMILES is 	c1cc(oc1)c2c3c(c4c(c(sc4n2)C(=O)C)N)CCCC3
# The Scaffold is 	c1coc(-c2nc3sccc3c3c2CCCC3)c1
#
# Original SMILES is 	c1cc(sc1)C=C2C(=O)c3ccc(cc3O2)O
# The Scaffold is 	O=C1C(=Cc2cccs2)Oc2ccccc21
#
# Original SMILES is 	c1cc(ccc1C)NCc2cc3cc(c(cc3n(c2=O)CC(=O)Nc4ccc(cc4F)F)OC)OC
# The Scaffold is 	O=C(Cn1c(=O)c(CNc2ccccc2)cc2ccccc21)Nc1ccccc1
#
# Original SMILES is 	c1cc2c3c(c1)C(=O)N(C(=O)c3ccc2[N+](=O)[O-])OC(=O)C
# The Scaffold is 	O=C1NC(=O)c2cccc3cccc1c23
#
# Original SMILES is 	c1ccc2c(c1)nc3c(c(n(c3n2)Cc4ccco4)N)[S-](=O)(c5cccs5)[O-]
# The Scaffold is 	O=[SH-](c1cccs1)c1cn(Cc2ccco2)c2nc3ccccc3nc12
#
# Original SMILES is 	C(#N)C(c1c(nc2ccccc2n1)N3CCCC3)[S-](=O)(c4cc(ccc4C)C)[O-]
# The Scaffold is 	O=[SH-](Cc1nc2ccccc2nc1N1CCCC1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)c(=O)c(c(s2)NC(=O)c3ccc(cc3)[N+](=O)[O-])c4cccs4
# The Scaffold is 	O=C(Nc1sc2ccccc2c(=O)c1-c1cccs1)c1ccccc1
#
# Original SMILES is 	C(#N)c1c(c2c(nc1N)CCN(C2)C)c3ccc(c(c3OC)OC)OC
# The Scaffold is 	c1ccc(-c2ccnc3c2CNCC3)cc1
#
# Original SMILES is 	c1cc2c(c3c1cc(c(=O)o3)c4ccc(c(c4)OC)OC)CN(CO2)CC5CCCO5
# The Scaffold is 	O=c1oc2c3c(ccc2cc1-c1ccccc1)OCN(CC1CCCO1)C3
#
# Original SMILES is 	c1ccc2c(c1)C(=O)N(C2=O)CC(=O)Nc3c(c4c(s3)CN(CC4)C(C)C)C(=O)N
# The Scaffold is 	O=C(CN1C(=O)c2ccccc2C1=O)Nc1cc2c(s1)CNCC2
#
# Original SMILES is 	c1ccc(cc1)CN2Cc3c(c(c(s3)NC(=O)COc4ccc(cc4Cl)Cl)c5nc6ccccc6s5)CC2
# The Scaffold is 	O=C(COc1ccccc1)Nc1sc2c(c1-c1nc3ccccc3s1)CCN(Cc1ccccc1)C2
#
# Original SMILES is 	c1ccc2c(c1)ccc3c2cc(c(=O)o3)C(=O)Nc4nnc(o4)c5ccncc5
# The Scaffold is 	O=C(Nc1nnc(-c2ccncc2)o1)c1cc2c(ccc3ccccc32)oc1=O
#
# Original SMILES is 	c1cc(c(cc1C=NN=C2NC(=O)CS2)OC)OC
# The Scaffold is 	O=C1CSC(=NN=Cc2ccccc2)N1
#
# Original SMILES is 	c1ccc2c(c1)nc(o2)Sc3c4c5c(sc4nc(n3)C)CCCC5
# The Scaffold is 	c1ccc2oc(Sc3ncnc4sc5c(c34)CCCC5)nc2c1
#
# Original SMILES is 	c1ccc2c[n+](ccc2c1)CC(=O)N
# The Scaffold is 	c1ccc2c[nH+]ccc2c1
#
# Original SMILES is 	c1cc(oc1)CN[S-](=O)(c2ccc(c(c2)C(=O)O)OC)[O-]
# The Scaffold is 	O=[SH-](NCc1ccco1)c1ccccc1
#
# Original SMILES is 	c1ccc2c(c1)ccc(c2C=Nc3ccc(cc3OC)OC)O
# The Scaffold is 	C(=Nc1ccccc1)c1cccc2ccccc12
#
# Original SMILES is 	c1ccc2c(c1)c3c(c(c(o3)C)C(=O)C)c4c2OCN(C4)CCO
# The Scaffold is 	c1ccc2c(c1)c1c(c3ccoc32)CNCO1
#
# 47 total smiles
# 45 different scaffolds
