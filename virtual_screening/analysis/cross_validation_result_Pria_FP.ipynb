# %%
from analysis import *
from docking_analysis import *
from IPython.display import Markdown

file_paths = {0: 'single_classification_22/45710870/',
              1: 'single_classification_42/45710871/', 
              2: 'single_regression_2/45710874/',
              3: 'single_regression_11/45710875/',
              4: 'vanilla_lstm_8/46547695/',
              5: 'vanilla_lstm_19/46547696/',
              6: 'multi_classification_15/eval_keck/',
              7: 'multi_classification_18/eval_keck/'}

number = 20

evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01'}

paths = ['../../output/cross_validation_Keck_FP/{}'.format(p) for p in file_paths.values()]
model_list = ['single_classification_22',
              'single_classification_42',
              'single_regression_2',
              'single_regression_11',
              'vanilla_lstm_8',
              'vanilla_lstm_19',
              'multi_classification_15',
              'multi_classification_18']

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
for k in range(len(file_paths)):
    print 'Check ', file_paths[k]
    check_result_completeness(dir_='../../output/cross_validation_Keck_FP/', file_path=file_paths[k], number=number)
    print
# Out:
# Check  single_classification_22/45710870/
# All output result complete.
#
# Check  single_classification_42/45710871/
# All output result complete.
#
# Check  single_regression_2/45710874/
# All output result complete.
#
# Check  single_regression_11/45710875/
# All output result complete.
#
# Check  vanilla_lstm_8/46547695/
# All output result complete.
#
# Check  vanilla_lstm_19/46547696/
# All output result complete.
#
# Check  multi_classification_15/eval_keck/
# All output result complete.
#
# Check  multi_classification_18/eval_keck/
# All output result complete.

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                      model_list=model_list,
                      title='AUC[PR]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[PR]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.945 | 0.045 | 0.002 |
# | single_classification_42 | 0.937 | 0.039 | 0.002 |
# | single_regression_2 | 0.012 | 0.011 | 0.011 |
# | single_regression_11 | 0.032 | 0.006 | 0.005 |
# | vanilla_lstm_8 | 0.000 | 0.001 | 0.001 |
# | vanilla_lstm_19 | 0.000 | 0.001 | 0.001 |
# | multi_classification_15 | 0.001 | 0.003 | 0.001 |
# | multi_classification_18 | 0.549 | 0.016 | 0.004 |
#
# ## Model comparison
# ### median of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.973 | 0.011 | 0.000 |
# | single_classification_42 | 1.000 | 0.008 | 0.000 |
# | single_regression_2 | 0.012 | 0.003 | 0.003 |
# | single_regression_11 | 0.032 | 0.004 | 0.004 |
# | vanilla_lstm_8 | 0.000 | 0.001 | 0.000 |
# | vanilla_lstm_19 | 0.000 | 0.001 | 0.000 |
# | multi_classification_15 | 0.001 | 0.001 | 0.000 |
# | multi_classification_18 | 0.988 | 0.003 | 0.001 |
#
# ## Model comparison
# ### std of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.074 | 0.054 | 0.002 |
# | single_classification_42 | 0.227 | 0.067 | 0.003 |
# | single_regression_2 | 0.004 | 0.018 | 0.019 |
# | single_regression_11 | 0.008 | 0.008 | 0.004 |
# | vanilla_lstm_8 | 0.000 | 0.001 | 0.001 |
# | vanilla_lstm_19 | 0.000 | 0.000 | 0.001 |
# | multi_classification_15 | 0.003 | 0.004 | 0.001 |
# | multi_classification_18 | 0.509 | 0.038 | 0.014 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                      model_list=model_list,
                      title='AUC[ROC]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.984 | 0.614 | 0.548 |
# | single_classification_42 | 0.977 | 0.610 | 0.539 |
# | single_regression_2 | 0.891 | 0.816 | 0.817 |
# | single_regression_11 | 0.994 | 0.812 | 0.813 |
# | vanilla_lstm_8 | 0.519 | 0.679 | 0.569 |
# | vanilla_lstm_19 | 0.519 | 0.653 | 0.519 |
# | multi_classification_15 | 0.620 | 0.632 | 0.535 |
# | multi_classification_18 | 0.828 | 0.670 | 0.662 |
#
# ## Model comparison
# ### median of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification_22 | 1.000 | 0.618 | 0.559 |
# | single_classification_42 | 1.000 | 0.629 | 0.547 |
# | single_regression_2 | 0.891 | 0.830 | 0.820 |
# | single_regression_11 | 0.994 | 0.804 | 0.826 |
# | vanilla_lstm_8 | 0.511 | 0.676 | 0.568 |
# | vanilla_lstm_19 | 0.517 | 0.637 | 0.505 |
# | multi_classification_15 | 0.590 | 0.608 | 0.538 |
# | multi_classification_18 | 1.000 | 0.682 | 0.624 |
#
# ## Model comparison
# ### std of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.029 | 0.054 | 0.081 |
# | single_classification_42 | 0.104 | 0.117 | 0.134 |
# | single_regression_2 | 0.033 | 0.058 | 0.056 |
# | single_regression_11 | 0.001 | 0.079 | 0.081 |
# | vanilla_lstm_8 | 0.069 | 0.087 | 0.117 |
# | vanilla_lstm_19 | 0.087 | 0.078 | 0.105 |
# | multi_classification_15 | 0.120 | 0.135 | 0.140 |
# | multi_classification_18 | 0.207 | 0.144 | 0.148 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                      model_list=model_list,
                      title='AUC[BED ROC]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[BED ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.971 | 0.330 | 0.176 |
# | single_classification_42 | 0.955 | 0.318 | 0.163 |
# | single_regression_2 | 0.608 | 0.447 | 0.449 |
# | single_regression_11 | 0.945 | 0.476 | 0.473 |
# | vanilla_lstm_8 | 0.115 | 0.207 | 0.137 |
# | vanilla_lstm_19 | 0.106 | 0.181 | 0.128 |
# | multi_classification_15 | 0.207 | 0.280 | 0.120 |
# | multi_classification_18 | 0.635 | 0.326 | 0.272 |
#
# ## Model comparison
# ### median of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.998 | 0.332 | 0.164 |
# | single_classification_42 | 0.998 | 0.332 | 0.144 |
# | single_regression_2 | 0.601 | 0.467 | 0.462 |
# | single_regression_11 | 0.944 | 0.463 | 0.428 |
# | vanilla_lstm_8 | 0.114 | 0.202 | 0.130 |
# | vanilla_lstm_19 | 0.099 | 0.146 | 0.101 |
# | multi_classification_15 | 0.183 | 0.238 | 0.068 |
# | multi_classification_18 | 0.998 | 0.339 | 0.246 |
#
# ## Model comparison
# ### std of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.053 | 0.090 | 0.132 |
# | single_classification_42 | 0.195 | 0.105 | 0.107 |
# | single_regression_2 | 0.052 | 0.068 | 0.071 |
# | single_regression_11 | 0.006 | 0.089 | 0.091 |
# | vanilla_lstm_8 | 0.058 | 0.117 | 0.071 |
# | vanilla_lstm_19 | 0.054 | 0.094 | 0.101 |
# | multi_classification_15 | 0.157 | 0.126 | 0.129 |
# | multi_classification_18 | 0.415 | 0.093 | 0.161 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                      model_list=model_list,
                      title='Enrichment Factor on Test Set')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='Enrichment Factor (Test-set)')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification_22 | 4.667 | 8.333 | 6.667 | 0.000 |
# | single_classification_42 | 2.333 | 2.667 | 17.778 | 18.333 |
# | single_regression_2 | 14.083 | 20.917 | 26.667 | 40.000 |
# | single_regression_11 | 14.417 | 24.750 | 0.000 | 0.000 |
# | vanilla_lstm_8 | 2.176 | 2.963 | 0.000 | 0.000 |
# | vanilla_lstm_19 | 1.000 | 2.000 | 0.000 | 0.000 |
# | multi_classification_15 | 1.042 | 0.833 | 0.000 | 0.000 |
# | multi_classification_18 | 5.458 | 4.500 | 6.667 | 10.000 |
#
# ## Model comparison
# ### median of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification_22 | 0.000 | 0.000 | 0.000 | 0.000 |
# | single_classification_42 | 0.000 | 0.000 | 0.000 | 0.000 |
# | single_regression_2 | 12.500 | 20.000 | 0.000 | 0.000 |
# | single_regression_11 | 12.500 | 25.000 | 0.000 | 0.000 |
# | vanilla_lstm_8 | 0.000 | 0.000 | 0.000 | 0.000 |
# | vanilla_lstm_19 | 0.000 | 0.000 | 0.000 | 0.000 |
# | multi_classification_15 | 0.000 | 0.000 | 0.000 | 0.000 |
# | multi_classification_18 | 0.000 | 0.000 | 0.000 | 0.000 |
#
# ## Model comparison
# ### std of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification_22 | 6.412 | 12.727 | 29.814 | 0.000 |
# | single_classification_42 | 5.282 | 6.543 | 43.618 | 56.687 |
# | single_regression_2 | 5.990 | 14.990 | 54.719 | 82.078 |
# | single_regression_11 | 9.169 | 16.713 | 0.000 | 0.000 |
# | vanilla_lstm_8 | 4.270 | 6.849 | 0.000 | 0.000 |
# | vanilla_lstm_19 | 4.472 | 8.944 | 0.000 | 0.000 |
# | multi_classification_15 | 3.277 | 3.727 | 0.000 | 0.000 |
# | multi_classification_18 | 7.022 | 9.305 | 29.814 | 44.721 |

# %% [markdown]
# # Docking Results

# %%
content = get_auc_table(file_path='../../output/docking_result/lc123-pria-dockdata-qnorm.csv.gz',
                        target_name='Keck_Pria_FP_data',
                        auc_list=['precision_auc_single', 'roc_auc_single', 'bedroc_auc_single'],
                        auc_header=['AUC[PR]', 'AUC[ROC]', 'AUC[BED ROC]'],
                        title='AUC for Docking Methods')
Markdown(content)
# Out:
# ## AUC for Docking Methods
# | docking method | AUC[PR] | AUC[ROC] | AUC[BED ROC] |
# | --- | --- | --- | --- |
# | dockscore_ad4 | 0.000378 | 0.561110 | 0.078540 |
# | dockscore_dock6 | 0.000433 | 0.522190 | 0.139809 |
# | dockscore_fred | 0.000382 | 0.533364 | 0.091214 |
# | dockscore_hybrid | 0.000523 | 0.559783 | 0.181253 |
# | dockscore_plants | 0.000401 | 0.558695 | 0.100401 |
# | dockscore_rdockint | 0.000400 | 0.567930 | 0.085613 |
# | dockscore_rdocktot | 0.000368 | 0.531869 | 0.093266 |
# | dockscore_smina | 0.000368 | 0.508839 | 0.102915 |
# | dockscore_surflex | 0.000405 | 0.504622 | 0.130612 |
# | consensus_dockscore_mean | 0.000419 | 0.573213 | 0.102945 |
# | consensus_dockscore_STD | 0.000335 | 0.474377 | 0.091024 |
# | consensus_dockscore_median | 0.000454 | 0.589241 | 0.130702 |
# | consensus_dockscore_max | 0.000401 | 0.569533 | 0.091254 |
# | consensus_dockscore_min | 0.000385 | 0.541761 | 0.097389 |

# %%
EF_ratio_list = [0.02, 0.01, 0.0015, 0.001]
content = get_ef_table(file_path='../../output/docking_result/lc123-pria-dockdata-qnorm.csv.gz',
                       target_name='Keck_Pria_FP_data',
                       efr_list=EF_ratio_list,
                       ef_header=['EF_2', 'EF_1', 'EF_015', 'EF_01'],
                       title='Enrichment Factor for Docking Methods')
Markdown(content)
# Out:
# ## Enrichment Factor for Docking Methods
# | docking method | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | dockscore_ad4 | 0.0 | 0.0 | 0.0 | 0.0 |
# | dockscore_dock6 | 2.17391304348 | 4.34782608696 | 0.0 | 0.0 |
# | dockscore_fred | 0.0 | 0.0 | 0.0 | 0.0 |
# | dockscore_hybrid | 0.0 | 0.0 | 0.0 | 0.0 |
# | dockscore_plants | 0.0 | 0.0 | 0.0 | 0.0 |
# | dockscore_rdockint | 2.08333333333 | 0.0 | 0.0 | 0.0 |
# | dockscore_rdocktot | 0.0 | 0.0 | 0.0 | 0.0 |
# | dockscore_smina | 2.08333333333 | 0.0 | 0.0 | 0.0 |
# | dockscore_surflex | 2.08333333333 | 0.0 | 0.0 | 0.0 |
# | consensus_dockscore_mean | 0.0 | 0.0 | 0.0 | 0.0 |
# | consensus_dockscore_STD | 0.0 | 0.0 | 0.0 | 0.0 |
# | consensus_dockscore_median | 0.0 | 0.0 | 0.0 | 0.0 |
# | consensus_dockscore_max | 0.0 | 0.0 | 0.0 | 0.0 |
# | consensus_dockscore_min | 0.0 | 0.0 | 0.0 | 0.0 |

# %% [markdown]
# # Plot EF curve

# %%
from EF_curve_support import *

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 30.0)
# Out:
# Using Theano backend.
# Using gpu device 1: Tesla K40m (CNMeM is disabled, CuDNN 4004)

# %%
json_file_list = ['single_classification_22.json',
                  'single_classification_42.json',
                  'single_regression_2.json',
                  'single_regression_11.json',
                  'multi_classification_15.json',
                  'multi_classification_18.json']

json_paths = ['../../output/cross_validation_Keck_FP/{}'.format(p) for p in json_file_list]
print json_paths

weights_dir_paths = ['../../output/cross_validation_Keck_FP/single_classification_22/45710870/',
                     '../../output/cross_validation_Keck_FP/single_classification_42/45710871/',
                     '../../output/cross_validation_Keck_FP/single_regression_2/45710874/',
                     '../../output/cross_validation_Keck_FP/single_regression_11/45710875/',
                     '../../output/cross_validation_Keck_FP/multi_classification_15/46007208/',
                     '../../output/cross_validation_Keck_FP/multi_classification_18/46029086/']

model_names_list = ['single_classification_22',
                    'single_classification_42',
                    'single_regression_2',
                    'single_regression_11',
                    'multi_classification_15',
                    'multi_classification_18']
# Out:
# ['../../output/cross_validation_Keck_FP/single_classification_22.json', '../../output/cross_validation_Keck_FP/single_classification_42.json', '../../output/cross_validation_Keck_FP/single_regression_2.json', '../../output/cross_validation_Keck_FP/single_regression_11.json', '../../output/cross_validation_Keck_FP/multi_classification_15.json', '../../output/cross_validation_Keck_FP/multi_classification_18.json']

# %%
EF_ratio_list = np.linspace(0.001, 0.15, 100)
N = len(json_file_list)
data_set_name = 'Keck_Pria_FP_data'

data_pd_list = []
for i in range(N):
    temp_pd = get_EF_curve_in_pd(EF_ratio_list=EF_ratio_list,
                                 data_set_name=data_set_name,
                                 config_json_file=json_paths[i],
                                 weight_dir=weights_dir_paths[i],
                                 model_name=model_names_list[i],
                                 regenerate=False)
    data_pd_list.append(temp_pd)
    
whole_pd = data_pd_list[0]
for i in range(1, N):
    whole_pd = whole_pd.append(data_pd_list[i])

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 15.0)

# Calculate Normalized EF, and add it to dataframe
whole_pd['Normalized EF'] = whole_pd.apply(lambda row: row['EF'] / row['EF max'], axis=1)
sns.tsplot(data=whole_pd, time="EFR", unit="running process", condition="model", value="Normalized EF")
plt.savefig('plottings/NEF_curve.png')

# %%
focused_pd = whole_pd[whole_pd['EFR']<=0.06]
sns.tsplot(data=focused_pd, time="EFR", unit="running process", condition="model", value="Normalized EF")
