# %%
from virtual_screening.analysis.analysis import *

file_paths = {0: 'single_classification/45472002/', #0: 'single_classification/45472002/',
              1: 'single_regression/45472003/', 
              2: 'vanilla_lstm/45476819/',
              3: 'multi_classification/45472055/'}

number = {0: 48, 1: 24, 2: 30, 3: 24}

evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01'}

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (25.0, 5.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Single-task Classification

# %%
k = 0

# %%
check_result_completeness(dir_='../../output/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1']

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [5, 9, 25, 11, 1]
#
# Analyze val roc:
# Top 5 rankings:  [36, 23, 17, 21, 37]
#
# Analyze val bedroc:
# Top 5 rankings:  [5, 17, 9, 23, 0]

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [5, 9, 23, 11, 29]
#
# Analyze test roc:
# Top 5 rankings:  [0, 23, 39, 13, 17]
#
# Analyze test bedroc:
# Top 5 rankings:  [0, 6, 5, 17, 4]
#
# Analyze EF_2:
# Top 5 rankings:  [4, 0, 5, 6, 29]
#
# Analyze EF_1:
# Top 5 rankings:  [0, 4, 9, 1, 2]

# %% [markdown]
# # Single-task Regression

# %%
k = 0

# %%
check_result_completeness(dir_='../../output/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1']

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [5, 9, 25, 11, 1]
#
# Analyze val roc:
# Top 5 rankings:  [36, 23, 17, 21, 37]
#
# Analyze val bedroc:
# Top 5 rankings:  [5, 17, 9, 23, 0]

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [5, 9, 23, 11, 29]
#
# Analyze test roc:
# Top 5 rankings:  [0, 23, 39, 13, 17]
#
# Analyze test bedroc:
# Top 5 rankings:  [0, 6, 5, 17, 4]
#
# Analyze EF_2:
# Top 5 rankings:  [4, 0, 5, 6, 29]
#
# Analyze EF_1:
# Top 5 rankings:  [0, 4, 9, 1, 2]

# %% [markdown]
# # Vanilla LSTM

# %%
k = 0

# %%
check_result_completeness(dir_='../../output/', file_path=file_paths[k], number=number[k])
# Out:
# All output result complete.

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[9], evaluations[10]],
                                    title='EF')
# Out:
# ['EF_2', 'EF_1']

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [5, 9, 25, 11, 1]
#
# Analyze val roc:
# Top 5 rankings:  [36, 23, 17, 21, 37]
#
# Analyze val bedroc:
# Top 5 rankings:  [5, 17, 9, 23, 0]

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8], evaluations[9], evaluations[10]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [5, 9, 23, 11, 29]
#
# Analyze test roc:
# Top 5 rankings:  [0, 23, 39, 13, 17]
#
# Analyze test bedroc:
# Top 5 rankings:  [0, 6, 5, 17, 4]
#
# Analyze EF_2:
# Top 5 rankings:  [4, 0, 5, 6, 29]
#
# Analyze EF_1:
# Top 5 rankings:  [0, 4, 9, 1, 2]

# %% [markdown]
# # Multi-task Classification

# %%
k = 3

# %%
check_result_completeness(dir_='../../output/', file_path=file_paths[k], number=number[k])
# Out:
# Missing hyperparameter set result: 11

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                    title='AUC[PR]')
# Out:
# ['train prec', 'val prec', 'test prec']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                    title='AUC[BED ROC]')
# Out:
# ['train bedroc', 'val bedroc', 'test bedroc']

# %%
plot_single_model_multi_evaluations('../../output/{}'.format(file_paths[k]),
                                    number[k],
                                    evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                    title='AUC[ROC]')
# Out:
# ['train roc', 'val roc', 'test roc']

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[3], evaluations[4], evaluations[5]],
                    fetch_top_num=5)
# Out:
# Analyze val prec:
# Top 5 rankings:  [11, 0, 1, 21, 13]
#
# Analyze val roc:
# Top 5 rankings:  [11, 23, 4, 21, 19]
#
# Analyze val bedroc:
# Top 5 rankings:  [11, 13, 23, 21, 19]

# %%
get_ranked_analysis('../../output/{}'.format(file_paths[k]),
                    number[k], 
                    evaluation_list=[evaluations[6], evaluations[7], evaluations[8]],
                    fetch_top_num=5)
# Out:
# Analyze test prec:
# Top 5 rankings:  [11, 0, 1, 4, 23]
#
# Analyze test roc:
# Top 5 rankings:  [11, 4, 23, 18, 16]
#
# Analyze test bedroc:
# Top 5 rankings:  [11, 4, 23, 13, 18]

# %% [markdown]
# # Appendix
#
# All the corresponding hyperparamter sets are displayed [here](https://github.com/chao1224/virtual-screening/blob/6ff69e2f64f954c88d34c6a90a0569e5d50e7c8a/virtual_screening/analysis/Hyperparameter_Set_Display.ipynb).
