# %%
from NN_Tree_Comparison import *

# %load_ext autoreload
# %autoreload 2
from virtual_screening.function import *
from virtual_screening.evaluation import *
from virtual_screening.models.deep_classification import *
# Out:
# Using Theano backend.
# Using gpu device 1: Tesla K40m (CNMeM is disabled, CuDNN 4004)

# %%
running_index = 1
k = 5
pos_num = 50
neg_num = 200

# %% [markdown]
# # Get Input Feature

# %%
directory = '../../dataset/fixed_dataset/fold_{}/'.format(k)
file_list = []
for i in range(k):
    file_list.append('{}file_{}.csv'.format(directory, i))
file_list = np.array(file_list)

# read data
test_index = running_index / 4
val_index = running_index % 4 + (running_index % 4 >= test_index)
complete_index = np.arange(k)
train_index = np.where((complete_index != test_index) & (complete_index != val_index))[0]

train_file_list = file_list[train_index]
val_file_list = file_list[val_index:val_index+1]
test_file_list = file_list[test_index:test_index+1]

# %%
label_name_list = ['Keck_Pria_AS_Retest']

train_pd = filter_out_missing_values(read_merged_data(train_file_list), label_list=label_name_list)
val_pd = filter_out_missing_values(read_merged_data(val_file_list), label_list=label_name_list)
test_pd = filter_out_missing_values(read_merged_data(test_file_list), label_list=label_name_list)

# extract data, and split training data into training and val
X_train, y_train = extract_feature_and_label(train_pd,
                                             feature_name='Fingerprints',
                                             label_name_list=label_name_list)
X_val, y_val = extract_feature_and_label(val_pd,
                                         feature_name='Fingerprints',
                                         label_name_list=label_name_list)
X_test, y_test = extract_feature_and_label(test_pd,
                                           feature_name='Fingerprints',
                                           label_name_list=label_name_list)
# Out:
# (43453, 1)
# (14484, 1)
# (14486, 1)

# %% [markdown]
# # Test Single-task

# %%
with open('../../output/cross_validation/single_classification_22.json', 'r') as f:
    conf = json.load(f)
single_task = SingleClassification(conf=conf)

# %%
PMTNN_weight_file = '../../output/cross_validation/single_classification_22/45540945/{}.weight'.format(running_index)
print PMTNN_weight_file
single_task.predict_with_existing(X_train, y_train, X_val, y_val, X_test, y_test,
                           PMTNN_weight_file=PMTNN_weight_file)
# Out:
# ../../output/cross_validation/single_classification_22/45540945/1.weight
#
# train precision: 0.998314670017
# train roc: 0.999998039294
# train bedroc: 0.994706144082
#
# validation precision: 0.307938220156
# validation roc: 0.783930484518
# validation bedroc: 0.612508723339
#
# test precision: 0.0959068095274
# test roc: 0.837264599171
# test bedroc: 0.628970145806
#
# ratio: 0.02, EF: 25.0,	active: 16.0
# ratio: 0.01, EF: 43.75,	active: 16.0
# ratio: 0.0015, EF: 208.333333333,	active: 16.0
# ratio: 0.001, EF: 312.5,	active: 16.0

# %%
single_model = single_task.setup_model()
single_model.load_weights(PMTNN_weight_file)

# %% [markdown]
# ## Show val and test rank on single NN

# %%
y_pred_on_val_single_NN = single_model.predict(X_val)
y_pred_on_test_single_NN = single_model.predict(X_test)

# %%
print 'For validation'
get_rank(y_val, y_pred_on_val_single_NN)
print
print 'For test'
get_rank(y_test, y_pred_on_test_single_NN)
# Out:
# For validation
# 0.999667	     1/ 14484		Rank: 0.000069
# 0.000004	 13523/ 14484		Rank: 0.933651
# 0.007614	    26/ 14484		Rank: 0.001795
# 0.000007	 11032/ 14484		Rank: 0.761668
# 0.003222	    34/ 14484		Rank: 0.002347
# 0.012485	    23/ 14484		Rank: 0.001588
# 0.992665	     4/ 14484		Rank: 0.000276
# 0.000008	 10578/ 14484		Rank: 0.730323
# 0.997849	     3/ 14484		Rank: 0.000207
# 0.000013	  5067/ 14484		Rank: 0.349834
# 0.000012	  6246/ 14484		Rank: 0.431234
# 0.000013	  5766/ 14484		Rank: 0.398094
# 0.164386	     9/ 14484		Rank: 0.000621
# 0.149422	    10/ 14484		Rank: 0.000690
# 0.000069	   306/ 14484		Rank: 0.021127
# 0.809995	     6/ 14484		Rank: 0.000414
#
# For test
# 0.000033	   769/ 14486		Rank: 0.053086
# 0.000002	 14220/ 14486		Rank: 0.981637
# 0.000029	   999/ 14486		Rank: 0.068963
# 0.160746	     9/ 14486		Rank: 0.000621
# 0.000026	  1262/ 14486		Rank: 0.087119
# 0.708671	     6/ 14486		Rank: 0.000414
# 0.000322	    94/ 14486		Rank: 0.006489
# 0.000028	  1089/ 14486		Rank: 0.075176
# 0.000078	   254/ 14486		Rank: 0.017534
# 0.000026	  1308/ 14486		Rank: 0.090294
# 0.000009	  8551/ 14486		Rank: 0.590294
# 0.000008	  9950/ 14486		Rank: 0.686870
# 0.920472	     5/ 14486		Rank: 0.000345
# 0.069630	    11/ 14486		Rank: 0.000759
# 0.000193	   117/ 14486		Rank: 0.008077
# 0.040926	    14/ 14486		Rank: 0.000966

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from xgboost import DMatrix

# %%
def custom(y_true, y_pred):
    return 'ROC[AUC]', roc_auc_single

# %%
# dtrain = DMatrix(data=X_train, label=y_train)
# dval = DMatrix(data=X_val, label=y_val)
# dtest = DMatrix(data=X_test, label=y_test)
# params = {'max_depth':10, 'objective':'binary:logistic'}
# evallist = [dtest, dtrain]
# bst = xgb.train(params=params, dtrain=dtrain, num_boost_round=10,
#                 evals=evallist,
#                 feval='auc', maximize=True, verbose_eval=True)

# %%
clf = xgb.XGBClassifier(max_depth=10, n_estimators=100, silent=True, objective='binary:logistic')
clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric='auc', verbose=False)
# Out:
# /usr/local/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=10,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
predict_with_existing(clf, X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# train precision: 0.930939315435
# train roc: 0.999898288402
# train bedroc: 0.993722514348
#
# validation precision: 0.289237329326
# validation roc: 0.89217151645
# validation bedroc: 0.7628689951
#
# test precision: 0.149050688356
# test roc: 0.880422857636
# test bedroc: 0.78269282675
#
# ratio: 0.02, EF: 37.5,	active: 16.0
# ratio: 0.01, EF: 68.75,	active: 16.0
# ratio: 0.0015, EF: 208.333333333,	active: 16.0
# ratio: 0.001, EF: 250.0,	active: 16.0

# %%
y_pred_on_train_xgboost = reshape_data_into_2_dim(clf.predict_proba(X_train)[:, 1])
y_pred_on_val_xgboost = reshape_data_into_2_dim(clf.predict_proba(X_val)[:, 1])
y_pred_on_test_xgboost = reshape_data_into_2_dim(clf.predict_proba(X_test)[:, 1])

# %% [markdown]
# ## Show val and test rank on XGBoost

# %%
print 'For validation'
get_rank(y_val, y_pred_on_val_xgboost)
print
print 'For test'
get_rank(y_test, y_pred_on_test_xgboost)
# Out:
# For validation
# 0.255025	     8/ 14484		Rank: 0.000552
# 0.006654	    98/ 14484		Rank: 0.006766
# 0.000973	   902/ 14484		Rank: 0.062276
# 0.004228	   138/ 14484		Rank: 0.009528
# 0.128536	    13/ 14484		Rank: 0.000898
# 0.034595	    29/ 14484		Rank: 0.002002
# 0.482657	     2/ 14484		Rank: 0.000138
# 0.001720	   450/ 14484		Rank: 0.031069
# 0.302829	     7/ 14484		Rank: 0.000483
# 0.000115	  9162/ 14484		Rank: 0.632560
# 0.000396	  2706/ 14484		Rank: 0.186827
# 0.000083	 11536/ 14484		Rank: 0.796465
# 0.303580	     6/ 14484		Rank: 0.000414
# 0.397426	     4/ 14484		Rank: 0.000276
# 0.032834	    31/ 14484		Rank: 0.002140
# 0.315210	     5/ 14484		Rank: 0.000345
#
# For test
# 0.011174	    58/ 14486		Rank: 0.004004
# 0.000630	  1526/ 14486		Rank: 0.105343
# 0.004896	   131/ 14486		Rank: 0.009043
# 0.604062	     2/ 14486		Rank: 0.000138
# 0.001474	   522/ 14486		Rank: 0.036035
# 0.188084	    11/ 14486		Rank: 0.000759
# 0.018850	    44/ 14486		Rank: 0.003037
# 0.002573	   264/ 14486		Rank: 0.018224
# 0.004952	   128/ 14486		Rank: 0.008836
# 0.005711	   115/ 14486		Rank: 0.007939
# 0.000092	 10853/ 14486		Rank: 0.749206
# 0.000053	 14108/ 14486		Rank: 0.973906
# 0.393397	     5/ 14486		Rank: 0.000345
# 0.035639	    28/ 14486		Rank: 0.001933
# 0.059066	    19/ 14486		Rank: 0.001312
# 0.298602	     7/ 14486		Rank: 0.000483

# %% [markdown]
# ## Compare Rank

# %% [markdown]
# ### Compare Rank on Val

# %%
compare_rank(y_val, y_pred_on_val_single_NN, y_pred_on_val_xgboost)
# Out:
# 14423 	0.999667	     1		Rank: 0.000069	|	0.255025	     8		Rank: 0.000552
# 14424 	0.000004	 13523		Rank: 0.933651	|	0.006654	    98		Rank: 0.006766
# 14425 	0.007614	    26		Rank: 0.001795	|	0.000973	   902		Rank: 0.062276
# 14426 	0.000007	 11032		Rank: 0.761668	|	0.004228	   138		Rank: 0.009528
# 14427 	0.003222	    34		Rank: 0.002347	|	0.128536	    13		Rank: 0.000898
# 14428 	0.012485	    23		Rank: 0.001588	|	0.034595	    29		Rank: 0.002002
# 14429 	0.992665	     4		Rank: 0.000276	|	0.482657	     2		Rank: 0.000138
# 14430 	0.000008	 10578		Rank: 0.730323	|	0.001720	   450		Rank: 0.031069
# 14431 	0.997849	     3		Rank: 0.000207	|	0.302829	     7		Rank: 0.000483
# 14432 	0.000013	  5067		Rank: 0.349834	|	0.000115	  9162		Rank: 0.632560
# 14433 	0.000012	  6246		Rank: 0.431234	|	0.000396	  2706		Rank: 0.186827
# 14434 	0.000013	  5766		Rank: 0.398094	|	0.000083	 11536		Rank: 0.796465
# 14435 	0.164386	     9		Rank: 0.000621	|	0.303580	     6		Rank: 0.000414
# 14436 	0.149422	    10		Rank: 0.000690	|	0.397426	     4		Rank: 0.000276
# 14437 	0.000069	   306		Rank: 0.021127	|	0.032834	    31		Rank: 0.002140
# 14438 	0.809995	     6		Rank: 0.000414	|	0.315210	     5		Rank: 0.000345

# %%
test_list = [14424, 14426, 14437]

for test_id in test_list:
    test_molecule = X_val[test_id]
    print 'testing: ', test_id
    for i in range(len(X_train)):
        x_val = X_train[i]
        sim = similarity(test_molecule, x_val)
        if sim / sum(test_molecule) >= 0.6:
            print i, '\t', sim, '\t true label', y_train[i, 0]
    print
# Out:
# testing:  14424
# 923 	32.0 	 true label 0.0
# 3197 	32.0 	 true label 0.0
# 3200 	34.0 	 true label 0.0
# 3201 	38.0 	 true label 0.0
# 3202 	32.0 	 true label 0.0
# 3217 	35.0 	 true label 0.0
# 3223 	34.0 	 true label 0.0
# 3225 	34.0 	 true label 0.0
# 3226 	38.0 	 true label 0.0
# 3236 	34.0 	 true label 0.0
# 3237 	34.0 	 true label 0.0
# 3246 	37.0 	 true label 0.0
# 3255 	37.0 	 true label 0.0
# 3257 	34.0 	 true label 0.0
# 3262 	34.0 	 true label 0.0
# 3263 	35.0 	 true label 0.0
# 3718 	33.0 	 true label 0.0
# 6299 	40.0 	 true label 0.0
# 7492 	34.0 	 true label 0.0
# 11511 	36.0 	 true label 0.0
# 17679 	32.0 	 true label 0.0
# 17704 	34.0 	 true label 0.0
# 17705 	35.0 	 true label 0.0
# 17711 	35.0 	 true label 0.0
# 17720 	33.0 	 true label 0.0
# 17722 	34.0 	 true label 0.0
# 17725 	34.0 	 true label 0.0
# 17726 	34.0 	 true label 0.0
# 17732 	33.0 	 true label 0.0
# 17741 	35.0 	 true label 0.0
# 17750 	34.0 	 true label 0.0
# 17753 	37.0 	 true label 0.0
# 17757 	34.0 	 true label 0.0
# 17759 	37.0 	 true label 0.0
# 18263 	36.0 	 true label 0.0
# 22955 	44.0 	 true label 0.0
# 28909 	34.0 	 true label 1.0
# 32135 	33.0 	 true label 0.0
# 32141 	37.0 	 true label 0.0
# 32150 	37.0 	 true label 0.0
# 32157 	35.0 	 true label 0.0
# 32158 	34.0 	 true label 0.0
# 32164 	37.0 	 true label 0.0
# 32170 	36.0 	 true label 0.0
# 32188 	36.0 	 true label 0.0
# 32189 	38.0 	 true label 0.0
# 32191 	37.0 	 true label 0.0
# 35424 	38.0 	 true label 0.0
# 35534 	40.0 	 true label 0.0
# 40475 	42.0 	 true label 0.0
# 40567 	33.0 	 true label 0.0
#
# testing:  14426
# 7727 	34.0 	 true label 0.0
# 8245 	40.0 	 true label 0.0
# 8265 	33.0 	 true label 0.0
# 20089 	45.0 	 true label 0.0
# 22574 	34.0 	 true label 0.0
#
# testing:  14437
# 4050 	28.0 	 true label 0.0
# 4073 	27.0 	 true label 0.0
# 11458 	28.0 	 true label 0.0
# 12327 	27.0 	 true label 0.0
# 13487 	27.0 	 true label 0.0
# 13488 	27.0 	 true label 0.0
# 13489 	30.0 	 true label 0.0
# 13490 	28.0 	 true label 0.0
# 14177 	31.0 	 true label 0.0
# 14201 	28.0 	 true label 0.0
# 18564 	27.0 	 true label 0.0
# 19085 	30.0 	 true label 0.0
# 27966 	30.0 	 true label 0.0
# 27967 	34.0 	 true label 0.0
# 28679 	31.0 	 true label 0.0
# 28680 	29.0 	 true label 0.0
# 32496 	28.0 	 true label 0.0
# 32710 	27.0 	 true label 0.0
# 33907 	30.0 	 true label 0.0
# 40724 	28.0 	 true label 0.0
# 41448 	30.0 	 true label 0.0
# 41650 	28.0 	 true label 0.0
# 42377 	33.0 	 true label 0.0
# 42394 	28.0 	 true label 0.0
# 43147 	28.0 	 true label 0.0
# 43158 	28.0 	 true label 0.0
# 43404 	27.0 	 true label 1.0
# 43405 	27.0 	 true label 1.0

# %% [markdown]
# ### Compare Rank on Test

# %%
compare_rank(y_test, y_pred_on_test_single_NN, y_pred_on_test_xgboost)
# Out:
# 14424 	0.000033	   769		Rank: 0.053086	|	0.011174	    58		Rank: 0.004004
# 14425 	0.000002	 14220		Rank: 0.981637	|	0.000630	  1526		Rank: 0.105343
# 14426 	0.000029	   999		Rank: 0.068963	|	0.004896	   131		Rank: 0.009043
# 14427 	0.160746	     9		Rank: 0.000621	|	0.604062	     2		Rank: 0.000138
# 14428 	0.000026	  1262		Rank: 0.087119	|	0.001474	   522		Rank: 0.036035
# 14429 	0.708671	     6		Rank: 0.000414	|	0.188084	    11		Rank: 0.000759
# 14430 	0.000322	    94		Rank: 0.006489	|	0.018850	    44		Rank: 0.003037
# 14431 	0.000028	  1089		Rank: 0.075176	|	0.002573	   264		Rank: 0.018224
# 14432 	0.000078	   254		Rank: 0.017534	|	0.004952	   128		Rank: 0.008836
# 14433 	0.000026	  1308		Rank: 0.090294	|	0.005711	   115		Rank: 0.007939
# 14434 	0.000009	  8551		Rank: 0.590294	|	0.000092	 10853		Rank: 0.749206
# 14435 	0.000008	  9950		Rank: 0.686870	|	0.000053	 14108		Rank: 0.973906
# 14436 	0.920472	     5		Rank: 0.000345	|	0.393397	     5		Rank: 0.000345
# 14437 	0.069630	    11		Rank: 0.000759	|	0.035639	    28		Rank: 0.001933
# 14438 	0.000193	   117		Rank: 0.008077	|	0.059066	    19		Rank: 0.001312
# 14439 	0.040926	    14		Rank: 0.000966	|	0.298602	     7		Rank: 0.000483

# %%
test_list = [14425, 14428, 14431, 14438]

for test_id in test_list:
    test_molecule = X_test[test_id]
    print 'testing: ', test_id
    for i in range(len(X_train)):
        x_val = X_train[i]
        sim = similarity(test_molecule, x_val)
        if sim / sum(test_molecule) >= 0.6:
            print i, '\t', sim, '\t true label', y_train[i, 0]
    print
# Out:
# testing:  14425
# 898 	41.0 	 true label 0.0
# 904 	37.0 	 true label 0.0
# 906 	43.0 	 true label 0.0
# 914 	35.0 	 true label 0.0
# 925 	43.0 	 true label 0.0
# 933 	40.0 	 true label 0.0
# 935 	36.0 	 true label 0.0
# 936 	39.0 	 true label 0.0
# 4856 	33.0 	 true label 0.0
# 4858 	43.0 	 true label 0.0
# 4879 	33.0 	 true label 0.0
# 4884 	35.0 	 true label 0.0
# 4891 	36.0 	 true label 0.0
# 4892 	39.0 	 true label 0.0
# 4912 	42.0 	 true label 0.0
# 4919 	39.0 	 true label 0.0
# 6261 	33.0 	 true label 0.0
# 6262 	33.0 	 true label 0.0
# 6270 	44.0 	 true label 0.0
# 6279 	39.0 	 true label 0.0
# 6288 	33.0 	 true label 0.0
# 6296 	34.0 	 true label 0.0
# 6300 	34.0 	 true label 0.0
# 6301 	36.0 	 true label 0.0
# 6314 	41.0 	 true label 0.0
# 6323 	39.0 	 true label 0.0
# 6332 	36.0 	 true label 0.0
# 6350 	33.0 	 true label 0.0
# 15329 	35.0 	 true label 0.0
# 15347 	41.0 	 true label 0.0
# 15363 	33.0 	 true label 0.0
# 15366 	37.0 	 true label 0.0
# 15372 	37.0 	 true label 0.0
# 15389 	36.0 	 true label 0.0
# 15390 	37.0 	 true label 0.0
# 15598 	34.0 	 true label 0.0
# 15645 	37.0 	 true label 0.0
# 15664 	40.0 	 true label 0.0
# 19369 	39.0 	 true label 0.0
# 19378 	38.0 	 true label 0.0
# 19388 	44.0 	 true label 0.0
# 19389 	36.0 	 true label 0.0
# 19398 	41.0 	 true label 0.0
# 19401 	45.0 	 true label 0.0
# 19409 	36.0 	 true label 0.0
# 19414 	39.0 	 true label 0.0
# 19423 	45.0 	 true label 0.0
# 19430 	34.0 	 true label 0.0
# 19431 	39.0 	 true label 0.0
# 20766 	35.0 	 true label 0.0
# 20767 	37.0 	 true label 0.0
# 20770 	36.0 	 true label 0.0
# 20776 	37.0 	 true label 0.0
# 20777 	36.0 	 true label 0.0
# 20794 	37.0 	 true label 0.0
# 20803 	38.0 	 true label 0.0
# 20804 	33.0 	 true label 0.0
# 20814 	41.0 	 true label 0.0
# 20817 	34.0 	 true label 0.0
# 20876 	39.0 	 true label 0.0
# 20877 	33.0 	 true label 0.0
# 29827 	39.0 	 true label 0.0
# 29829 	41.0 	 true label 0.0
# 29833 	36.0 	 true label 0.0
# 29836 	43.0 	 true label 0.0
# 29852 	40.0 	 true label 0.0
# 29860 	41.0 	 true label 0.0
# 29868 	37.0 	 true label 0.0
# 29869 	39.0 	 true label 0.0
# 29875 	42.0 	 true label 0.0
# 29884 	37.0 	 true label 0.0
# 29889 	41.0 	 true label 0.0
# 30115 	34.0 	 true label 0.0
# 30129 	34.0 	 true label 0.0
# 33792 	48.0 	 true label 0.0
# 33799 	42.0 	 true label 0.0
# 33806 	33.0 	 true label 0.0
# 33815 	51.0 	 true label 0.0
# 33817 	39.0 	 true label 0.0
# 33820 	43.0 	 true label 0.0
# 33825 	41.0 	 true label 0.0
# 33833 	45.0 	 true label 0.0
# 33834 	48.0 	 true label 0.0
# 33838 	39.0 	 true label 0.0
# 33849 	38.0 	 true label 0.0
# 33850 	39.0 	 true label 0.0
# 35191 	33.0 	 true label 0.0
# 35210 	38.0 	 true label 0.0
# 35228 	36.0 	 true label 0.0
# 35868 	33.0 	 true label 0.0
# 36417 	34.0 	 true label 0.0
# 43410 	33.0 	 true label 0.0
#
# testing:  14428
# 2295 	26.0 	 true label 0.0
# 2777 	26.0 	 true label 0.0
# 3613 	29.0 	 true label 0.0
# 3795 	27.0 	 true label 0.0
# 3994 	27.0 	 true label 0.0
# 4024 	26.0 	 true label 0.0
# 4119 	27.0 	 true label 0.0
# 4141 	28.0 	 true label 0.0
# 5934 	30.0 	 true label 0.0
# 6517 	27.0 	 true label 0.0
# 6716 	26.0 	 true label 0.0
# 6872 	29.0 	 true label 0.0
# 7242 	32.0 	 true label 0.0
# 7276 	30.0 	 true label 0.0
# 7366 	30.0 	 true label 0.0
# 8167 	26.0 	 true label 0.0
# 8556 	27.0 	 true label 0.0
# 9431 	27.0 	 true label 0.0
# 10720 	28.0 	 true label 0.0
# 10966 	30.0 	 true label 0.0
# 11165 	27.0 	 true label 0.0
# 11397 	26.0 	 true label 0.0
# 12122 	28.0 	 true label 0.0
# 12153 	28.0 	 true label 0.0
# 12325 	28.0 	 true label 0.0
# 12850 	28.0 	 true label 0.0
# 13664 	29.0 	 true label 0.0
# 15365 	26.0 	 true label 0.0
# 16028 	26.0 	 true label 0.0
# 16486 	26.0 	 true label 0.0
# 17369 	27.0 	 true label 0.0
# 17492 	28.0 	 true label 0.0
# 17504 	28.0 	 true label 0.0
# 18078 	28.0 	 true label 0.0
# 20386 	26.0 	 true label 0.0
# 20823 	27.0 	 true label 0.0
# 21206 	29.0 	 true label 0.0
# 21769 	30.0 	 true label 0.0
# 21791 	26.0 	 true label 0.0
# 21823 	27.0 	 true label 0.0
# 21973 	26.0 	 true label 0.0
# 21989 	27.0 	 true label 0.0
# 21992 	26.0 	 true label 0.0
# 21995 	30.0 	 true label 0.0
# 22865 	29.0 	 true label 0.0
# 22881 	30.0 	 true label 0.0
# 23012 	27.0 	 true label 0.0
# 23758 	27.0 	 true label 0.0
# 24439 	29.0 	 true label 0.0
# 25460 	26.0 	 true label 0.0
# 26171 	30.0 	 true label 0.0
# 26300 	27.0 	 true label 0.0
# 26569 	27.0 	 true label 0.0
# 26808 	27.0 	 true label 0.0
# 28146 	27.0 	 true label 0.0
# 29802 	28.0 	 true label 0.0
# 30319 	29.0 	 true label 0.0
# 30998 	26.0 	 true label 0.0
# 34662 	30.0 	 true label 0.0
# 34695 	26.0 	 true label 0.0
# 34826 	31.0 	 true label 0.0
# 34909 	27.0 	 true label 0.0
# 35779 	26.0 	 true label 0.0
# 36084 	30.0 	 true label 0.0
# 36162 	30.0 	 true label 0.0
# 36582 	29.0 	 true label 0.0
# 39962 	28.0 	 true label 0.0
# 40330 	27.0 	 true label 0.0
# 40362 	26.0 	 true label 0.0
# 40616 	28.0 	 true label 0.0
# 41031 	30.0 	 true label 0.0
# 41091 	29.0 	 true label 0.0
# 41183 	26.0 	 true label 0.0
#
# testing:  14431
# 24099 	33.0 	 true label 0.0
# 34501 	34.0 	 true label 0.0
#
# testing:  14438
# 4931 	39.0 	 true label 0.0
# 11494 	36.0 	 true label 0.0
# 11798 	33.0 	 true label 0.0
# 12348 	34.0 	 true label 0.0
# 12609 	33.0 	 true label 0.0
# 12612 	37.0 	 true label 0.0
# 12697 	38.0 	 true label 0.0
# 12748 	37.0 	 true label 0.0
# 13019 	34.0 	 true label 0.0
# 14435 	33.0 	 true label 1.0
# 15465 	35.0 	 true label 0.0
# 16143 	34.0 	 true label 0.0
# 18598 	33.0 	 true label 0.0
# 20384 	36.0 	 true label 0.0
# 26294 	37.0 	 true label 0.0
# 27278 	36.0 	 true label 0.0
# 27931 	38.0 	 true label 0.0
# 27937 	40.0 	 true label 0.0
# 27950 	37.0 	 true label 0.0
# 30008 	34.0 	 true label 0.0
# 30608 	34.0 	 true label 0.0
# 32191 	35.0 	 true label 0.0
# 34909 	35.0 	 true label 0.0
# 40456 	41.0 	 true label 0.0
# 40539 	43.0 	 true label 0.0
# 40709 	34.0 	 true label 0.0
# 41171 	36.0 	 true label 0.0
# 41740 	35.0 	 true label 0.0
# 42632 	36.0 	 true label 0.0

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rnd_state = 1337
clf = RandomForestClassifier(n_estimators=4000,
                             max_features='log2',
                             min_samples_leaf=1, 
                             n_jobs=3, 
                             class_weight='balanced',
                             random_state=rnd_state,
                             oob_score=False, 
                             verbose=0)
clf.fit(X_train, y_train)
# Out:
# /usr/local/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=4000, n_jobs=3,
#             oob_score=False, random_state=1337, verbose=0,
#             warm_start=False)

# %%
predict_with_existing(clf, X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# train precision: 1.0
# train roc: 1.0
# train bedroc: 0.994725515647
#
# validation precision: 0.351985010494
# validation roc: 0.961587641692
# validation bedroc: 0.829019613984
#
# test precision: 0.130721818647
# test roc: 0.872224861783
# test bedroc: 0.689646653184
#
# ratio: 0.02, EF: 31.25,	active: 16.0
# ratio: 0.01, EF: 62.5,	active: 16.0
# ratio: 0.0015, EF: 208.333333333,	active: 16.0
# ratio: 0.001, EF: 187.5,	active: 16.0

# %% [markdown]
# ## Show val and test rank on RF

# %%
y_pred_on_val_rf = reshape_data_into_2_dim(clf.predict_proba(X_val)[:, 1])
y_pred_on_test_rf = reshape_data_into_2_dim(clf.predict_proba(X_test)[:, 1])

# %%
print 'For validation'
get_rank(y_val, y_pred_on_val_rf)
print
print 'For test'
get_rank(y_test, y_pred_on_test_rf)
# Out:
# For validation
# 0.175000	     8/ 14484		Rank: 0.000552
# 0.010500	   173/ 14484		Rank: 0.011944
# 0.033250	    46/ 14484		Rank: 0.003176
# 0.000500	  4584/ 14484		Rank: 0.316487
# 0.133250	    15/ 14484		Rank: 0.001036
# 0.083750	    21/ 14484		Rank: 0.001450
# 0.307500	     1/ 14484		Rank: 0.000069
# 0.054500	    30/ 14484		Rank: 0.002071
# 0.198250	     5/ 14484		Rank: 0.000345
# 0.001750	  1086/ 14484		Rank: 0.074979
# 0.008500	   208/ 14484		Rank: 0.014361
# 0.000750	  3469/ 14484		Rank: 0.239506
# 0.121250	    16/ 14484		Rank: 0.001105
# 0.170750	     9/ 14484		Rank: 0.000621
# 0.044750	    38/ 14484		Rank: 0.002624
# 0.295500	     2/ 14484		Rank: 0.000138
#
# For test
# 0.021250	    93/ 14486		Rank: 0.006420
# 0.000000	  8667/ 14486		Rank: 0.598302
# 0.000750	  3383/ 14486		Rank: 0.233536
# 0.251750	     2/ 14486		Rank: 0.000138
# 0.001500	  1441/ 14486		Rank: 0.099475
# 0.147250	     8/ 14486		Rank: 0.000552
# 0.063000	    33/ 14486		Rank: 0.002278
# 0.004000	   443/ 14486		Rank: 0.030581
# 0.019500	    97/ 14486		Rank: 0.006696
# 0.017750	   103/ 14486		Rank: 0.007110
# 0.000250	  6975/ 14486		Rank: 0.481499
# 0.000250	  7019/ 14486		Rank: 0.484537
# 0.169500	     6/ 14486		Rank: 0.000414
# 0.122250	    15/ 14486		Rank: 0.001035
# 0.089500	    21/ 14486		Rank: 0.001450
# 0.082250	    26/ 14486		Rank: 0.001795

# %% [markdown]
# ## Compare Rank

# %% [markdown]
# ### Compare Rank on Val

# %%
compare_rank(y_val, y_pred_on_val_single_NN, y_pred_on_val_rf)
# Out:
# 14423 	0.999667	     1		Rank: 0.000069	|	0.175000	     8		Rank: 0.000552
# 14424 	0.000004	 13523		Rank: 0.933651	|	0.010500	   173		Rank: 0.011944
# 14425 	0.007614	    26		Rank: 0.001795	|	0.033250	    46		Rank: 0.003176
# 14426 	0.000007	 11032		Rank: 0.761668	|	0.000500	  4584		Rank: 0.316487
# 14427 	0.003222	    34		Rank: 0.002347	|	0.133250	    15		Rank: 0.001036
# 14428 	0.012485	    23		Rank: 0.001588	|	0.083750	    21		Rank: 0.001450
# 14429 	0.992665	     4		Rank: 0.000276	|	0.307500	     1		Rank: 0.000069
# 14430 	0.000008	 10578		Rank: 0.730323	|	0.054500	    30		Rank: 0.002071
# 14431 	0.997849	     3		Rank: 0.000207	|	0.198250	     5		Rank: 0.000345
# 14432 	0.000013	  5067		Rank: 0.349834	|	0.001750	  1086		Rank: 0.074979
# 14433 	0.000012	  6246		Rank: 0.431234	|	0.008500	   208		Rank: 0.014361
# 14434 	0.000013	  5766		Rank: 0.398094	|	0.000750	  3469		Rank: 0.239506
# 14435 	0.164386	     9		Rank: 0.000621	|	0.121250	    16		Rank: 0.001105
# 14436 	0.149422	    10		Rank: 0.000690	|	0.170750	     9		Rank: 0.000621
# 14437 	0.000069	   306		Rank: 0.021127	|	0.044750	    38		Rank: 0.002624
# 14438 	0.809995	     6		Rank: 0.000414	|	0.295500	     2		Rank: 0.000138

# %%
test_list = [14424, 14426, 14430, 14433]

for test_id in test_list:
    test_molecule = X_test[test_id]
    print 'testing: ', test_id
    for i in range(len(X_train)):
        x_val = X_train[i]
        sim = similarity(test_molecule, x_val)
        if sim / sum(test_molecule) >= 0.6:
            print i, '\t', sim, '\t true label', y_train[i, 0]
    print
# Out:
# testing:  14424
# 277 	39.0 	 true label 0.0
# 298 	41.0 	 true label 0.0
# 3057 	32.0 	 true label 0.0
# 3058 	30.0 	 true label 0.0
# 3713 	34.0 	 true label 0.0
# 4097 	30.0 	 true label 0.0
# 5804 	34.0 	 true label 0.0
# 7623 	30.0 	 true label 0.0
# 10142 	30.0 	 true label 0.0
# 10768 	31.0 	 true label 0.0
# 11441 	32.0 	 true label 0.0
# 11726 	30.0 	 true label 0.0
# 12130 	32.0 	 true label 0.0
# 12131 	32.0 	 true label 0.0
# 12132 	32.0 	 true label 0.0
# 14762 	38.0 	 true label 0.0
# 14771 	41.0 	 true label 0.0
# 15880 	37.0 	 true label 0.0
# 15945 	41.0 	 true label 0.0
# 16143 	32.0 	 true label 0.0
# 17651 	34.0 	 true label 0.0
# 17657 	33.0 	 true label 0.0
# 18202 	36.0 	 true label 0.0
# 18598 	30.0 	 true label 0.0
# 20267 	32.0 	 true label 0.0
# 20570 	30.0 	 true label 0.0
# 21839 	30.0 	 true label 0.0
# 23264 	30.0 	 true label 0.0
# 23271 	30.0 	 true label 0.0
# 24605 	30.0 	 true label 0.0
# 25102 	34.0 	 true label 0.0
# 25342 	31.0 	 true label 0.0
# 25908 	33.0 	 true label 0.0
# 26189 	30.0 	 true label 0.0
# 26294 	30.0 	 true label 0.0
# 26604 	31.0 	 true label 0.0
# 26605 	31.0 	 true label 0.0
# 27233 	30.0 	 true label 0.0
# 28906 	39.0 	 true label 1.0
# 29200 	41.0 	 true label 0.0
# 30107 	39.0 	 true label 0.0
# 30301 	30.0 	 true label 0.0
# 30608 	31.0 	 true label 0.0
# 32191 	37.0 	 true label 0.0
# 32416 	30.0 	 true label 0.0
# 33193 	32.0 	 true label 0.0
# 33215 	32.0 	 true label 0.0
# 34709 	32.0 	 true label 0.0
# 34710 	31.0 	 true label 0.0
# 34722 	32.0 	 true label 0.0
# 34723 	30.0 	 true label 0.0
# 36534 	30.0 	 true label 0.0
# 37405 	30.0 	 true label 0.0
# 37727 	30.0 	 true label 0.0
# 37772 	30.0 	 true label 0.0
# 38976 	33.0 	 true label 0.0
# 39718 	34.0 	 true label 0.0
# 39751 	30.0 	 true label 0.0
# 40709 	34.0 	 true label 0.0
# 40784 	30.0 	 true label 0.0
# 41373 	30.0 	 true label 0.0
# 41506 	30.0 	 true label 0.0
#
# testing:  14426
# 3368 	23.0 	 true label 0.0
# 6443 	23.0 	 true label 0.0
# 6455 	18.0 	 true label 0.0
# 9188 	24.0 	 true label 0.0
# 10077 	23.0 	 true label 0.0
# 13070 	18.0 	 true label 0.0
# 14439 	18.0 	 true label 0.0
# 15024 	21.0 	 true label 0.0
# 18017 	18.0 	 true label 0.0
# 19908 	23.0 	 true label 0.0
# 21104 	23.0 	 true label 0.0
# 23137 	18.0 	 true label 0.0
# 24708 	20.0 	 true label 0.0
# 29024 	19.0 	 true label 0.0
# 29025 	18.0 	 true label 0.0
# 29107 	23.0 	 true label 0.0
# 36025 	23.0 	 true label 0.0
# 39903 	23.0 	 true label 0.0
# 39907 	18.0 	 true label 0.0
#
# testing:  14430
# 14432 	32.0 	 true label 1.0
# 28916 	30.0 	 true label 1.0
# 43401 	30.0 	 true label 1.0
#
# testing:  14433

# %% [markdown]
# ### Compare Rank on Test

# %%
compare_rank(y_test, y_pred_on_test_single_NN, y_pred_on_test_rf)
# Out:
# 14424 	0.000033	   769		Rank: 0.053086	|	0.021250	    93		Rank: 0.006420
# 14425 	0.000002	 14220		Rank: 0.981637	|	0.000000	  8667		Rank: 0.598302
# 14426 	0.000029	   999		Rank: 0.068963	|	0.000750	  3383		Rank: 0.233536
# 14427 	0.160746	     9		Rank: 0.000621	|	0.251750	     2		Rank: 0.000138
# 14428 	0.000026	  1262		Rank: 0.087119	|	0.001500	  1441		Rank: 0.099475
# 14429 	0.708671	     6		Rank: 0.000414	|	0.147250	     8		Rank: 0.000552
# 14430 	0.000322	    94		Rank: 0.006489	|	0.063000	    33		Rank: 0.002278
# 14431 	0.000028	  1089		Rank: 0.075176	|	0.004000	   443		Rank: 0.030581
# 14432 	0.000078	   254		Rank: 0.017534	|	0.019500	    97		Rank: 0.006696
# 14433 	0.000026	  1308		Rank: 0.090294	|	0.017750	   103		Rank: 0.007110
# 14434 	0.000009	  8551		Rank: 0.590294	|	0.000250	  6975		Rank: 0.481499
# 14435 	0.000008	  9950		Rank: 0.686870	|	0.000250	  7019		Rank: 0.484537
# 14436 	0.920472	     5		Rank: 0.000345	|	0.169500	     6		Rank: 0.000414
# 14437 	0.069630	    11		Rank: 0.000759	|	0.122250	    15		Rank: 0.001035
# 14438 	0.000193	   117		Rank: 0.008077	|	0.089500	    21		Rank: 0.001450
# 14439 	0.040926	    14		Rank: 0.000966	|	0.082250	    26		Rank: 0.001795

# %%
test_list = [14424, 14425, 14433]

for test_id in test_list:
    test_molecule = X_test[test_id]
    print 'testing: ', test_id
    for i in range(len(X_train)):
        x_val = X_train[i]
        sim = similarity(test_molecule, x_val)
        if sim / sum(test_molecule) >= 0.5:
            print i, '\t', sim, '\t true label', y_train[i, 0]
    print
# Out:
# testing:  14424
# 80 	27.0 	 true label 0.0
# 259 	25.0 	 true label 0.0
# 277 	39.0 	 true label 0.0
# 298 	41.0 	 true label 0.0
# 431 	26.0 	 true label 0.0
# 1482 	26.0 	 true label 0.0
# 3057 	32.0 	 true label 0.0
# 3058 	30.0 	 true label 0.0
# 3127 	28.0 	 true label 0.0
# 3201 	26.0 	 true label 0.0
# 3246 	26.0 	 true label 0.0
# 3533 	28.0 	 true label 0.0
# 3712 	27.0 	 true label 0.0
# 3713 	34.0 	 true label 0.0
# 3723 	25.0 	 true label 0.0
# 3780 	27.0 	 true label 0.0
# 4097 	30.0 	 true label 0.0
# 4122 	29.0 	 true label 0.0
# 4798 	25.0 	 true label 0.0
# 4800 	26.0 	 true label 0.0
# 4828 	25.0 	 true label 0.0
# 4837 	25.0 	 true label 0.0
# 4838 	25.0 	 true label 0.0
# 4931 	25.0 	 true label 0.0
# 4984 	27.0 	 true label 0.0
# 5079 	25.0 	 true label 0.0
# 5804 	34.0 	 true label 0.0
# 5820 	27.0 	 true label 0.0
# 5903 	25.0 	 true label 0.0
# 5910 	25.0 	 true label 0.0
# 6269 	28.0 	 true label 0.0
# 6299 	26.0 	 true label 0.0
# 6542 	29.0 	 true label 0.0
# 7029 	27.0 	 true label 0.0
# 7166 	25.0 	 true label 0.0
# 7187 	27.0 	 true label 0.0
# 7357 	28.0 	 true label 0.0
# 7623 	30.0 	 true label 0.0
# 8050 	26.0 	 true label 0.0
# 8419 	27.0 	 true label 0.0
# 8783 	28.0 	 true label 0.0
# 8784 	29.0 	 true label 0.0
# 9974 	29.0 	 true label 0.0
# 9992 	29.0 	 true label 0.0
# 10132 	26.0 	 true label 0.0
# 10142 	30.0 	 true label 0.0
# 10312 	26.0 	 true label 0.0
# 10314 	25.0 	 true label 0.0
# 10657 	26.0 	 true label 0.0
# 10768 	31.0 	 true label 0.0
# 10783 	27.0 	 true label 0.0
# 11016 	27.0 	 true label 0.0
# 11441 	32.0 	 true label 0.0
# 11628 	25.0 	 true label 0.0
# 11672 	27.0 	 true label 0.0
# 11673 	25.0 	 true label 0.0
# 11726 	30.0 	 true label 0.0
# 11798 	27.0 	 true label 0.0
# 11951 	25.0 	 true label 0.0
# 12130 	32.0 	 true label 0.0
# 12131 	32.0 	 true label 0.0
# 12132 	32.0 	 true label 0.0
# 12348 	27.0 	 true label 0.0
# 12444 	26.0 	 true label 0.0
# 12477 	25.0 	 true label 0.0
# 12485 	26.0 	 true label 0.0
# 12609 	28.0 	 true label 0.0
# 12703 	26.0 	 true label 0.0
# 12748 	27.0 	 true label 0.0
# 12764 	26.0 	 true label 0.0
# 13019 	28.0 	 true label 0.0
# 13727 	28.0 	 true label 0.0
# 13819 	29.0 	 true label 0.0
# 13892 	26.0 	 true label 0.0
# 14762 	38.0 	 true label 0.0
# 14771 	41.0 	 true label 0.0
# 15465 	29.0 	 true label 0.0
# 15588 	25.0 	 true label 0.0
# 15880 	37.0 	 true label 0.0
# 15897 	26.0 	 true label 0.0
# 15945 	41.0 	 true label 0.0
# 16050 	27.0 	 true label 0.0
# 16143 	32.0 	 true label 0.0
# 16280 	25.0 	 true label 0.0
# 17103 	25.0 	 true label 0.0
# 17112 	25.0 	 true label 0.0
# 17223 	27.0 	 true label 0.0
# 17279 	28.0 	 true label 0.0
# 17651 	34.0 	 true label 0.0
# 17657 	33.0 	 true label 0.0
# 17753 	25.0 	 true label 0.0
# 17984 	27.0 	 true label 0.0
# 17994 	26.0 	 true label 0.0
# 18002 	29.0 	 true label 0.0
# 18032 	26.0 	 true label 0.0
# 18046 	25.0 	 true label 0.0
# 18202 	36.0 	 true label 0.0
# 18204 	26.0 	 true label 0.0
# 18263 	25.0 	 true label 0.0
# 18598 	30.0 	 true label 0.0
# 19289 	28.0 	 true label 0.0
# 19295 	25.0 	 true label 0.0
# 19309 	26.0 	 true label 0.0
# 19329 	25.0 	 true label 0.0
# 19439 	26.0 	 true label 0.0
# 19443 	26.0 	 true label 0.0
# 19450 	26.0 	 true label 0.0
# 19464 	25.0 	 true label 0.0
# 19490 	26.0 	 true label 0.0
# 19641 	26.0 	 true label 0.0
# 20267 	32.0 	 true label 0.0
# 20420 	25.0 	 true label 0.0
# 20501 	26.0 	 true label 0.0
# 20570 	30.0 	 true label 0.0
# 20782 	28.0 	 true label 0.0
# 20808 	28.0 	 true label 0.0
# 21010 	27.0 	 true label 0.0
# 21111 	25.0 	 true label 0.0
# 21533 	26.0 	 true label 0.0
# 21839 	30.0 	 true label 0.0
# 21871 	25.0 	 true label 0.0
# 22113 	25.0 	 true label 0.0
# 22125 	25.0 	 true label 0.0
# 22909 	26.0 	 true label 0.0
# 22955 	26.0 	 true label 0.0
# 23262 	29.0 	 true label 0.0
# 23264 	30.0 	 true label 0.0
# 23271 	30.0 	 true label 0.0
# 24379 	25.0 	 true label 0.0
# 24467 	26.0 	 true label 0.0
# 24605 	30.0 	 true label 0.0
# 25102 	34.0 	 true label 0.0
# 25332 	25.0 	 true label 0.0
# 25342 	31.0 	 true label 0.0
# 25531 	25.0 	 true label 0.0
# 25908 	33.0 	 true label 0.0
# 25940 	28.0 	 true label 0.0
# 25957 	26.0 	 true label 0.0
# 25976 	26.0 	 true label 0.0
# 26189 	30.0 	 true label 0.0
# 26294 	30.0 	 true label 0.0
# 26402 	25.0 	 true label 0.0
# 26604 	31.0 	 true label 0.0
# 26605 	31.0 	 true label 0.0
# 26942 	27.0 	 true label 0.0
# 27107 	25.0 	 true label 0.0
# 27233 	30.0 	 true label 0.0
# 27278 	25.0 	 true label 0.0
# 27585 	25.0 	 true label 0.0
# 27931 	29.0 	 true label 0.0
# 27937 	25.0 	 true label 0.0
# 27950 	28.0 	 true label 0.0
# 27977 	25.0 	 true label 0.0
# 28906 	39.0 	 true label 1.0
# 29120 	25.0 	 true label 0.0
# 29200 	41.0 	 true label 0.0
# 29282 	25.0 	 true label 0.0
# 29321 	27.0 	 true label 0.0
# 30008 	26.0 	 true label 0.0
# 30107 	39.0 	 true label 0.0
# 30301 	30.0 	 true label 0.0
# 30608 	31.0 	 true label 0.0
# 32141 	27.0 	 true label 0.0
# 32189 	27.0 	 true label 0.0
# 32191 	37.0 	 true label 0.0
# 32416 	30.0 	 true label 0.0
# 32458 	26.0 	 true label 0.0
# 32469 	26.0 	 true label 0.0
# 32625 	29.0 	 true label 0.0
# 32628 	25.0 	 true label 0.0
# 32652 	27.0 	 true label 0.0
# 32660 	26.0 	 true label 0.0
# 32680 	29.0 	 true label 0.0
# 32707 	25.0 	 true label 0.0
# 33039 	29.0 	 true label 0.0
# 33193 	32.0 	 true label 0.0
# 33215 	32.0 	 true label 0.0
# 33718 	27.0 	 true label 0.0
# 33734 	26.0 	 true label 0.0
# 33773 	27.0 	 true label 0.0
# 33783 	27.0 	 true label 0.0
# 33875 	26.0 	 true label 0.0
# 33882 	27.0 	 true label 0.0
# 33889 	26.0 	 true label 0.0
# 33891 	27.0 	 true label 0.0
# 33900 	25.0 	 true label 0.0
# 33903 	28.0 	 true label 0.0
# 34709 	32.0 	 true label 0.0
# 34710 	31.0 	 true label 0.0
# 34722 	32.0 	 true label 0.0
# 34723 	30.0 	 true label 0.0
# 34724 	28.0 	 true label 0.0
# 34867 	25.0 	 true label 0.0
# 34898 	25.0 	 true label 0.0
# 35016 	27.0 	 true label 0.0
# 35027 	26.0 	 true label 0.0
# 35355 	29.0 	 true label 0.0
# 35412 	27.0 	 true label 0.0
# 35424 	26.0 	 true label 0.0
# 35447 	29.0 	 true label 0.0
# 35458 	26.0 	 true label 0.0
# 35790 	26.0 	 true label 0.0
# 35987 	28.0 	 true label 0.0
# 36286 	28.0 	 true label 0.0
# 36442 	27.0 	 true label 0.0
# 36534 	30.0 	 true label 0.0
# 36895 	25.0 	 true label 0.0
# 37405 	30.0 	 true label 0.0
# 37437 	27.0 	 true label 0.0
# 37727 	30.0 	 true label 0.0
# 37772 	30.0 	 true label 0.0
# 38976 	33.0 	 true label 0.0
# 39127 	29.0 	 true label 0.0
# 39128 	25.0 	 true label 0.0
# 39238 	26.0 	 true label 0.0
# 39710 	29.0 	 true label 0.0
# 39718 	34.0 	 true label 0.0
# 39751 	30.0 	 true label 0.0
# 39929 	27.0 	 true label 0.0
# 39955 	28.0 	 true label 0.0
# 39981 	26.0 	 true label 0.0
# 40179 	25.0 	 true label 0.0
# 40180 	25.0 	 true label 0.0
# 40456 	26.0 	 true label 0.0
# 40475 	25.0 	 true label 0.0
# 40539 	26.0 	 true label 0.0
# 40618 	25.0 	 true label 0.0
# 40653 	28.0 	 true label 0.0
# 40654 	28.0 	 true label 0.0
# 40709 	34.0 	 true label 0.0
# 40748 	25.0 	 true label 0.0
# 40784 	30.0 	 true label 0.0
# 40786 	28.0 	 true label 0.0
# 40787 	29.0 	 true label 0.0
# 41215 	27.0 	 true label 0.0
# 41330 	28.0 	 true label 0.0
# 41373 	30.0 	 true label 0.0
# 41506 	30.0 	 true label 0.0
# 41830 	26.0 	 true label 0.0
# 41880 	26.0 	 true label 0.0
# 42153 	27.0 	 true label 0.0
# 42632 	28.0 	 true label 0.0
# 42651 	28.0 	 true label 0.0
# 42876 	25.0 	 true label 0.0
#
# testing:  14425
# 512 	27.0 	 true label 0.0
# 825 	27.0 	 true label 0.0
# 826 	28.0 	 true label 0.0
# 842 	29.0 	 true label 0.0
# 843 	29.0 	 true label 0.0
# 846 	29.0 	 true label 0.0
# 858 	27.0 	 true label 0.0
# 862 	27.0 	 true label 0.0
# 873 	28.0 	 true label 0.0
# 874 	27.0 	 true label 0.0
# 885 	30.0 	 true label 0.0
# 886 	32.0 	 true label 0.0
# 894 	29.0 	 true label 0.0
# 895 	30.0 	 true label 0.0
# 896 	30.0 	 true label 0.0
# 898 	41.0 	 true label 0.0
# 904 	37.0 	 true label 0.0
# 906 	43.0 	 true label 0.0
# 914 	35.0 	 true label 0.0
# 925 	43.0 	 true label 0.0
# 926 	27.0 	 true label 0.0
# 927 	27.0 	 true label 0.0
# 933 	40.0 	 true label 0.0
# 934 	28.0 	 true label 0.0
# 935 	36.0 	 true label 0.0
# 936 	39.0 	 true label 0.0
# 944 	31.0 	 true label 0.0
# 946 	28.0 	 true label 0.0
# 1093 	29.0 	 true label 0.0
# 1161 	29.0 	 true label 0.0
# 1169 	29.0 	 true label 0.0
# 1181 	31.0 	 true label 0.0
# 1185 	27.0 	 true label 0.0
# 1186 	32.0 	 true label 0.0
# 1191 	28.0 	 true label 0.0
# 1210 	30.0 	 true label 0.0
# 1213 	32.0 	 true label 0.0
# 1218 	29.0 	 true label 0.0
# 1221 	29.0 	 true label 0.0
# 1224 	32.0 	 true label 0.0
# 4026 	28.0 	 true label 0.0
# 4056 	28.0 	 true label 0.0
# 4065 	30.0 	 true label 0.0
# 4856 	33.0 	 true label 0.0
# 4858 	43.0 	 true label 0.0
# 4879 	33.0 	 true label 0.0
# 4884 	35.0 	 true label 0.0
# 4891 	36.0 	 true label 0.0
# 4892 	39.0 	 true label 0.0
# 4912 	42.0 	 true label 0.0
# 4919 	39.0 	 true label 0.0
# 6017 	29.0 	 true label 0.0
# 6211 	27.0 	 true label 0.0
# 6219 	28.0 	 true label 0.0
# 6261 	33.0 	 true label 0.0
# 6262 	33.0 	 true label 0.0
# 6270 	44.0 	 true label 0.0
# 6279 	39.0 	 true label 0.0
# 6288 	33.0 	 true label 0.0
# 6296 	34.0 	 true label 0.0
# 6300 	34.0 	 true label 0.0
# 6301 	36.0 	 true label 0.0
# 6314 	41.0 	 true label 0.0
# 6323 	39.0 	 true label 0.0
# 6332 	36.0 	 true label 0.0
# 6346 	27.0 	 true label 0.0
# 6350 	33.0 	 true label 0.0
# 6369 	29.0 	 true label 0.0
# 6705 	29.0 	 true label 0.0
# 6712 	28.0 	 true label 0.0
# 6886 	30.0 	 true label 0.0
# 6898 	28.0 	 true label 0.0
# 7417 	28.0 	 true label 0.0
# 7440 	28.0 	 true label 0.0
# 7447 	29.0 	 true label 0.0
# 7460 	28.0 	 true label 0.0
# 7468 	30.0 	 true label 0.0
# 7477 	30.0 	 true label 0.0
# 8546 	27.0 	 true label 0.0
# 8585 	28.0 	 true label 0.0
# 9085 	29.0 	 true label 0.0
# 10104 	27.0 	 true label 0.0
# 10724 	29.0 	 true label 0.0
# 10832 	28.0 	 true label 0.0
# 10834 	30.0 	 true label 0.0
# 10882 	29.0 	 true label 0.0
# 10883 	28.0 	 true label 0.0
# 11641 	28.0 	 true label 0.0
# 14425 	31.0 	 true label 1.0
# 15253 	28.0 	 true label 0.0
# 15262 	32.0 	 true label 0.0
# 15280 	30.0 	 true label 0.0
# 15286 	28.0 	 true label 0.0
# 15287 	28.0 	 true label 0.0
# 15291 	29.0 	 true label 0.0
# 15297 	29.0 	 true label 0.0
# 15314 	32.0 	 true label 0.0
# 15328 	30.0 	 true label 0.0
# 15329 	35.0 	 true label 0.0
# 15330 	31.0 	 true label 0.0
# 15334 	28.0 	 true label 0.0
# 15335 	29.0 	 true label 0.0
# 15345 	27.0 	 true label 0.0
# 15347 	41.0 	 true label 0.0
# 15354 	32.0 	 true label 0.0
# 15355 	29.0 	 true label 0.0
# 15362 	28.0 	 true label 0.0
# 15363 	33.0 	 true label 0.0
# 15364 	29.0 	 true label 0.0
# 15365 	29.0 	 true label 0.0
# 15366 	37.0 	 true label 0.0
# 15368 	29.0 	 true label 0.0
# 15370 	28.0 	 true label 0.0
# 15371 	29.0 	 true label 0.0
# 15372 	37.0 	 true label 0.0
# 15380 	28.0 	 true label 0.0
# 15381 	32.0 	 true label 0.0
# 15388 	29.0 	 true label 0.0
# 15389 	36.0 	 true label 0.0
# 15390 	37.0 	 true label 0.0
# 15538 	31.0 	 true label 0.0
# 15571 	27.0 	 true label 0.0
# 15593 	27.0 	 true label 0.0
# 15598 	34.0 	 true label 0.0
# 15603 	30.0 	 true label 0.0
# 15608 	27.0 	 true label 0.0
# 15620 	29.0 	 true label 0.0
# 15644 	30.0 	 true label 0.0
# 15645 	37.0 	 true label 0.0
# 15650 	29.0 	 true label 0.0
# 15651 	28.0 	 true label 0.0
# 15652 	28.0 	 true label 0.0
# 15656 	30.0 	 true label 0.0
# 15664 	40.0 	 true label 0.0
# 15666 	29.0 	 true label 0.0
# 15998 	28.0 	 true label 0.0
# 16029 	29.0 	 true label 0.0
# 16060 	27.0 	 true label 0.0
# 16088 	29.0 	 true label 0.0
# 16098 	29.0 	 true label 0.0
# 18580 	27.0 	 true label 0.0
# 18604 	29.0 	 true label 0.0
# 19369 	39.0 	 true label 0.0
# 19378 	38.0 	 true label 0.0
# 19388 	44.0 	 true label 0.0
# 19389 	36.0 	 true label 0.0
# 19398 	41.0 	 true label 0.0
# 19401 	45.0 	 true label 0.0
# 19409 	36.0 	 true label 0.0
# 19414 	39.0 	 true label 0.0
# 19421 	31.0 	 true label 0.0
# 19423 	45.0 	 true label 0.0
# 19430 	34.0 	 true label 0.0
# 19431 	39.0 	 true label 0.0
# 19432 	28.0 	 true label 0.0
# 20480 	28.0 	 true label 0.0
# 20484 	28.0 	 true label 0.0
# 20681 	27.0 	 true label 0.0
# 20715 	28.0 	 true label 0.0
# 20729 	27.0 	 true label 0.0
# 20766 	35.0 	 true label 0.0
# 20767 	37.0 	 true label 0.0
# 20770 	36.0 	 true label 0.0
# 20776 	37.0 	 true label 0.0
# 20777 	36.0 	 true label 0.0
# 20794 	37.0 	 true label 0.0
# 20803 	38.0 	 true label 0.0
# 20804 	33.0 	 true label 0.0
# 20814 	41.0 	 true label 0.0
# 20817 	34.0 	 true label 0.0
# 20860 	29.0 	 true label 0.0
# 20876 	39.0 	 true label 0.0
# 20877 	33.0 	 true label 0.0
# 21378 	30.0 	 true label 0.0
# 21391 	29.0 	 true label 0.0
# 21419 	28.0 	 true label 0.0
# 21421 	28.0 	 true label 0.0
# 21681 	29.0 	 true label 0.0
# 21701 	29.0 	 true label 0.0
# 21716 	32.0 	 true label 0.0
# 21980 	27.0 	 true label 0.0
# 22001 	30.0 	 true label 0.0
# 25117 	28.0 	 true label 0.0
# 25118 	28.0 	 true label 0.0
# 26071 	27.0 	 true label 0.0
# 26686 	31.0 	 true label 0.0
# 27809 	28.0 	 true label 0.0
# 28216 	27.0 	 true label 0.0
# 29763 	29.0 	 true label 0.0
# 29803 	28.0 	 true label 0.0
# 29810 	27.0 	 true label 0.0
# 29811 	28.0 	 true label 0.0
# 29818 	27.0 	 true label 0.0
# 29819 	29.0 	 true label 0.0
# 29821 	27.0 	 true label 0.0
# 29827 	39.0 	 true label 0.0
# 29829 	41.0 	 true label 0.0
# 29833 	36.0 	 true label 0.0
# 29834 	28.0 	 true label 0.0
# 29835 	28.0 	 true label 0.0
# 29836 	43.0 	 true label 0.0
# 29842 	29.0 	 true label 0.0
# 29849 	27.0 	 true label 0.0
# 29850 	28.0 	 true label 0.0
# 29852 	40.0 	 true label 0.0
# 29858 	29.0 	 true label 0.0
# 29860 	41.0 	 true label 0.0
# 29867 	30.0 	 true label 0.0
# 29868 	37.0 	 true label 0.0
# 29869 	39.0 	 true label 0.0
# 29874 	31.0 	 true label 0.0
# 29875 	42.0 	 true label 0.0
# 29884 	37.0 	 true label 0.0
# 29885 	27.0 	 true label 0.0
# 29887 	28.0 	 true label 0.0
# 29888 	28.0 	 true label 0.0
# 29889 	41.0 	 true label 0.0
# 30110 	27.0 	 true label 0.0
# 30112 	30.0 	 true label 0.0
# 30115 	34.0 	 true label 0.0
# 30119 	27.0 	 true label 0.0
# 30123 	30.0 	 true label 0.0
# 30129 	34.0 	 true label 0.0
# 30130 	27.0 	 true label 0.0
# 30132 	31.0 	 true label 0.0
# 30137 	29.0 	 true label 0.0
# 30139 	30.0 	 true label 0.0
# 30148 	27.0 	 true label 0.0
# 30151 	30.0 	 true label 0.0
# 30168 	27.0 	 true label 0.0
# 30170 	29.0 	 true label 0.0
# 30176 	28.0 	 true label 0.0
# 30177 	27.0 	 true label 0.0
# 30178 	31.0 	 true label 0.0
# 30179 	27.0 	 true label 0.0
# 32706 	28.0 	 true label 0.0
# 32967 	30.0 	 true label 0.0
# 32974 	27.0 	 true label 0.0
# 33792 	48.0 	 true label 0.0
# 33799 	42.0 	 true label 0.0
# 33806 	33.0 	 true label 0.0
# 33815 	51.0 	 true label 0.0
# 33817 	39.0 	 true label 0.0
# 33820 	43.0 	 true label 0.0
# 33825 	41.0 	 true label 0.0
# 33833 	45.0 	 true label 0.0
# 33834 	48.0 	 true label 0.0
# 33838 	39.0 	 true label 0.0
# 33849 	38.0 	 true label 0.0
# 33850 	39.0 	 true label 0.0
# 34916 	28.0 	 true label 0.0
# 34937 	29.0 	 true label 0.0
# 35139 	29.0 	 true label 0.0
# 35146 	31.0 	 true label 0.0
# 35157 	28.0 	 true label 0.0
# 35172 	32.0 	 true label 0.0
# 35174 	31.0 	 true label 0.0
# 35191 	33.0 	 true label 0.0
# 35210 	38.0 	 true label 0.0
# 35228 	36.0 	 true label 0.0
# 35251 	32.0 	 true label 0.0
# 35288 	29.0 	 true label 0.0
# 35299 	27.0 	 true label 0.0
# 35316 	29.0 	 true label 0.0
# 35364 	27.0 	 true label 0.0
# 35831 	27.0 	 true label 0.0
# 35850 	27.0 	 true label 0.0
# 35859 	29.0 	 true label 0.0
# 35868 	33.0 	 true label 0.0
# 35877 	29.0 	 true label 0.0
# 35878 	28.0 	 true label 0.0
# 36396 	28.0 	 true label 0.0
# 36417 	34.0 	 true label 0.0
# 36429 	29.0 	 true label 0.0
# 36435 	28.0 	 true label 0.0
# 36446 	29.0 	 true label 0.0
# 39200 	27.0 	 true label 0.0
# 39941 	27.0 	 true label 0.0
# 43410 	33.0 	 true label 0.0
#
# testing:  14433
# 14432 	26.0 	 true label 1.0
# 16752 	28.0 	 true label 0.0
# 24788 	27.0 	 true label 0.0
