# %%
from analysis import *
from docking_analysis import *
from IPython.display import Markdown

file_paths = {0: 'single_classification_22/46244865/',
              1: 'single_classification_42/46101892/', 
              2: 'single_regression_2/46245031/',
              3: 'single_regression_11/46245032/',
              4: 'vanilla_lstm_8/46680983/',
              5: 'vanilla_lstm_19/46680994/',
              6: 'multi_classification_15/eval_keck/',
              7: 'multi_classification_18/eval_keck/',
              8: 'sklearn_rf_390014_96/',
              9: 'sklearn_rf_390014_97/'}

number = 20

evaluations = {0: 'train prec', 1: 'train roc', 2: 'train bedroc',
               3: 'val prec', 4: 'val roc', 5: 'val bedroc',
               6: 'test prec', 7: 'test roc', 8: 'test bedroc',
               9: 'EF_2', 10: 'EF_1', 11: 'EF_015', 12: 'EF_01'}

paths = ['../../output/stage_1/cross_validation_RMI/{}'.format(p) for p in file_paths.values()]
model_list = ['single_classification_22',
              'single_classification_42',
              'single_regression_2',
              'single_regression_11',
              'vanilla_lstm_8',
              'vanilla_lstm_19',
              'multi_classification_15',
              'multi_classification_18',
              'random_forest_96',
              'random_forest_97']
# Out:
# /home/sliu426/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
for k in range(len(file_paths)):
    print 'Check ', file_paths[k]
    check_result_completeness(file_path=paths[k], number=number)
    print
# Out:
# Check  single_classification_22/46244865/
# All output result complete.
#
# Check  single_classification_42/46101892/
# All output result complete.
#
# Check  single_regression_2/46245031/
# All output result complete.
#
# Check  single_regression_11/46245032/
# All output result complete.
#
# Check  vanilla_lstm_8/46680983/
# All output result complete.
#
# Check  vanilla_lstm_19/46680994/
# All output result complete.
#
# Check  multi_classification_15/eval_keck/
# All output result complete.
#
# Check  multi_classification_18/eval_keck/
# All output result complete.
#
# Check  sklearn_rf_390014_96/
# All output result complete.
#
# Check  sklearn_rf_390014_97/
# All output result complete.

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                      model_list=model_list,
                      title='AUC[PR]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[0], evaluations[3], evaluations[6]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[PR]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.933 | 0.111 | 0.072 |
# | single_classification_42 | 0.985 | 0.099 | 0.082 |
# | single_regression_2 | 0.007 | 0.004 | 0.004 |
# | single_regression_11 | 0.549 | 0.040 | 0.040 |
# | vanilla_lstm_8 | 0.006 | 0.007 | 0.006 |
# | vanilla_lstm_19 | 0.006 | 0.007 | 0.005 |
# | multi_classification_15 | 0.640 | 0.054 | 0.044 |
# | multi_classification_18 | 0.774 | 0.062 | 0.041 |
# | random_forest_96 | 1.000 | 0.000 | 0.122 |
# | random_forest_97 | 1.000 | 0.000 | 0.124 |
#
# ## Model comparison
# ### median of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.997 | 0.120 | 0.068 |
# | single_classification_42 | 1.000 | 0.110 | 0.085 |
# | single_regression_2 | 0.005 | 0.004 | 0.004 |
# | single_regression_11 | 0.547 | 0.035 | 0.035 |
# | vanilla_lstm_8 | 0.006 | 0.006 | 0.006 |
# | vanilla_lstm_19 | 0.006 | 0.007 | 0.005 |
# | multi_classification_15 | 0.752 | 0.051 | 0.034 |
# | multi_classification_18 | 0.812 | 0.061 | 0.035 |
# | random_forest_96 | 1.000 | 0.000 | 0.109 |
# | random_forest_97 | 1.000 | 0.000 | 0.110 |
#
# ## Model comparison
# ### std of AUC[PR]
# | model | train prec | val prec | test prec |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.135 | 0.036 | 0.034 |
# | single_classification_42 | 0.069 | 0.040 | 0.040 |
# | single_regression_2 | 0.005 | 0.000 | 0.000 |
# | single_regression_11 | 0.023 | 0.023 | 0.024 |
# | vanilla_lstm_8 | 0.002 | 0.002 | 0.002 |
# | vanilla_lstm_19 | 0.001 | 0.002 | 0.002 |
# | multi_classification_15 | 0.347 | 0.028 | 0.032 |
# | multi_classification_18 | 0.193 | 0.029 | 0.019 |
# | random_forest_96 | 0.000 | 0.000 | 0.050 |
# | random_forest_97 | 0.000 | 0.000 | 0.051 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                      model_list=model_list,
                      title='AUC[ROC]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[1], evaluations[4], evaluations[7]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.997 | 0.662 | 0.655 |
# | single_classification_42 | 1.000 | 0.663 | 0.662 |
# | single_regression_2 | 0.486 | 0.389 | 0.388 |
# | single_regression_11 | 0.998 | 0.467 | 0.463 |
# | vanilla_lstm_8 | 0.555 | 0.589 | 0.558 |
# | vanilla_lstm_19 | 0.540 | 0.577 | 0.520 |
# | multi_classification_15 | 0.919 | 0.730 | 0.726 |
# | multi_classification_18 | 0.995 | 0.755 | 0.753 |
# | random_forest_96 | 1.000 | 0.000 | 0.831 |
# | random_forest_97 | 1.000 | 0.000 | 0.835 |
#
# ## Model comparison
# ### median of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification_22 | 1.000 | 0.637 | 0.655 |
# | single_classification_42 | 1.000 | 0.666 | 0.661 |
# | single_regression_2 | 0.490 | 0.383 | 0.382 |
# | single_regression_11 | 0.998 | 0.458 | 0.454 |
# | vanilla_lstm_8 | 0.560 | 0.585 | 0.558 |
# | vanilla_lstm_19 | 0.532 | 0.570 | 0.528 |
# | multi_classification_15 | 0.996 | 0.752 | 0.743 |
# | multi_classification_18 | 0.998 | 0.761 | 0.760 |
# | random_forest_96 | 1.000 | 0.000 | 0.836 |
# | random_forest_97 | 1.000 | 0.000 | 0.842 |
#
# ## Model comparison
# ### std of AUC[ROC]
# | model | train roc | val roc | test roc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.008 | 0.080 | 0.068 |
# | single_classification_42 | 0.002 | 0.058 | 0.050 |
# | single_regression_2 | 0.019 | 0.029 | 0.029 |
# | single_regression_11 | 0.000 | 0.042 | 0.038 |
# | vanilla_lstm_8 | 0.036 | 0.041 | 0.048 |
# | vanilla_lstm_19 | 0.047 | 0.047 | 0.058 |
# | multi_classification_15 | 0.161 | 0.078 | 0.080 |
# | multi_classification_18 | 0.005 | 0.052 | 0.044 |
# | random_forest_96 | 0.000 | 0.000 | 0.034 |
# | random_forest_97 | 0.000 | 0.000 | 0.036 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                      model_list=model_list,
                      title='AUC[BED ROC]')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[2], evaluations[5], evaluations[8]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='AUC[BED ROC]')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.965 | 0.344 | 0.339 |
# | single_classification_42 | 0.975 | 0.359 | 0.337 |
# | single_regression_2 | 0.091 | 0.055 | 0.054 |
# | single_regression_11 | 0.958 | 0.168 | 0.168 |
# | vanilla_lstm_8 | 0.136 | 0.147 | 0.134 |
# | vanilla_lstm_19 | 0.130 | 0.152 | 0.117 |
# | multi_classification_15 | 0.795 | 0.339 | 0.318 |
# | multi_classification_18 | 0.944 | 0.378 | 0.358 |
# | random_forest_96 | 0.977 | 0.000 | 0.505 |
# | random_forest_97 | 0.977 | 0.000 | 0.511 |
#
# ## Model comparison
# ### median of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.977 | 0.323 | 0.329 |
# | single_classification_42 | 0.977 | 0.359 | 0.332 |
# | single_regression_2 | 0.094 | 0.049 | 0.049 |
# | single_regression_11 | 0.958 | 0.174 | 0.160 |
# | vanilla_lstm_8 | 0.138 | 0.135 | 0.129 |
# | vanilla_lstm_19 | 0.130 | 0.153 | 0.112 |
# | multi_classification_15 | 0.942 | 0.361 | 0.338 |
# | multi_classification_18 | 0.958 | 0.382 | 0.365 |
# | random_forest_96 | 0.977 | 0.000 | 0.476 |
# | random_forest_97 | 0.977 | 0.000 | 0.481 |
#
# ## Model comparison
# ### std of AUC[BED ROC]
# | model | train bedroc | val bedroc | test bedroc |
# | --- | --- | --- | --- |
# | single_classification_22 | 0.033 | 0.084 | 0.065 |
# | single_classification_42 | 0.012 | 0.069 | 0.059 |
# | single_regression_2 | 0.018 | 0.015 | 0.015 |
# | single_regression_11 | 0.001 | 0.034 | 0.029 |
# | vanilla_lstm_8 | 0.027 | 0.046 | 0.044 |
# | vanilla_lstm_19 | 0.037 | 0.049 | 0.036 |
# | multi_classification_15 | 0.320 | 0.081 | 0.082 |
# | multi_classification_18 | 0.034 | 0.062 | 0.046 |
# | random_forest_96 | 0.000 | 0.000 | 0.057 |
# | random_forest_97 | 0.000 | 0.000 | 0.058 |

# %%
plot_cross_validation(paths,
                      evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                      model_list=model_list,
                      title='Enrichment Factor on Test Set')

# %%
mean_content, median_content, std_content = table_cross_validation(paths,
                                                                   evaluation_list=[evaluations[9], evaluations[10], evaluations[11], evaluations[12]],
                                                                   model_list=model_list,
                                                                   evaluation_mode='Enrichment Factor (Test-set)')
content = '{}\n{}\n{}'.format(mean_content, median_content, std_content)
Markdown(content)
# Out:
# ## Model comparison
# ### mean of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification_22 | 11.998 | 19.105 | 51.440 | 54.278 |
# | single_classification_42 | 11.898 | 20.315 | 49.376 | 62.080 |
# | single_regression_2 | 0.652 | 0.655 | 0.709 | 0.000 |
# | single_regression_11 | 6.790 | 12.491 | 47.074 | 51.179 |
# | vanilla_lstm_8 | 1.255 | 1.092 | 0.741 | 1.111 |
# | vanilla_lstm_19 | 1.032 | 1.191 | 2.159 | 1.111 |
# | multi_classification_15 | 8.250 | 12.486 | 31.913 | 34.916 |
# | multi_classification_18 | 9.343 | 14.117 | 33.189 | 34.656 |
# | random_forest_96 | 16.935 | 27.383 | 63.860 | 78.298 |
# | random_forest_97 | 16.935 | 27.818 | 63.860 | 78.298 |
#
# ## Model comparison
# ### median of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification_22 | 11.962 | 20.000 | 50.591 | 63.830 |
# | single_classification_42 | 12.494 | 20.000 | 50.591 | 63.830 |
# | single_regression_2 | 0.000 | 0.000 | 0.000 | 0.000 |
# | single_regression_11 | 6.667 | 12.905 | 44.444 | 63.830 |
# | vanilla_lstm_8 | 1.075 | 0.000 | 0.000 | 0.000 |
# | vanilla_lstm_19 | 1.099 | 0.000 | 0.000 | 0.000 |
# | multi_classification_15 | 8.696 | 11.111 | 35.769 | 21.981 |
# | multi_classification_18 | 10.000 | 13.333 | 28.369 | 22.222 |
# | random_forest_96 | 15.556 | 24.444 | 74.074 | 88.889 |
# | random_forest_97 | 15.556 | 26.087 | 74.074 | 88.889 |
#
# ## Model comparison
# ### std of Enrichment Factor (Test-set)
# | model | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | single_classification_22 | 3.016 | 5.657 | 30.270 | 35.995 |
# | single_classification_42 | 3.343 | 6.422 | 25.763 | 39.174 |
# | single_regression_2 | 0.890 | 1.254 | 3.172 | 0.000 |
# | single_regression_11 | 1.519 | 3.263 | 22.536 | 28.795 |
# | vanilla_lstm_8 | 1.335 | 2.382 | 3.313 | 4.969 |
# | vanilla_lstm_19 | 0.892 | 1.642 | 5.275 | 4.969 |
# | multi_classification_15 | 3.421 | 5.932 | 23.927 | 31.495 |
# | multi_classification_18 | 2.417 | 4.619 | 23.307 | 24.595 |
# | random_forest_96 | 2.840 | 5.602 | 27.796 | 45.804 |
# | random_forest_97 | 2.840 | 5.386 | 27.796 | 45.804 |

# %% [markdown]
# # Docking Results

# %%
content = get_auc_table(file_path='../../output/docking/stage_1/lc123_rmi_all_docking_scores.csv',
                        target_name='Keck_RMI_cdd',
                        auc_list=['precision_auc_single', 'roc_auc_single', 'bedroc_auc_single'],
                        auc_header=['AUC[PR]', 'AUC[ROC]', 'AUC[BED ROC]'],
                        title='AUC for Docking Methods')
Markdown(content)
# Out:
# ## AUC for Docking Methods
# | docking method | AUC[PR] | AUC[ROC] | AUC[BED ROC] |
# | --- | --- | --- | --- |
# | consensus_bcs_efr1_opt | 0.004717 | 0.478746 | 0.089088 |
# | consensus_bcs_rocauc_opt | 0.004670 | 0.480623 | 0.084198 |
# | consensus_dockscore_max | 0.008438 | 0.549098 | 0.151286 |
# | consensus_dockscore_mean | 0.005138 | 0.499520 | 0.106350 |
# | consensus_dockscore_median | 0.004947 | 0.495799 | 0.100859 |
# | dockscore_ad4 | 0.007137 | 0.545203 | 0.147147 |
# | dockscore_dock6 | 0.004384 | 0.426895 | 0.059025 |
# | dockscore_fred | 0.004312 | 0.477780 | 0.088328 |
# | dockscore_hybrid | 0.006733 | 0.573188 | 0.155289 |
# | dockscore_plants | 0.004411 | 0.486771 | 0.095651 |
# | dockscore_rdockint | 0.004707 | 0.500415 | 0.106783 |
# | dockscore_rdocktot | 0.011470 | 0.555950 | 0.165897 |
# | dockscore_smina | 0.007661 | 0.536561 | 0.138841 |
# | dockscore_surflex | 0.003717 | 0.406184 | 0.069794 |

# %%
EF_ratio_list = [0.02, 0.01, 0.0015, 0.001]
content = get_ef_table(file_path='../../output/docking/stage_1/lc123_rmi_all_docking_scores.csv',
                       target_name='Keck_RMI_cdd',
                       efr_list=EF_ratio_list,
                       ef_header=['EF_2', 'EF_1', 'EF_015', 'EF_01'],
                       title='Enrichment Factor for Docking Methods')
Markdown(content)
# Out:
# ## Enrichment Factor for Docking Methods
# | docking method | EF_2 | EF_1 | EF_015 | EF_01 |
# | --- | --- | --- | --- | --- |
# | consensus_bcs_efr1_opt | 1.46341463415 | 1.46341463415 | 3.25203252033 | 4.87804878049 |
# | consensus_bcs_rocauc_opt | 1.46341463415 | 1.46341463415 | 3.25203252033 | 4.87804878049 |
# | consensus_dockscore_max | 3.17073170732 | 3.41463414634 | 9.75609756098 | 9.75609756098 |
# | consensus_dockscore_mean | 2.68292682927 | 2.92682926829 | 3.25203252033 | 4.87804878049 |
# | consensus_dockscore_median | 2.19512195122 | 1.9512195122 | 6.50406504065 | 4.87804878049 |
# | dockscore_ad4 | 2.43902439024 | 3.90243902439 | 13.0081300813 | 9.75609756098 |
# | dockscore_dock6 | 1.22549019608 | 1.96078431373 | 9.80392156863 | 14.7058823529 |
# | dockscore_fred | 0.975609756098 | 0.487804878049 | 0.0 | 0.0 |
# | dockscore_hybrid | 2.19512195122 | 2.43902439024 | 3.25203252033 | 4.87804878049 |
# | dockscore_plants | 0.731707317073 | 1.46341463415 | 0.0 | 0.0 |
# | dockscore_rdockint | 1.21951219512 | 0.975609756098 | 0.0 | 0.0 |
# | dockscore_rdocktot | 3.17073170732 | 2.92682926829 | 3.25203252033 | 4.87804878049 |
# | dockscore_smina | 2.19512195122 | 3.41463414634 | 9.75609756098 | 14.6341463415 |
# | dockscore_surflex | 0.731707317073 | 0.975609756098 | 3.25203252033 | 0.0 |

# %% [markdown]
# # Plot EF Curve

# %%
from EF_curve_support_loader import *

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 30.0)
# Out:
# Using Theano backend.
# Using gpu device 1: Tesla K40m (CNMeM is disabled, CuDNN 4004)

# %%
predictions_path = '../../output/stage_1_predictions/cross_validation_RMI'

model_names_list = ['single_classification_22',
                    'single_classification_42',
                    'single_regression_2',
                    'single_regression_11',
                    'multi_classification_15',
                    'multi_classification_18',
                    'sklearn_rf_390014_96',
                    'sklearn_rf_390014_97']

# %%
EF_ratio_list = np.linspace(0.001, 0.15, 100)
N = len(model_names_list)
data_set_name = 'Keck_RMI'

data_pd_list = []
for i in range(N):
    temp_pd = get_EF_curve_in_pd(EF_ratio_list=EF_ratio_list,
                                 data_set_name=data_set_name,
                                 model_name=model_names_list[i],
                                 predictions_path=predictions_path,
                                 regenerate=True)
    data_pd_list.append(temp_pd)
    
whole_pd = data_pd_list[0]
for i in range(1, N):
    whole_pd = whole_pd.append(data_pd_list[i])
# Out:
# running single_classification_22
# running single_classification_42
# running single_regression_2
# running single_regression_11
# running multi_classification_15
# running multi_classification_18
# running sklearn_rf_390014_96
# running sklearn_rf_390014_97

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 15.0)

# Calculate Normalized EF, and add it to dataframe
whole_pd['Normalized EF'] = whole_pd.apply(lambda row: row['EF'] / row['EF max'], axis=1)
sns.tsplot(data=whole_pd, time="EFR", unit="running process", condition="model", value="Normalized EF")
plt.savefig('plottings/NEF_curve.png')

# %%
focused_pd = whole_pd[whole_pd['EFR']<=0.06]
sns.tsplot(data=focused_pd, time="EFR", unit="running process", condition="model", value="Normalized EF")
